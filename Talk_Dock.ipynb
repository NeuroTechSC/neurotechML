# %% [markdown]
# # Loose EEGNet
# This notebook is a neural network that is based as much off of the EEGNet paper as I could understand.

# %% [markdown]
# ---

# %% [markdown]
# # Import/Install all necessary packages and libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np

from sklearn.metrics import roc_auc_score, precision_score, recall_score, accuracy_score, classification_report
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable, gradcheck
from torch.utils.data import TensorDataset, DataLoader

import pandas as pd

from matplotlib import pyplot

import math

from os import walk

# %% [markdown]
# # Check for GPU availability and set device

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %% [markdown]
# # Load and format the data

# %% [markdown]
# Here is a brief rundown of the data:
#
# > Each data segment (chunk) is a two second recording in which a subject subvocalized either "yes" or "no" at any point in the recording
#
# > The data is taken with a sampling frequency of 250hz, so in the end there are 500 timepoints for each chunk
#
# > The hardware we are using has 7 channels
#
# > After all these data cells are run the data is in the shape (# of chunks, 1, # of channels, # of timepoints)

# %%
master_data, master_label = [], []
datafix, labelfix = ".pkl", ".csv"
# paste path below
for (dirpath, dirnames, filenames) in walk('/content/drive/Shareddrives/NeuroTech ML/Processed Data Files'):
    new_data = [dirpath + '/' + name for name in filenames if datafix in name]
    master_data.extend(new_data)

    new_labels = [dirpath + '/' + name for name in filenames if labelfix in name]
    master_label.extend(new_labels)
assert len(master_data) == len(master_label)
master_data.sort()
master_label.sort()
for index in range(len(master_data)):
    try: 
        assert master_data[index][:-4] == master_label[index][:-11]
    except:
        print(index)
        print(master_data[index][:-4])
        print(master_label[index][:-11])

# %%
pkllabels = np.zeros((1, 1))
pkldata = np.zeros((1, 7, 500))
pkllabels2 = np.zeros((1, 1))
pkldata2 = np.zeros((1, 7, 500))

for i in range(len(master_data)):

    # To train no ICA data change data type to ICA
    # To train no ICA and weaker filter change data type to Weaker
    # To train unprocessed data change data type to Unprocessed

    data_type = "Talk_Dock"

    if data_type in master_data[i]:
        new_data = pd.read_pickle(master_data[i])

        new_labels = pd.read_csv(master_label[i], delimiter=',', header=None)
        if new_labels.shape[0] == 1 and new_labels.shape[1] > new_labels.shape[0]:
            new_labels = new_labels.T
        new_labels = np.array(new_labels)
        new_labels = new_labels.reshape((new_labels.shape[0], 1))

        pkldata = np.concatenate((pkldata, new_data), axis = 0)
        pkllabels = np.concatenate((pkllabels, new_labels), axis = 0)
    # elif data_type in master_data[i] and 'YESNO' in master_data[i]:
    #     new_data = pd.read_pickle(master_data[i])

    #     new_labels = pd.read_csv(master_label[i], delimiter=',', header=None)
    #     if new_labels.shape[0] == 1 and new_labels.shape[1] > new_labels.shape[0]:
    #         new_labels = new_labels.T
    #     new_labels = np.array(new_labels)
    #     new_labels = new_labels.reshape((new_labels.shape[0], 1))

    #     pkldata2 = np.concatenate((pkldata2, new_data), axis = 0)
    #     pkllabels2 = np.concatenate((pkllabels2, new_labels), axis = 0)

pkllabels = pkllabels[1:, :]
pkldata = pkldata[1:, :, :]
pkllabels2 = pkllabels2[1:, :]
pkldata2 = pkldata2[1:, :, :]

# %%
# Uncomment below if u wanna see a bunch of graphs of the data
print(pkldata.shape, pkllabels.shape)
print(pkllabels.shape)
x = pkldata[0]
only_no = [pkldata[i] for i in range(pkldata.shape[0]) if pkllabels[i][0] == 0]
only_no = np.array(only_no)
only_yes = [pkldata[i] for i in range(pkldata.shape[0]) if pkllabels[i][0] == 1]
only_yes = np.array(only_yes)
print(only_no.shape, only_yes.shape)
for i in range(pkldata.shape[1]):
    g = i + 1
    pyplot.plot(only_yes[0:, i, :].T, color="red")
    pyplot.plot(only_no[0:, i, :].T, alpha = .3, color="blue")
    pyplot.title("Value for channel {} over all {} chunks".format(i, pkldata.shape[0]))
    #pyplot.savefig(f"/content/drive/My Drive/Extra/processed_data_Riley_channel_{g}.png")
    pyplot.show()
# Out:
# (125, 7, 500) (125, 1)
# (125, 1)
# (62, 7, 500) (63, 7, 500)

# %%
torch.manual_seed(4)
torch.cuda.manual_seed(4)

# %%
channels = pkldata.shape[1]
timepoints = pkldata.shape[2]
print(channels, timepoints)
# Out:
# 7 500

# %%
BATCH_SIZE = 32

pkllabels = pkllabels.astype(np.float32)
X_actual = torch.from_numpy(pkllabels)

scaler = StandardScaler()
X_train = pkldata
# for i in range(len(X_train)):
#     X_train[i] = scaler.fit_transform(X_train[i])
X_train = torch.from_numpy(X_train)
X_train = X_train.unsqueeze(1)

# pkllabels2 = pkllabels2.astype(np.float32)
# X_test_labels = torch.from_numpy(pkllabels2)

# X_test = pkldata2
# X_test = torch.from_numpy(X_test)
# X_test = X_test.unsqueeze(1)

# splits the data into a train and dev set, and loads them into dataloaders
train_data, test_data, labels_train, labels_test = train_test_split(X_train, X_actual, test_size=0.2, random_state=4)

# test_data = X_test
# labels_test = X_test_labels

trainset = torch.utils.data.TensorDataset(train_data, labels_train)
testset = torch.utils.data.TensorDataset(test_data, labels_test)

train_loader = torch.utils.data.DataLoader(trainset, batch_size = BATCH_SIZE, shuffle = True, drop_last=True)
test_loader = torch.utils.data.DataLoader(testset, batch_size = test_data.shape[0], shuffle = True, drop_last=True)

print(train_data.shape, test_data.shape, labels_train.shape, labels_test.shape)
# Out:
# torch.Size([100, 1, 7, 500]) torch.Size([25, 1, 7, 500]) torch.Size([100, 1]) torch.Size([25, 1])

# %% [markdown]
# # Build the model and train
# A short breakdown of the paper:
# > EEGNet is a CNN for classification and interpretation of EEG-based BCI's
#
# > Benefits of EEGNet:
# > 1. Can be applied to different BCI paradagims (MI, ERP, SSVEP)
# > 2. Can be trained with very limited data
# > 3. Can produce neurophysiologically interpretable features
#
# > The model architecture:
# > 1. Fit 2D convolutional filters of size (1, sampling rate//2)
# > 2. Use a depthwise convolution of size (# of channels, 1)
# > 3. Add a separable convolution of size (1, 16)
# > 4. Flatten the data and feed it through a classification layer

# %%
# hyperparameters
freq, avg1stride, avg2stride = 250, (1, 4), (1, 8)
convstride = 1 # stride for each conv2D
conv1_neurons = 4
conv2_neurons = 8
conv3_neurons = 32
conv4_neurons = 16
kern1size = freq // 2
kern3size = 32

# %%
padding_needed = (kern1size - 1) / 2
conv1outx, conv1outy = (channels, (timepoints + (2 * padding_needed) - kern1size)/convstride + 1)

print("1st layer output size:", conv1outx, conv1outy)

conv2outx, conv2outy = ((conv1outx - channels)/convstride + 1, conv1outy)
conv2outx, conv2outy = conv2outx // avg1stride[0], conv2outy // avg1stride[1]

print("2nd layer output size:", conv2outx, conv2outy)

# conv3outx, conv3outy = (conv2outx, (conv2outy - kern3size)/convstride + 1)

# print("3rd layer output size:", conv3outx, conv3outy)

# conv4outx, conv4outy = (conv3outx, conv3outy)
# conv4outx, conv4outy = (conv4outx // avg2stride[0], conv4outy // avg2stride[1])

# print("4th layer output size:", conv4outx, conv4outy)

# flat1_in = int(conv4outx * conv4outy * conv4_neurons)

flat1_in = int(conv2outx * conv2outy * conv2_neurons)
# Out:
# 1st layer output size: 7 500.0
# 2nd layer output size: 1.0 125.0

# %% [markdown]
# Model description, layer by layer
#
# 1. Temporal convolution
# > * - Uses filters of (1, sampling frequency // 2)
# > * - Learns frequency filters at 2Hz and above
# 2. Depthwise convolution
# > * - Learns spatial filters
# 3. Separable Convolution
# > * - Conists of a deptwise convolution followed by a pointwise convolution
# > * - First learnes a kernel summarizing each feature map, then merges the outputs
# 4. Fully connected layer
# > * - Consists of a linear layer that reduces the channels, followed by a sigmoid classification

# %% [markdown]
# 3.5k research grant at school
#
# https://science.ucsc.edu/research-opportunities/undergraduate-research-in-science-and-technology-award/

# %%
class ConstrainedConv2d(nn.Conv2d):
    def forward(self, input):
        return F.conv2d(input, self.weight.clamp(min=-1.0, max=1.0), self.bias, self.stride,
                        self.padding, self.dilation, self.groups)

# %%
class EEGNet(nn.Module):
    def __init__(self):
        super(EEGNet, self).__init__()
        self.pad = nn.ZeroPad2d((math.floor(padding_needed), math.ceil(padding_needed), 0, 0))
        self.conv1 = nn.Conv2d(1, conv1_neurons, (1, kern1size), bias=False)
        self.norm1 = nn.BatchNorm2d(conv1_neurons)
        self.conv2 = ConstrainedConv2d(conv1_neurons, conv2_neurons, (channels, 1), bias=False)
        self.norm2 = nn.BatchNorm2d(conv2_neurons)
        self.pool = nn.MaxPool2d(avg1stride)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(flat1_in, 1)
        self.dropout = nn.Dropout()

        self.activation = nn.ELU()
        self.activation2 = nn.Sigmoid()

    def forward(self, x):
        out = self.pad(x)
        out = self.conv1(out)
        out = self.activation(out)
        out = self.norm1(out)

        out = self.conv2(out)
        out = self.activation(out)
        out = self.pool(self.norm2(out))
        out = self.dropout(out)

        out = self.activation2(self.fc1(self.flatten(out)))
        return out

CNNPoor = EEGNet()

# %%
# CNNPoor = nn.Sequential(
#     nn.ZeroPad2d((math.floor(padding_needed), math.ceil(padding_needed), 0, 0)),
#     nn.Conv2d(1, conv1_neurons, (1, kern1size), bias=False),
#     nn.ELU(),
#     nn.BatchNorm2d(conv1_neurons),
    
#     ConstrainedConv2d(conv1_neurons, conv2_neurons, (channels, 1), bias=False),
#     nn.ELU(),
#     nn.BatchNorm2d(conv2_neurons),
#     nn.MaxPool2d(avg1stride),
#     nn.Dropout(),
    
#     # nn.Conv2d(conv2_neurons, conv3_neurons, (1, kern3size), bias=False, groups=conv2_neurons),
#     # nn.Conv2d(conv3_neurons, conv4_neurons, kernel_size=1, bias=False),
#     # nn.ELU(),
#     # nn.BatchNorm2d(conv4_neurons),
#     # nn.MaxPool2d(avg2stride),
#     # nn.Dropout(),
    
#     nn.Flatten(),

#     nn.Linear(flat1_in, 1),
#     nn.Sigmoid(),
# )

CNNPoor = CNNPoor.to(device)

# %%
loss_function = nn.BCELoss()
optimizer = optim.Adam(CNNPoor.parameters(), lr = 0.001)

# %%
def test(model, device, test_loader):
    
    model.eval()
    correct = 0
    tot_loss = 0
    acc_score, prec_score, rec_score = 0, 0, 0
    with torch.no_grad():
        for (data, labels) in test_loader:
            data, labels = data.to(device), labels.to(device)
            
            classification = model(data.float())
            loss = loss_function(classification, labels)

            pred = torch.round(classification)
            correct += pred.eq(labels.view_as(pred)).sum().item()
            tot_loss += loss.item()

            acc_score += accuracy_score(labels, pred)
            prec_score += precision_score(labels, pred)
            rec_score += recall_score(labels, pred)

        print("\nTest set: Total loss: {:.6f}, Accuracy: {:.6f}".format(tot_loss, 
                                                                          correct / len(test_loader.dataset)))
        # print(classification_report(labels, pred))
        return (tot_loss, acc_score, prec_score, rec_score)

# %%
def train(model, device, train_loader, optimizer, epoch):

    model.train()
    correct = 0
    tot_loss = 0
    for batch, (data, labels) in enumerate(train_loader):
        data, labels = data.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        classification = model(data.float())
        loss = loss_function(classification, labels)

        loss.backward()
        optimizer.step()

        pred = torch.round(classification)
        correct += pred.eq(labels.view_as(pred)).sum().item()
        tot_loss += loss.item()
    print("Epoch: {}".format(epoch))
    print("\tAverage loss: {:.6f}".format(tot_loss / (batch + 1)))
    print("\tAccuracy: {:.6f}".format(correct / len(train_loader.dataset)))

    labels_detached = labels.detach()
    preds_detached = pred.detach()
    print(classification_report(labels_detached, preds_detached))
    return (tot_loss / (batch + 1), correct / len(train_loader.dataset))

# %%
plots = {"train loss": [],
         "train acc": [],
         "test loss": [],
         "test acc": [],
         "test prec": [],
         "test rec": []}

for epoch in range(120):
    trl, tra = train(CNNPoor, device, train_loader, optimizer, epoch)
    plots["train loss"].append(trl)
    plots["train acc"].append(tra)
    tl, ta, tp, tr = test(CNNPoor, device, test_loader)
    plots["test loss"].append(tl)
    plots["test acc"].append(ta)
    plots["test prec"].append(tp)
    plots["test rec"].append(tr)
# Out:
# Epoch: 0
# 	Average loss: 0.815873
# 	Accuracy: 0.410000
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.63      0.59        19
#          1.0       0.30      0.23      0.26        13
#
#     accuracy                           0.47        32
#    macro avg       0.42      0.43      0.42        32
# weighted avg       0.45      0.47      0.45        32
#
#
# Test set: Total loss: 0.850612, Accuracy: 0.480000
# Epoch: 1
# 	Average loss: 0.776917
# 	Accuracy: 0.470000
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.85      0.55        13
#          1.0       0.60      0.16      0.25        19
#
#     accuracy                           0.44        32
#    macro avg       0.50      0.50      0.40        32
# weighted avg       0.52      0.44      0.37        32
#
#
# Test set: Total loss: 0.808666, Accuracy: 0.480000
# Epoch: 2
# 	Average loss: 0.755346
# 	Accuracy: 0.460000
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.44      0.45        16
#          1.0       0.47      0.50      0.48        16
#
#     accuracy                           0.47        32
#    macro avg       0.47      0.47      0.47        32
# weighted avg       0.47      0.47      0.47        32
#
#
# Test set: Total loss: 0.808210, Accuracy: 0.480000
# Epoch: 3
# 	Average loss: 0.753913
# 	Accuracy: 0.420000
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.36      0.37        14
#          1.0       0.53      0.56      0.54        18
#
#     accuracy                           0.47        32
#    macro avg       0.46      0.46      0.46        32
# weighted avg       0.46      0.47      0.47        32
#
#
# Test set: Total loss: 0.788573, Accuracy: 0.480000
# Epoch: 4
# 	Average loss: 0.680138
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.22      0.32        18
#          1.0       0.44      0.79      0.56        14
#
#     accuracy                           0.47        32
#    macro avg       0.51      0.50      0.44        32
# weighted avg       0.51      0.47      0.43        32
#
#
# Test set: Total loss: 0.734242, Accuracy: 0.480000
# Epoch: 5
# 	Average loss: 0.688149
# 	Accuracy: 0.570000
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.73      0.63        15
#          1.0       0.67      0.47      0.55        17
#
#     accuracy                           0.59        32
#    macro avg       0.61      0.60      0.59        32
# weighted avg       0.61      0.59      0.59        32
#
#
# Test set: Total loss: 0.697175, Accuracy: 0.480000
# Epoch: 6
# 	Average loss: 0.765207
# 	Accuracy: 0.460000
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.43      0.41        14
#          1.0       0.53      0.50      0.51        18
#
#     accuracy                           0.47        32
#    macro avg       0.46      0.46      0.46        32
# weighted avg       0.47      0.47      0.47        32
#
#
# Test set: Total loss: 0.694055, Accuracy: 0.480000
# Epoch: 7
# 	Average loss: 0.728424
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.43      0.38        14
#          1.0       0.43      0.33      0.38        18
#
#     accuracy                           0.38        32
#    macro avg       0.38      0.38      0.38        32
# weighted avg       0.39      0.38      0.38        32
#
#
# Test set: Total loss: 0.692076, Accuracy: 0.520000
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 8
# 	Average loss: 0.698717
# 	Accuracy: 0.520000
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.41      0.47        17
#          1.0       0.47      0.60      0.53        15
#
#     accuracy                           0.50        32
#    macro avg       0.51      0.51      0.50        32
# weighted avg       0.51      0.50      0.50        32
#
#
# Test set: Total loss: 0.692703, Accuracy: 0.520000
# Epoch: 9
# 	Average loss: 0.665940
# 	Accuracy: 0.550000
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.47      0.52        15
#          1.0       0.60      0.71      0.65        17
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.58        32
# weighted avg       0.59      0.59      0.59        32
#
#
# Test set: Total loss: 0.692364, Accuracy: 0.520000
# Epoch: 10
# 	Average loss: 0.745051
# 	Accuracy: 0.530000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.53      0.52        15
#          1.0       0.56      0.53      0.55        17
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Test set: Total loss: 0.694030, Accuracy: 0.520000
# Epoch: 11
# 	Average loss: 0.771738
# 	Accuracy: 0.410000
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.79      0.56        14
#          1.0       0.57      0.22      0.32        18
#
#     accuracy                           0.47        32
#    macro avg       0.51      0.50      0.44        32
# weighted avg       0.51      0.47      0.43        32
#
#
# Test set: Total loss: 0.693481, Accuracy: 0.520000
# Epoch: 12
# 	Average loss: 0.671349
# 	Accuracy: 0.580000
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.69      0.69        16
#          1.0       0.69      0.69      0.69        16
#
#     accuracy                           0.69        32
#    macro avg       0.69      0.69      0.69        32
# weighted avg       0.69      0.69      0.69        32
#
#
# Test set: Total loss: 0.692863, Accuracy: 0.520000
# Epoch: 13
# 	Average loss: 0.736027
# 	Accuracy: 0.390000
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.25      0.25        12
#          1.0       0.55      0.55      0.55        20
#
#     accuracy                           0.44        32
#    macro avg       0.40      0.40      0.40        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.693148, Accuracy: 0.520000
# Epoch: 14
# 	Average loss: 0.741729
# 	Accuracy: 0.410000
#               precision    recall  f1-score   support
#
#          0.0       0.37      0.54      0.44        13
#          1.0       0.54      0.37      0.44        19
#
#     accuracy                           0.44        32
#    macro avg       0.45      0.45      0.44        32
# weighted avg       0.47      0.44      0.44        32
#
#
# Test set: Total loss: 0.693252, Accuracy: 0.520000
# Epoch: 15
# 	Average loss: 0.680201
# 	Accuracy: 0.520000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.53      0.51        17
#          1.0       0.43      0.40      0.41        15
#
#     accuracy                           0.47        32
#    macro avg       0.46      0.46      0.46        32
# weighted avg       0.47      0.47      0.47        32
#
#
# Test set: Total loss: 0.697001, Accuracy: 0.520000
# Epoch: 16
# 	Average loss: 0.709381
# 	Accuracy: 0.470000
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.44      0.44        16
#          1.0       0.44      0.44      0.44        16
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.707662, Accuracy: 0.520000
# Epoch: 17
# 	Average loss: 0.720527
# 	Accuracy: 0.440000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.62      0.56        16
#          1.0       0.50      0.38      0.43        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.49        32
# weighted avg       0.50      0.50      0.49        32
#
#
# Test set: Total loss: 0.713039, Accuracy: 0.520000
# Epoch: 18
# 	Average loss: 0.743036
# 	Accuracy: 0.430000
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.40      0.39        15
#          1.0       0.44      0.41      0.42        17
#
#     accuracy                           0.41        32
#    macro avg       0.41      0.41      0.41        32
# weighted avg       0.41      0.41      0.41        32
#
#
# Test set: Total loss: 0.702981, Accuracy: 0.520000
# Epoch: 19
# 	Average loss: 0.667923
# 	Accuracy: 0.560000
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.41      0.58        22
#          1.0       0.43      1.00      0.61        10
#
#     accuracy                           0.59        32
#    macro avg       0.72      0.70      0.59        32
# weighted avg       0.82      0.59      0.59        32
#
#
# Test set: Total loss: 0.695158, Accuracy: 0.520000
# Epoch: 20
# 	Average loss: 0.688005
# 	Accuracy: 0.560000
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.50      0.57        16
#          1.0       0.60      0.75      0.67        16
#
#     accuracy                           0.62        32
#    macro avg       0.63      0.62      0.62        32
# weighted avg       0.63      0.62      0.62        32
#
#
# Test set: Total loss: 0.696645, Accuracy: 0.520000
# Epoch: 21
# 	Average loss: 0.687547
# 	Accuracy: 0.550000
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.65      0.67        17
#          1.0       0.62      0.67      0.65        15
#
#     accuracy                           0.66        32
#    macro avg       0.66      0.66      0.66        32
# weighted avg       0.66      0.66      0.66        32
#
#
# Test set: Total loss: 0.697384, Accuracy: 0.520000
# Epoch: 22
# 	Average loss: 0.774439
# 	Accuracy: 0.380000
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.33      0.36        18
#          1.0       0.29      0.36      0.32        14
#
#     accuracy                           0.34        32
#    macro avg       0.35      0.35      0.34        32
# weighted avg       0.35      0.34      0.35        32
#
#
# Test set: Total loss: 0.696876, Accuracy: 0.520000
# Epoch: 23
# 	Average loss: 0.684665
# 	Accuracy: 0.550000
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.79      0.67        14
#          1.0       0.77      0.56      0.65        18
#
#     accuracy                           0.66        32
#    macro avg       0.67      0.67      0.66        32
# weighted avg       0.69      0.66      0.65        32
#
#
# Test set: Total loss: 0.696496, Accuracy: 0.520000
# Epoch: 24
# 	Average loss: 0.683130
# 	Accuracy: 0.560000
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.64      0.60        14
#          1.0       0.69      0.61      0.65        18
#
#     accuracy                           0.62        32
#    macro avg       0.62      0.63      0.62        32
# weighted avg       0.63      0.62      0.63        32
#
#
# Test set: Total loss: 0.695065, Accuracy: 0.520000
# Epoch: 25
# 	Average loss: 0.711941
# 	Accuracy: 0.470000
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.65      0.59        17
#          1.0       0.50      0.40      0.44        15
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.52      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Test set: Total loss: 0.695992, Accuracy: 0.440000
# Epoch: 26
# 	Average loss: 0.712096
# 	Accuracy: 0.440000
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.38      0.37        13
#          1.0       0.56      0.53      0.54        19
#
#     accuracy                           0.47        32
#    macro avg       0.46      0.46      0.46        32
# weighted avg       0.47      0.47      0.47        32
#
#
# Test set: Total loss: 0.698211, Accuracy: 0.480000
# Epoch: 27
# 	Average loss: 0.683671
# 	Accuracy: 0.510000
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.50      0.52        14
#          1.0       0.63      0.67      0.65        18
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.58      0.58        32
# weighted avg       0.59      0.59      0.59        32
#
#
# Test set: Total loss: 0.701759, Accuracy: 0.480000
# Epoch: 28
# 	Average loss: 0.722934
# 	Accuracy: 0.450000
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.29      0.36        17
#          1.0       0.43      0.60      0.50        15
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.45      0.43        32
# weighted avg       0.44      0.44      0.42        32
#
#
# Test set: Total loss: 0.702006, Accuracy: 0.480000
# Epoch: 29
# 	Average loss: 0.743493
# 	Accuracy: 0.400000
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.21      0.26        14
#          1.0       0.52      0.67      0.59        18
#
#     accuracy                           0.47        32
#    macro avg       0.43      0.44      0.42        32
# weighted avg       0.44      0.47      0.44        32
#
#
# Test set: Total loss: 0.699518, Accuracy: 0.480000
# Epoch: 30
# 	Average loss: 0.746977
# 	Accuracy: 0.360000
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.40      0.40        15
#          1.0       0.47      0.47      0.47        17
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.695911, Accuracy: 0.440000
# Epoch: 31
# 	Average loss: 0.697855
# 	Accuracy: 0.490000
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.38      0.46        16
#          1.0       0.55      0.75      0.63        16
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.56      0.55        32
# weighted avg       0.57      0.56      0.55        32
#
#
# Test set: Total loss: 0.695004, Accuracy: 0.520000
# Epoch: 32
# 	Average loss: 0.676247
# 	Accuracy: 0.600000
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.47      0.52        15
#          1.0       0.60      0.71      0.65        17
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.58        32
# weighted avg       0.59      0.59      0.59        32
#
#
# Test set: Total loss: 0.696357, Accuracy: 0.520000
# Epoch: 33
# 	Average loss: 0.701545
# 	Accuracy: 0.530000
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.67      0.62        15
#          1.0       0.67      0.59      0.62        17
#
#     accuracy                           0.62        32
#    macro avg       0.63      0.63      0.62        32
# weighted avg       0.63      0.62      0.62        32
#
#
# Test set: Total loss: 0.698740, Accuracy: 0.480000
# Epoch: 34
# 	Average loss: 0.735000
# 	Accuracy: 0.510000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        15
#          1.0       0.57      0.47      0.52        17
#
#     accuracy                           0.53        32
#    macro avg       0.54      0.54      0.53        32
# weighted avg       0.54      0.53      0.53        32
#
#
# Test set: Total loss: 0.709344, Accuracy: 0.480000
# Epoch: 35
# 	Average loss: 0.694079
# 	Accuracy: 0.530000
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.19      0.26        16
#          1.0       0.48      0.75      0.59        16
#
#     accuracy                           0.47        32
#    macro avg       0.45      0.47      0.42        32
# weighted avg       0.45      0.47      0.42        32
#
#
# Test set: Total loss: 0.710528, Accuracy: 0.480000
# Epoch: 36
# 	Average loss: 0.701373
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.50      0.52        14
#          1.0       0.63      0.67      0.65        18
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.58      0.58        32
# weighted avg       0.59      0.59      0.59        32
#
#
# Test set: Total loss: 0.699894, Accuracy: 0.480000
# Epoch: 37
# 	Average loss: 0.714268
# 	Accuracy: 0.480000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.35      0.41        17
#          1.0       0.45      0.60      0.51        15
#
#     accuracy                           0.47        32
#    macro avg       0.47      0.48      0.46        32
# weighted avg       0.48      0.47      0.46        32
#
#
# Test set: Total loss: 0.703729, Accuracy: 0.480000
# Epoch: 38
# 	Average loss: 0.700200
# 	Accuracy: 0.490000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        15
#          1.0       0.57      0.47      0.52        17
#
#     accuracy                           0.53        32
#    macro avg       0.54      0.54      0.53        32
# weighted avg       0.54      0.53      0.53        32
#
#
# Test set: Total loss: 0.696919, Accuracy: 0.480000
# Epoch: 39
# 	Average loss: 0.708312
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.57      0.50        14
#          1.0       0.57      0.44      0.50        18
#
#     accuracy                           0.50        32
#    macro avg       0.51      0.51      0.50        32
# weighted avg       0.52      0.50      0.50        32
#
#
# Test set: Total loss: 0.696858, Accuracy: 0.480000
# Epoch: 40
# 	Average loss: 0.716425
# 	Accuracy: 0.520000
#               precision    recall  f1-score   support
#
#          0.0       0.11      0.08      0.09        13
#          1.0       0.48      0.58      0.52        19
#
#     accuracy                           0.38        32
#    macro avg       0.29      0.33      0.31        32
# weighted avg       0.33      0.38      0.35        32
#
#
# Test set: Total loss: 0.724121, Accuracy: 0.480000
# Epoch: 41
# 	Average loss: 0.685495
# 	Accuracy: 0.570000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.46      0.57        13
#          1.0       0.71      0.89      0.79        19
#
#     accuracy                           0.72        32
#    macro avg       0.73      0.68      0.68        32
# weighted avg       0.73      0.72      0.70        32
#
#
# Test set: Total loss: 0.712519, Accuracy: 0.480000
# Epoch: 42
# 	Average loss: 0.728805
# 	Accuracy: 0.430000
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.33      0.38        15
#          1.0       0.52      0.65      0.58        17
#
#     accuracy                           0.50        32
#    macro avg       0.49      0.49      0.48        32
# weighted avg       0.49      0.50      0.49        32
#
#
# Test set: Total loss: 0.725957, Accuracy: 0.480000
# Epoch: 43
# 	Average loss: 0.669470
# 	Accuracy: 0.510000
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.67      0.62        15
#          1.0       0.67      0.59      0.62        17
#
#     accuracy                           0.62        32
#    macro avg       0.63      0.63      0.62        32
# weighted avg       0.63      0.62      0.62        32
#
#
# Test set: Total loss: 0.716952, Accuracy: 0.480000
# Epoch: 44
# 	Average loss: 0.664970
# 	Accuracy: 0.600000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.58      0.65        19
#          1.0       0.53      0.69      0.60        13
#
#     accuracy                           0.62        32
#    macro avg       0.63      0.64      0.62        32
# weighted avg       0.65      0.62      0.63        32
#
#
# Test set: Total loss: 0.712397, Accuracy: 0.480000
# Epoch: 45
# 	Average loss: 0.690832
# 	Accuracy: 0.460000
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.42      0.47        19
#          1.0       0.35      0.46      0.40        13
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.46      0.44      0.44        32
#
#
# Test set: Total loss: 0.721682, Accuracy: 0.480000
# Epoch: 46
# 	Average loss: 0.702714
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.42      0.47        19
#          1.0       0.35      0.46      0.40        13
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.46      0.44      0.44        32
#
#
# Test set: Total loss: 0.700052, Accuracy: 0.440000
# Epoch: 47
# 	Average loss: 0.718306
# 	Accuracy: 0.450000
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.53      0.55        17
#          1.0       0.50      0.53      0.52        15
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Test set: Total loss: 0.701248, Accuracy: 0.520000
# Epoch: 48
# 	Average loss: 0.721853
# 	Accuracy: 0.450000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.38      0.43        16
#          1.0       0.50      0.62      0.56        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.49        32
# weighted avg       0.50      0.50      0.49        32
#
#
# Test set: Total loss: 0.700855, Accuracy: 0.520000
# Epoch: 49
# 	Average loss: 0.701611
# 	Accuracy: 0.480000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.31      0.38        16
#          1.0       0.50      0.69      0.58        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.48        32
# weighted avg       0.50      0.50      0.48        32
#
#
# Test set: Total loss: 0.698243, Accuracy: 0.480000
# Epoch: 50
# 	Average loss: 0.704849
# 	Accuracy: 0.460000
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.13      0.21        23
#          1.0       0.26      0.78      0.39         9
#
#     accuracy                           0.31        32
#    macro avg       0.43      0.45      0.30        32
# weighted avg       0.50      0.31      0.26        32
#
#
# Test set: Total loss: 0.706202, Accuracy: 0.520000
# Epoch: 51
# 	Average loss: 0.682100
# 	Accuracy: 0.580000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.56      0.53        16
#          1.0       0.50      0.44      0.47        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Test set: Total loss: 0.972509, Accuracy: 0.520000
# Epoch: 52
# 	Average loss: 0.712950
# 	Accuracy: 0.510000
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.75      0.62        16
#          1.0       0.56      0.31      0.40        16
#
#     accuracy                           0.53        32
#    macro avg       0.54      0.53      0.51        32
# weighted avg       0.54      0.53      0.51        32
#
#
# Test set: Total loss: 0.824873, Accuracy: 0.520000
# Epoch: 53
# 	Average loss: 0.721632
# 	Accuracy: 0.490000
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.40      0.39        15
#          1.0       0.44      0.41      0.42        17
#
#     accuracy                           0.41        32
#    macro avg       0.41      0.41      0.41        32
# weighted avg       0.41      0.41      0.41        32
#
#
# Test set: Total loss: 0.710663, Accuracy: 0.520000
# Epoch: 54
# 	Average loss: 0.697685
# 	Accuracy: 0.490000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.19      0.27        16
#          1.0       0.50      0.81      0.62        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.45        32
# weighted avg       0.50      0.50      0.45        32
#
#
# Test set: Total loss: 0.693667, Accuracy: 0.520000
# Epoch: 55
# 	Average loss: 0.701774
# 	Accuracy: 0.520000
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.29      0.38        14
#          1.0       0.60      0.83      0.70        18
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.56      0.54        32
# weighted avg       0.59      0.59      0.56        32
#
#
# Test set: Total loss: 0.694267, Accuracy: 0.520000
# Epoch: 56
# 	Average loss: 0.680854
# 	Accuracy: 0.530000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.47      0.57        17
#          1.0       0.57      0.80      0.67        15
#
#     accuracy                           0.62        32
#    macro avg       0.65      0.64      0.62        32
# weighted avg       0.65      0.62      0.62        32
#
#
# Test set: Total loss: 0.707140, Accuracy: 0.520000
# Epoch: 57
# 	Average loss: 0.703672
# 	Accuracy: 0.480000
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.64      0.49        14
#          1.0       0.44      0.22      0.30        18
#
#     accuracy                           0.41        32
#    macro avg       0.42      0.43      0.39        32
# weighted avg       0.42      0.41      0.38        32
#
#
# Test set: Total loss: 0.722638, Accuracy: 0.520000
# Epoch: 58
# 	Average loss: 0.696422
# 	Accuracy: 0.450000
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.79      0.58        14
#          1.0       0.62      0.28      0.38        18
#
#     accuracy                           0.50        32
#    macro avg       0.54      0.53      0.48        32
# weighted avg       0.55      0.50      0.47        32
#
#
# Test set: Total loss: 0.693240, Accuracy: 0.520000
# Epoch: 59
# 	Average loss: 0.700175
# 	Accuracy: 0.480000
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.38      0.40        16
#          1.0       0.44      0.50      0.47        16
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.702258, Accuracy: 0.480000
# Epoch: 60
# 	Average loss: 0.665432
# 	Accuracy: 0.580000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.46      0.48        13
#          1.0       0.65      0.68      0.67        19
#
#     accuracy                           0.59        32
#    macro avg       0.57      0.57      0.57        32
# weighted avg       0.59      0.59      0.59        32
#
#
# Test set: Total loss: 0.713134, Accuracy: 0.480000
# Epoch: 61
# 	Average loss: 0.694428
# 	Accuracy: 0.480000
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.67      0.56        15
#          1.0       0.55      0.35      0.43        17
#
#     accuracy                           0.50        32
#    macro avg       0.51      0.51      0.49        32
# weighted avg       0.51      0.50      0.49        32
#
#
# Test set: Total loss: 0.714613, Accuracy: 0.480000
# Epoch: 62
# 	Average loss: 0.699469
# 	Accuracy: 0.540000
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.57      0.50        14
#          1.0       0.57      0.44      0.50        18
#
#     accuracy                           0.50        32
#    macro avg       0.51      0.51      0.50        32
# weighted avg       0.52      0.50      0.50        32
#
#
# Test set: Total loss: 0.703715, Accuracy: 0.480000
# Epoch: 63
# 	Average loss: 0.688660
# 	Accuracy: 0.530000
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.29      0.40        21
#          1.0       0.35      0.73      0.47        11
#
#     accuracy                           0.44        32
#    macro avg       0.51      0.51      0.44        32
# weighted avg       0.56      0.44      0.42        32
#
#
# Test set: Total loss: 0.723479, Accuracy: 0.480000
# Epoch: 64
# 	Average loss: 0.722969
# 	Accuracy: 0.480000
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.20      0.26        15
#          1.0       0.50      0.71      0.59        17
#
#     accuracy                           0.47        32
#    macro avg       0.44      0.45      0.42        32
# weighted avg       0.44      0.47      0.43        32
#
#
# Test set: Total loss: 0.699529, Accuracy: 0.480000
# Epoch: 65
# 	Average loss: 0.708535
# 	Accuracy: 0.480000
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.73      0.61        15
#          1.0       0.64      0.41      0.50        17
#
#     accuracy                           0.56        32
#    macro avg       0.58      0.57      0.56        32
# weighted avg       0.58      0.56      0.55        32
#
#
# Test set: Total loss: 0.697047, Accuracy: 0.520000
# Epoch: 66
# 	Average loss: 0.741762
# 	Accuracy: 0.400000
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.25      0.32        20
#          1.0       0.29      0.50      0.36        12
#
#     accuracy                           0.34        32
#    macro avg       0.37      0.38      0.34        32
# weighted avg       0.39      0.34      0.34        32
#
#
# Test set: Total loss: 0.697203, Accuracy: 0.400000
# Epoch: 67
# 	Average loss: 0.691283
# 	Accuracy: 0.470000
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.44      0.48        16
#          1.0       0.53      0.62      0.57        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Test set: Total loss: 0.698181, Accuracy: 0.560000
# Epoch: 68
# 	Average loss: 0.718746
# 	Accuracy: 0.450000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.29      0.37        17
#          1.0       0.45      0.67      0.54        15
#
#     accuracy                           0.47        32
#    macro avg       0.48      0.48      0.46        32
# weighted avg       0.48      0.47      0.45        32
#
#
# Test set: Total loss: 0.700208, Accuracy: 0.440000
# Epoch: 69
# 	Average loss: 0.670727
# 	Accuracy: 0.540000
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.31      0.40        16
#          1.0       0.52      0.75      0.62        16
#
#     accuracy                           0.53        32
#    macro avg       0.54      0.53      0.51        32
# weighted avg       0.54      0.53      0.51        32
#
#
# Test set: Total loss: 0.700833, Accuracy: 0.440000
# Epoch: 70
# 	Average loss: 0.711543
# 	Accuracy: 0.480000
#               precision    recall  f1-score   support
#
#          0.0       0.31      0.33      0.32        15
#          1.0       0.38      0.35      0.36        17
#
#     accuracy                           0.34        32
#    macro avg       0.34      0.34      0.34        32
# weighted avg       0.35      0.34      0.34        32
#
#
# Test set: Total loss: 0.700597, Accuracy: 0.520000
# Epoch: 71
# 	Average loss: 0.701175
# 	Accuracy: 0.560000
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.53      0.55        17
#          1.0       0.50      0.53      0.52        15
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Test set: Total loss: 0.700612, Accuracy: 0.520000
# Epoch: 72
# 	Average loss: 0.686525
# 	Accuracy: 0.590000
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.47      0.53        17
#          1.0       0.53      0.67      0.59        15
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.57      0.56        32
# weighted avg       0.57      0.56      0.56        32
#
#
# Test set: Total loss: 0.699371, Accuracy: 0.560000
# Epoch: 73
# 	Average loss: 0.704445
# 	Accuracy: 0.460000
#               precision    recall  f1-score   support
#
#          0.0       0.37      0.54      0.44        13
#          1.0       0.54      0.37      0.44        19
#
#     accuracy                           0.44        32
#    macro avg       0.45      0.45      0.44        32
# weighted avg       0.47      0.44      0.44        32
#
#
# Test set: Total loss: 0.698065, Accuracy: 0.520000
# Epoch: 74
# 	Average loss: 0.704173
# 	Accuracy: 0.480000
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.47      0.47        15
#          1.0       0.53      0.53      0.53        17
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Test set: Total loss: 0.702047, Accuracy: 0.480000
# Epoch: 75
# 	Average loss: 0.702600
# 	Accuracy: 0.540000
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.31      0.43        16
#          1.0       0.56      0.88      0.68        16
#
#     accuracy                           0.59        32
#    macro avg       0.64      0.59      0.56        32
# weighted avg       0.64      0.59      0.56        32
#
#
# Test set: Total loss: 0.705769, Accuracy: 0.480000
# Epoch: 76
# 	Average loss: 0.718802
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.27      0.25      0.26        12
#          1.0       0.57      0.60      0.59        20
#
#     accuracy                           0.47        32
#    macro avg       0.42      0.42      0.42        32
# weighted avg       0.46      0.47      0.46        32
#
#
# Test set: Total loss: 0.698488, Accuracy: 0.440000
# Epoch: 77
# 	Average loss: 0.710938
# 	Accuracy: 0.430000
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.44      0.44        16
#          1.0       0.44      0.44      0.44        16
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.701307, Accuracy: 0.400000
# Epoch: 78
# 	Average loss: 0.700440
# 	Accuracy: 0.510000
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.56      0.56        16
#          1.0       0.56      0.56      0.56        16
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.56      0.56      0.56        32
#
#
# Test set: Total loss: 0.705643, Accuracy: 0.480000
# Epoch: 79
# 	Average loss: 0.690842
# 	Accuracy: 0.520000
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.54      0.41        13
#          1.0       0.45      0.26      0.33        19
#
#     accuracy                           0.38        32
#    macro avg       0.39      0.40      0.37        32
# weighted avg       0.41      0.38      0.37        32
#
#
# Test set: Total loss: 0.711665, Accuracy: 0.480000
# Epoch: 80
# 	Average loss: 0.673023
# 	Accuracy: 0.530000
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.37      0.52        19
#          1.0       0.50      0.92      0.65        13
#
#     accuracy                           0.59        32
#    macro avg       0.69      0.65      0.58        32
# weighted avg       0.72      0.59      0.57        32
#
#
# Test set: Total loss: 0.748511, Accuracy: 0.480000
# Epoch: 81
# 	Average loss: 0.655221
# 	Accuracy: 0.560000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.47      0.57        17
#          1.0       0.57      0.80      0.67        15
#
#     accuracy                           0.62        32
#    macro avg       0.65      0.64      0.62        32
# weighted avg       0.65      0.62      0.62        32
#
#
# Test set: Total loss: 0.771744, Accuracy: 0.480000
# Epoch: 82
# 	Average loss: 0.695450
# 	Accuracy: 0.540000
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.36      0.43        14
#          1.0       0.61      0.78      0.68        18
#
#     accuracy                           0.59        32
#    macro avg       0.58      0.57      0.56        32
# weighted avg       0.59      0.59      0.57        32
#
#
# Test set: Total loss: 0.792619, Accuracy: 0.480000
# Epoch: 83
# 	Average loss: 0.714298
# 	Accuracy: 0.510000
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.53      0.53        17
#          1.0       0.47      0.47      0.47        15
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Test set: Total loss: 0.820198, Accuracy: 0.480000
# Epoch: 84
# 	Average loss: 0.661435
# 	Accuracy: 0.600000
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.75      0.71        16
#          1.0       0.71      0.62      0.67        16
#
#     accuracy                           0.69        32
#    macro avg       0.69      0.69      0.69        32
# weighted avg       0.69      0.69      0.69        32
#
#
# Test set: Total loss: 0.802416, Accuracy: 0.480000
# Epoch: 85
# 	Average loss: 0.717371
# 	Accuracy: 0.430000
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.29      0.33        17
#          1.0       0.37      0.47      0.41        15
#
#     accuracy                           0.38        32
#    macro avg       0.38      0.38      0.37        32
# weighted avg       0.38      0.38      0.37        32
#
#
# Test set: Total loss: 0.758642, Accuracy: 0.480000
# Epoch: 86
# 	Average loss: 0.686223
# 	Accuracy: 0.520000
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.46      0.43        13
#          1.0       0.59      0.53      0.56        19
#
#     accuracy                           0.50        32
#    macro avg       0.49      0.49      0.49        32
# weighted avg       0.51      0.50      0.50        32
#
#
# Test set: Total loss: 0.702603, Accuracy: 0.480000
# Epoch: 87
# 	Average loss: 0.678377
# 	Accuracy: 0.580000
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.94      0.70        16
#          1.0       0.80      0.25      0.38        16
#
#     accuracy                           0.59        32
#    macro avg       0.68      0.59      0.54        32
# weighted avg       0.68      0.59      0.54        32
#
#
# Test set: Total loss: 0.698930, Accuracy: 0.360000
# Epoch: 88
# 	Average loss: 0.728926
# 	Accuracy: 0.390000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.14      0.22        21
#          1.0       0.31      0.73      0.43        11
#
#     accuracy                           0.34        32
#    macro avg       0.40      0.44      0.33        32
# weighted avg       0.43      0.34      0.29        32
#
#
# Test set: Total loss: 0.702307, Accuracy: 0.480000
# Epoch: 89
# 	Average loss: 0.689521
# 	Accuracy: 0.520000
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.33      0.36        15
#          1.0       0.47      0.53      0.50        17
#
#     accuracy                           0.44        32
#    macro avg       0.43      0.43      0.43        32
# weighted avg       0.43      0.44      0.43        32
#
#
# Test set: Total loss: 0.697896, Accuracy: 0.480000
# Epoch: 90
# 	Average loss: 0.716732
# 	Accuracy: 0.480000
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.50      0.47        14
#          1.0       0.56      0.50      0.53        18
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.51      0.50      0.50        32
#
#
# Test set: Total loss: 0.699109, Accuracy: 0.520000
# Epoch: 91
# 	Average loss: 0.687598
# 	Accuracy: 0.550000
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.64      0.60        14
#          1.0       0.69      0.61      0.65        18
#
#     accuracy                           0.62        32
#    macro avg       0.62      0.63      0.62        32
# weighted avg       0.63      0.62      0.63        32
#
#
# Test set: Total loss: 0.697856, Accuracy: 0.520000
# Epoch: 92
# 	Average loss: 0.715081
# 	Accuracy: 0.470000
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.44      0.48        16
#          1.0       0.53      0.62      0.57        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Test set: Total loss: 0.697694, Accuracy: 0.520000
# Epoch: 93
# 	Average loss: 0.679516
# 	Accuracy: 0.520000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50        14
#          1.0       0.61      0.61      0.61        18
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.56      0.56      0.56        32
#
#
# Test set: Total loss: 0.710750, Accuracy: 0.520000
# Epoch: 94
# 	Average loss: 0.703507
# 	Accuracy: 0.460000
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.71      0.54        14
#          1.0       0.56      0.28      0.37        18
#
#     accuracy                           0.47        32
#    macro avg       0.50      0.50      0.46        32
# weighted avg       0.50      0.47      0.44        32
#
#
# Test set: Total loss: 0.706528, Accuracy: 0.520000
# Epoch: 95
# 	Average loss: 0.731372
# 	Accuracy: 0.440000
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.46      0.43        13
#          1.0       0.59      0.53      0.56        19
#
#     accuracy                           0.50        32
#    macro avg       0.49      0.49      0.49        32
# weighted avg       0.51      0.50      0.50        32
#
#
# Test set: Total loss: 0.697461, Accuracy: 0.440000
# Epoch: 96
# 	Average loss: 0.701120
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.33      0.36        15
#          1.0       0.47      0.53      0.50        17
#
#     accuracy                           0.44        32
#    macro avg       0.43      0.43      0.43        32
# weighted avg       0.43      0.44      0.43        32
#
#
# Test set: Total loss: 0.708849, Accuracy: 0.480000
# Epoch: 97
# 	Average loss: 0.731441
# 	Accuracy: 0.510000
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.40      0.55        20
#          1.0       0.48      0.92      0.63        12
#
#     accuracy                           0.59        32
#    macro avg       0.68      0.66      0.59        32
# weighted avg       0.73      0.59      0.58        32
#
#
# Test set: Total loss: 0.797856, Accuracy: 0.480000
# Epoch: 98
# 	Average loss: 0.693403
# 	Accuracy: 0.530000
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.38      0.48        16
#          1.0       0.57      0.81      0.67        16
#
#     accuracy                           0.59        32
#    macro avg       0.62      0.59      0.57        32
# weighted avg       0.62      0.59      0.57        32
#
#
# Test set: Total loss: 0.817770, Accuracy: 0.480000
# Epoch: 99
# 	Average loss: 0.696863
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.91      0.54        11
#          1.0       0.83      0.24      0.37        21
#
#     accuracy                           0.47        32
#    macro avg       0.61      0.57      0.46        32
# weighted avg       0.68      0.47      0.43        32
#
#
# Test set: Total loss: 0.739690, Accuracy: 0.480000
# Epoch: 100
# 	Average loss: 0.710019
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.75      0.46        12
#          1.0       0.40      0.10      0.16        20
#
#     accuracy                           0.34        32
#    macro avg       0.37      0.42      0.31        32
# weighted avg       0.38      0.34      0.27        32
#
#
# Test set: Total loss: 0.775314, Accuracy: 0.480000
# Epoch: 101
# 	Average loss: 0.716624
# 	Accuracy: 0.420000
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.24      0.28        17
#          1.0       0.35      0.47      0.40        15
#
#     accuracy                           0.34        32
#    macro avg       0.34      0.35      0.34        32
# weighted avg       0.34      0.34      0.33        32
#
#
# Test set: Total loss: 0.965842, Accuracy: 0.480000
# Epoch: 102
# 	Average loss: 0.710175
# 	Accuracy: 0.440000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.18      0.26        17
#          1.0       0.46      0.80      0.59        15
#
#     accuracy                           0.47        32
#    macro avg       0.48      0.49      0.42        32
# weighted avg       0.48      0.47      0.41        32
#
#
# Test set: Total loss: 1.045886, Accuracy: 0.480000
# Epoch: 103
# 	Average loss: 0.690470
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.17      0.27        18
#          1.0       0.46      0.93      0.62        14
#
#     accuracy                           0.50        32
#    macro avg       0.61      0.55      0.45        32
# weighted avg       0.62      0.50      0.42        32
#
#
# Test set: Total loss: 0.904018, Accuracy: 0.480000
# Epoch: 104
# 	Average loss: 0.668878
# 	Accuracy: 0.620000
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.56      0.62        16
#          1.0       0.63      0.75      0.69        16
#
#     accuracy                           0.66        32
#    macro avg       0.66      0.66      0.65        32
# weighted avg       0.66      0.66      0.65        32
#
#
# Test set: Total loss: 0.784827, Accuracy: 0.480000
# Epoch: 105
# 	Average loss: 0.701540
# 	Accuracy: 0.470000
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.56      0.47        16
#          1.0       0.30      0.19      0.23        16
#
#     accuracy                           0.38        32
#    macro avg       0.35      0.38      0.35        32
# weighted avg       0.35      0.38      0.35        32
#
#
# Test set: Total loss: 0.734637, Accuracy: 0.480000
# Epoch: 106
# 	Average loss: 0.707819
# 	Accuracy: 0.470000
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.67      0.54        15
#          1.0       0.50      0.29      0.37        17
#
#     accuracy                           0.47        32
#    macro avg       0.48      0.48      0.46        32
# weighted avg       0.48      0.47      0.45        32
#
#
# Test set: Total loss: 0.727984, Accuracy: 0.480000
# Epoch: 107
# 	Average loss: 0.688995
# 	Accuracy: 0.510000
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.59      0.62        17
#          1.0       0.59      0.67      0.62        15
#
#     accuracy                           0.62        32
#    macro avg       0.63      0.63      0.62        32
# weighted avg       0.63      0.62      0.62        32
#
#
# Test set: Total loss: 0.745243, Accuracy: 0.480000
# Epoch: 108
# 	Average loss: 0.693453
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.30      0.20      0.24        15
#          1.0       0.45      0.59      0.51        17
#
#     accuracy                           0.41        32
#    macro avg       0.38      0.39      0.38        32
# weighted avg       0.38      0.41      0.38        32
#
#
# Test set: Total loss: 0.727333, Accuracy: 0.480000
# Epoch: 109
# 	Average loss: 0.695945
# 	Accuracy: 0.560000
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.47      0.59        17
#          1.0       0.59      0.87      0.70        15
#
#     accuracy                           0.66        32
#    macro avg       0.70      0.67      0.65        32
# weighted avg       0.70      0.66      0.64        32
#
#
# Test set: Total loss: 0.701232, Accuracy: 0.480000
# Epoch: 110
# 	Average loss: 0.672994
# 	Accuracy: 0.570000
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.69      0.63        16
#          1.0       0.62      0.50      0.55        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Test set: Total loss: 0.701184, Accuracy: 0.520000
# Epoch: 111
# 	Average loss: 0.711907
# 	Accuracy: 0.460000
#               precision    recall  f1-score   support
#
#          0.0       0.37      0.54      0.44        13
#          1.0       0.54      0.37      0.44        19
#
#     accuracy                           0.44        32
#    macro avg       0.45      0.45      0.44        32
# weighted avg       0.47      0.44      0.44        32
#
#
# Test set: Total loss: 0.709852, Accuracy: 0.520000
# Epoch: 112
# 	Average loss: 0.716086
# 	Accuracy: 0.390000
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.47      0.39        15
#          1.0       0.27      0.18      0.21        17
#
#     accuracy                           0.31        32
#    macro avg       0.30      0.32      0.30        32
# weighted avg       0.30      0.31      0.30        32
#
#
# Test set: Total loss: 0.701856, Accuracy: 0.520000
# Epoch: 113
# 	Average loss: 0.721666
# 	Accuracy: 0.480000
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.26      0.40        19
#          1.0       0.46      0.92      0.62        13
#
#     accuracy                           0.53        32
#    macro avg       0.65      0.59      0.51        32
# weighted avg       0.68      0.53      0.49        32
#
#
# Test set: Total loss: 0.704832, Accuracy: 0.480000
# Epoch: 114
# 	Average loss: 0.693294
# 	Accuracy: 0.470000
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.23      0.27        13
#          1.0       0.57      0.68      0.62        19
#
#     accuracy                           0.50        32
#    macro avg       0.45      0.46      0.45        32
# weighted avg       0.47      0.50      0.48        32
#
#
# Test set: Total loss: 0.704781, Accuracy: 0.480000
# Epoch: 115
# 	Average loss: 0.691887
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.50      0.48        12
#          1.0       0.68      0.65      0.67        20
#
#     accuracy                           0.59        32
#    macro avg       0.57      0.57      0.57        32
# weighted avg       0.60      0.59      0.60        32
#
#
# Test set: Total loss: 0.700804, Accuracy: 0.440000
# Epoch: 116
# 	Average loss: 0.707711
# 	Accuracy: 0.460000
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.40      0.39        15
#          1.0       0.44      0.41      0.42        17
#
#     accuracy                           0.41        32
#    macro avg       0.41      0.41      0.41        32
# weighted avg       0.41      0.41      0.41        32
#
#
# Test set: Total loss: 0.700484, Accuracy: 0.440000
# Epoch: 117
# 	Average loss: 0.683395
# 	Accuracy: 0.540000
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.87      0.70        15
#          1.0       0.80      0.47      0.59        17
#
#     accuracy                           0.66        32
#    macro avg       0.70      0.67      0.65        32
# weighted avg       0.70      0.66      0.64        32
#
#
# Test set: Total loss: 0.701769, Accuracy: 0.560000
# Epoch: 118
# 	Average loss: 0.695076
# 	Accuracy: 0.480000
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.56      0.60        16
#          1.0       0.61      0.69      0.65        16
#
#     accuracy                           0.62        32
#    macro avg       0.63      0.62      0.62        32
# weighted avg       0.63      0.62      0.62        32
#
#
# Test set: Total loss: 0.701547, Accuracy: 0.360000
# Epoch: 119
# 	Average loss: 0.686638
# 	Accuracy: 0.530000
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.28      0.42        18
#          1.0       0.50      0.93      0.65        14
#
#     accuracy                           0.56        32
#    macro avg       0.67      0.60      0.53        32
# weighted avg       0.69      0.56      0.52        32
#
#
# Test set: Total loss: 0.701319, Accuracy: 0.480000

# %%
conv1 = list(CNNPoor.children())
print(conv1[1].weight.shape)
weight1 = conv1[1].weight.reshape((4,125)).data.numpy()
#weight2 = conv1[4].weight.reshape((16,7)).data.numpy()
# weight3 = conv1[9].weight.reshape((32,32)).data.numpy()
#weight4 = conv1[10].weight.reshape((16,32)).data.numpy()
# weight5 = conv1[16].weight.reshape((1,176)).data.numpy()
pyplot.figure(figsize=(20,10))
pyplot.imshow(weight1)

#pyplot.imshow(weight2)
#pyplot.imshow(weight3)
#pyplot.imshow(weight4)
# pyplot.imshow(weight5)
# Out:
# torch.Size([4, 1, 1, 125])

# %%
pyplot.plot(plots["train acc"], "royalblue", label = "train")
pyplot.plot(plots["test acc"], "darkorange", label = "test")
pyplot.title("accuracy over training")
pyplot.legend()
pyplot.show()

# %%
# tload = torch.utils.data.TensorDataset(X_train, X_actual)
# tloader = torch.utils.data.DataLoader(tload, batch_size = X_train.shape[0], shuffle = True)
# _, _, _, _ = test(CNNPoor, device, tloader)
_, _, _, _ = test(CNNPoor, device, test_loader)
# Out:
# Test set: Total loss: 0.701319, Accuracy: 0.480000

# %%
# torch.save(CNNPoor.state_dict(), '/content/drive/Shared drives/NeuroTech ML/my_model.pt')

# %%
# import pickle

# pickle.dump(CNNPoor, open('model.pkl', 'wb'))
# # model = pickle.load(open('model.pkl', 'rb'))
