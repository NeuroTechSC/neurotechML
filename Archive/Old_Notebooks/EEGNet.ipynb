# %% [markdown]
# # Loose EEGNet
# This notebook is a neural network that is based as much off of the EEGNet paper as I could understand.

# %% [markdown]
# ---

# %% [markdown]
# # Import/Install all necessary packages and libraries

# %%
import numpy as np

from sklearn.metrics import roc_auc_score, precision_score, recall_score, accuracy_score, classification_report
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable, gradcheck
from torch.utils.data import TensorDataset, DataLoader

import pandas as pd

from matplotlib import pyplot

import math

from os import walk

# %% [markdown]
# # Check for GPU availability and set device

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %% [markdown]
# # Load and format the data

# %% [markdown]
# Here is a brief rundown of the data:
#
# > Each data segment (chunk) is a two second recording in which a subject subvocalized either "yes" or "no" at any point in the recording
#
# > The data is taken with a sampling frequency of 250hz, so in the end there are 500 timepoints for each chunk
#
# > The hardware we are using has 7 channels
#
# > After all these data cells are run the data is in the shape (# of chunks, 1, # of channels, # of timepoints)

# %%
master_data, master_label = [], []
datafix, labelfix = ".pkl", ".csv"
# paste path below
for (dirpath, dirnames, filenames) in walk('/content/drive/Shared drives/NeuroTech ML/Processed Data Files'):
    new_data = [dirpath + '/' + name for name in filenames if datafix in name]
    master_data.extend(new_data)

    new_labels = [dirpath + '/' + name for name in filenames if labelfix in name]
    master_label.extend(new_labels)
assert len(master_data) == len(master_label)
master_data.sort()
master_label.sort()
for index in range(len(master_data)):
    try: 
        assert master_data[index][:-4] == master_label[index][:-11]
    except:
        print(index)
        print(master_data[index][:-4])
        print(master_label[index][:-11])

# %%
pkllabels = np.zeros((1, 1))
pkldata = np.zeros((1, 7, 500))

for i in range(len(master_data)):

    # To train no ICA data change data type to ICA
    # To train no ICA and weaker filter change data type to Weaker
    # To train unprocessed data change data type to Unprocessed

    data_type = "Personal"

    if data_type in master_data[i]:
        new_data = pd.read_pickle(master_data[i])

        new_labels = pd.read_csv(master_label[i], delimiter=',', header=None)
        if new_labels.shape[0] == 1 and new_labels.shape[1] > new_labels.shape[0]:
            new_labels = new_labels.T
        new_labels = np.array(new_labels)
        new_labels = new_labels.reshape((new_labels.shape[0], 1))

        pkldata = np.concatenate((pkldata, new_data), axis = 0)
        pkllabels = np.concatenate((pkllabels, new_labels), axis = 0)

pkllabels = pkllabels[1:, :]
pkldata = pkldata[1:, :, :]

# %%
# # Uncomment below if u wanna see a bunch of graphs of the data
print(pkldata.shape, pkllabels.shape)
print(pkllabels.shape)
x = pkldata[0]
only_no = [pkldata[i] for i in range(pkldata.shape[0]) if pkllabels[i][0] == 0]
only_no = np.array(only_no)
only_yes = [pkldata[i] for i in range(pkldata.shape[0]) if pkllabels[i][0] == 1]
only_yes = np.array(only_yes)
print(only_no.shape, only_yes.shape)
for i in range(pkldata.shape[1]):
    g = i + 1
    pyplot.plot(only_yes[0:, i, :].T, color="red")
    pyplot.plot(only_no[0:, i, :].T, alpha = .3, color="blue")
    pyplot.title("Value for channel {} over all {} chunks".format(i, pkldata.shape[0]))
    #pyplot.savefig(f"/content/drive/My Drive/Extra/processed_data_Riley_channel_{g}.png")
    pyplot.show()
# Out:
# (278, 7, 500) (278, 1)
# (278, 1)
# (140, 7, 500) (138, 7, 500)

# %%
torch.manual_seed(4)
torch.cuda.manual_seed(4)

# %%
channels = pkldata.shape[1]
timepoints = pkldata.shape[2]
print(channels, timepoints)
# Out:
# 7 500

# %%
BATCH_SIZE = 32

pkllabels = pkllabels.astype(np.float32)
X_actual = torch.from_numpy(pkllabels)

scaler = StandardScaler()
X_train = pkldata
for i in range(len(X_train)):
    X_train[i] = scaler.fit_transform(X_train[i])
X_train = torch.from_numpy(X_train)
X_train = X_train.unsqueeze(1)

# splits the data into a train and dev set, and loads them into dataloaders
train_data, test_data, labels_train, labels_test = train_test_split(X_train, X_actual, test_size=0.3, random_state=4)

trainset = torch.utils.data.TensorDataset(train_data, labels_train)
testset = torch.utils.data.TensorDataset(test_data, labels_test)

train_loader = torch.utils.data.DataLoader(trainset, batch_size = BATCH_SIZE, shuffle = True)
test_loader = torch.utils.data.DataLoader(testset, batch_size = test_data.shape[0], shuffle = True)

print(train_data.shape, test_data.shape)
# Out:
# torch.Size([194, 1, 7, 500]) torch.Size([84, 1, 7, 500])

# %% [markdown]
# # Build the model and train
# A short breakdown of the paper:
# > EEGNet is a CNN for classification and interpretation of EEG-based BCI's
#
# > Benefits of EEGNet:
# > 1. Can be applied to different BCI paradagims (MI, ERP, SSVEP)
# > 2. Can be trained with very limited data
# > 3. Can produce neurophysiologically interpretable features
#
# > The model architecture:
# > 1. Fit 2D convolutional filters of size (1, sampling rate//2)
# > 2. Use a depthwise convolution of size (# of channels, 1)
# > 3. Add a separable convolution of size (1, 16)
# > 4. Flatten the data and feed it through a classification layer

# %%
# hyperparameters
freq, avg1stride, avg2stride = 250, (1, 4), (1, 8)
convstride = 1 # stride for each conv2D
conv1_neurons = 8
conv2_neurons = 16
conv3_neurons = 32
conv4_neurons = 16
kern1size = freq // 2
kern3size = 32

# %%
padding_needed = (kern1size - 1) / 2
conv1outx, conv1outy = (channels, (timepoints + (2 * padding_needed) - kern1size)/convstride + 1)

print("1st layer output size:", conv1outx, conv1outy)

conv2outx, conv2outy = ((conv1outx - channels)/convstride + 1, conv1outy)
conv2outx, conv2outy = conv2outx // avg1stride[0], conv2outy // avg1stride[1]

print("2nd layer output size:", conv2outx, conv2outy)

conv3outx, conv3outy = (conv2outx, (conv2outy - kern3size)/convstride + 1)

print("3rd layer output size:", conv3outx, conv3outy)

conv4outx, conv4outy = (conv3outx, conv3outy)
conv4outx, conv4outy = (conv4outx // avg2stride[0], conv4outy // avg2stride[1])

print("4th layer output size:", conv4outx, conv4outy)

flat1_in = int(conv4outx * conv4outy * conv4_neurons)
# Out:
# 1st layer output size: 7 500.0
# 2nd layer output size: 1.0 125.0
# 3rd layer output size: 1.0 94.0
# 4th layer output size: 1.0 11.0

# %% [markdown]
# Model description, layer by layer
#
# 1. Temporal convolution
# > * - Uses filters of (1, sampling frequency // 2)
# > * - Learns frequency filters at 2Hz and above
# 2. Depthwise convolution
# > * - Learns spatial filters
# 3. Separable Convolution
# > * - Conists of a deptwise convolution followed by a pointwise convolution
# > * - First learnes a kernel summarizing each feature map, then merges the outputs
# 4. Fully connected layer
# > * - Consists of a linear layer that reduces the channels, followed by a sigmoid classification

# %%
class ConstrainedConv2d(nn.Conv2d):
    def forward(self, input):
        return F.conv2d(input, self.weight.clamp(min=-1.0, max=1.0), self.bias, self.stride,
                        self.padding, self.dilation, self.groups)

# %%
CNNPoor = nn.Sequential(
    nn.ZeroPad2d((math.floor(padding_needed), math.ceil(padding_needed), 0, 0)),
    nn.Conv2d(1, conv1_neurons, (1, kern1size), bias=False),
    nn.ELU(),
    nn.BatchNorm2d(conv1_neurons),
    
    ConstrainedConv2d(conv1_neurons, conv2_neurons, (channels, 1), bias=False, groups=conv1_neurons),
    nn.ELU(),
    nn.BatchNorm2d(conv2_neurons),
    nn.MaxPool2d(avg1stride),
    nn.Dropout(),
    
    nn.Conv2d(conv2_neurons, conv3_neurons, (1, kern3size), bias=False, groups=conv2_neurons),
    nn.Conv2d(conv3_neurons, conv4_neurons, kernel_size=1, bias=False),
    nn.ELU(),
    nn.BatchNorm2d(conv4_neurons),
    nn.MaxPool2d(avg2stride),
    nn.Dropout(),
    
    nn.Flatten(),

    nn.Linear(flat1_in, 1),
    nn.Sigmoid(),
)

CNNPoor = CNNPoor.to(device)

# %%
loss_function = nn.BCELoss()
optimizer = optim.Adam(CNNPoor.parameters(), lr = 0.001)

# %%
def test(model, device, test_loader):
    
    model.eval()
    correct = 0
    tot_loss = 0
    acc_score, prec_score, rec_score = 0, 0, 0
    with torch.no_grad():
        for (data, labels) in test_loader:
            data, labels = data.to(device), labels.to(device)
            
            classification = model(data.float())
            loss = loss_function(classification, labels)

            pred = torch.round(classification)
            correct += pred.eq(labels.view_as(pred)).sum().item()
            tot_loss += loss.item()

            acc_score += accuracy_score(labels, pred)
            prec_score += precision_score(labels, pred)
            rec_score += recall_score(labels, pred)

        print("\nTest set: Total loss: {:.6f}, Accuracy: {:.6f}".format(tot_loss, 
                                                                          correct / len(test_loader.dataset)))
        print(classification_report(labels, pred))
        return (tot_loss, acc_score, prec_score, rec_score)

# %%
def train(model, device, train_loader, optimizer, epoch):

    model.train()
    correct = 0
    tot_loss = 0
    for batch, (data, labels) in enumerate(train_loader):
        data, labels = data.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        classification = model(data.float())
        loss = loss_function(classification, labels)

        loss.backward()
        optimizer.step()

        pred = torch.round(classification)
        correct += pred.eq(labels.view_as(pred)).sum().item()
        tot_loss += loss.item()
    print("Epoch: {}".format(epoch))
    print("\tAverage loss: {:.6f}".format(tot_loss / (batch + 1)))
    print("\tAccuracy: {:.6f}".format(correct / len(train_loader.dataset)))

    labels_detached = labels.detach()
    preds_detached = pred.detach()
    print(classification_report(labels_detached, preds_detached))
    return (tot_loss / (batch + 1), correct / len(train_loader.dataset))

# %%
plots = {"train loss": [],
         "train acc": [],
         "test loss": [],
         "test acc": [],
         "test prec": [],
         "test rec": []}

for epoch in range(120):
    trl, tra = train(CNNPoor, device, train_loader, optimizer, epoch)
    plots["train loss"].append(trl)
    plots["train acc"].append(tra)
    tl, ta, tp, tr = test(CNNPoor, device, test_loader)
    plots["test loss"].append(tl)
    plots["test acc"].append(ta)
    plots["test prec"].append(tp)
    plots["test rec"].append(tr)
# Out:
# Epoch: 0
# 	Average loss: 0.687011
# 	Accuracy: 0.608247
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.67         1
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#
# Test set: Total loss: 0.683191, Accuracy: 0.857143
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.74      0.85        46
#          1.0       0.76      1.00      0.86        38
#
#     accuracy                           0.86        84
#    macro avg       0.88      0.87      0.86        84
# weighted avg       0.89      0.86      0.86        84
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 1
# 	Average loss: 0.593038
# 	Accuracy: 0.721649
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.656752, Accuracy: 0.690476
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.43      0.61        46
#          1.0       0.59      1.00      0.75        38
#
#     accuracy                           0.69        84
#    macro avg       0.80      0.72      0.68        84
# weighted avg       0.82      0.69      0.67        84
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 2
# 	Average loss: 0.527040
# 	Accuracy: 0.835052
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.603239, Accuracy: 0.726190
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67        46
#          1.0       0.62      1.00      0.77        38
#
#     accuracy                           0.73        84
#    macro avg       0.81      0.75      0.72        84
# weighted avg       0.83      0.73      0.71        84
#
# Epoch: 3
# 	Average loss: 0.371849
# 	Accuracy: 0.835052
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.532413, Accuracy: 0.773810
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.59      0.74        46
#          1.0       0.67      1.00      0.80        38
#
#     accuracy                           0.77        84
#    macro avg       0.83      0.79      0.77        84
# weighted avg       0.85      0.77      0.77        84
#
# Epoch: 4
# 	Average loss: 0.421254
# 	Accuracy: 0.860825
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67         2
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.478837, Accuracy: 0.690476
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.43      0.61        46
#          1.0       0.59      1.00      0.75        38
#
#     accuracy                           0.69        84
#    macro avg       0.80      0.72      0.68        84
# weighted avg       0.82      0.69      0.67        84
#
# Epoch: 5
# 	Average loss: 0.411488
# 	Accuracy: 0.938144
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.413646, Accuracy: 0.797619
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.63      0.77        46
#          1.0       0.69      1.00      0.82        38
#
#     accuracy                           0.80        84
#    macro avg       0.85      0.82      0.80        84
# weighted avg       0.86      0.80      0.79        84
#
# Epoch: 6
# 	Average loss: 0.216614
# 	Accuracy: 0.932990
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.367264, Accuracy: 0.773810
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.59      0.74        46
#          1.0       0.67      1.00      0.80        38
#
#     accuracy                           0.77        84
#    macro avg       0.83      0.79      0.77        84
# weighted avg       0.85      0.77      0.77        84
#
# Epoch: 7
# 	Average loss: 0.158916
# 	Accuracy: 0.963918
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.258289, Accuracy: 0.976190
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.96      0.98        46
#          1.0       0.95      1.00      0.97        38
#
#     accuracy                           0.98        84
#    macro avg       0.97      0.98      0.98        84
# weighted avg       0.98      0.98      0.98        84
#
# Epoch: 8
# 	Average loss: 0.350422
# 	Accuracy: 0.989691
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.192953, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 9
# 	Average loss: 0.170574
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.139363, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 10
# 	Average loss: 0.074612
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.182539, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 11
# 	Average loss: 0.081464
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.130546, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 12
# 	Average loss: 0.170651
# 	Accuracy: 0.989691
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.065734, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 13
# 	Average loss: 0.082908
# 	Accuracy: 0.984536
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.184090, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 14
# 	Average loss: 0.242470
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67         2
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.045665, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 15
# 	Average loss: 0.045165
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.096408, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 16
# 	Average loss: 0.043104
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.047962, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 17
# 	Average loss: 0.025048
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.020568, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 18
# 	Average loss: 0.405646
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.014176, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 19
# 	Average loss: 0.023399
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.019395, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 20
# 	Average loss: 0.087195
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.020740, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 21
# 	Average loss: 0.028093
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.021532, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 22
# 	Average loss: 0.021528
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.020139, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 23
# 	Average loss: 0.288812
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67         2
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.021058, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 24
# 	Average loss: 0.197410
# 	Accuracy: 0.989691
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       0.0
#          1.0       0.00      0.00      0.00       2.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
#
#
# Test set: Total loss: 0.023537, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 25
# 	Average loss: 0.114980
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.014592, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 26
# 	Average loss: 0.256615
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67         2
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.528528, Accuracy: 0.630952
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.49        46
#          1.0       0.55      1.00      0.71        38
#
#     accuracy                           0.63        84
#    macro avg       0.78      0.66      0.60        84
# weighted avg       0.80      0.63      0.59        84
#
# Epoch: 27
# 	Average loss: 0.100497
# 	Accuracy: 0.989691
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.339155, Accuracy: 0.714286
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.48      0.65        46
#          1.0       0.61      1.00      0.76        38
#
#     accuracy                           0.71        84
#    macro avg       0.81      0.74      0.70        84
# weighted avg       0.82      0.71      0.70        84
#
# Epoch: 28
# 	Average loss: 0.042339
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.090007, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 29
# 	Average loss: 0.040351
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.027153, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 30
# 	Average loss: 0.402855
# 	Accuracy: 0.989691
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       2.0
#          1.0       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
#
#
# Test set: Total loss: 0.101732, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 31
# 	Average loss: 0.301780
# 	Accuracy: 0.989691
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       2.0
#          1.0       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
#
#
# Test set: Total loss: 0.570753, Accuracy: 0.726190
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        46
#          1.0       1.00      0.39      0.57        38
#
#     accuracy                           0.73        84
#    macro avg       0.83      0.70      0.68        84
# weighted avg       0.82      0.73      0.69        84
#
# Epoch: 32
# 	Average loss: 0.031847
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.096123, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 33
# 	Average loss: 0.021233
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.012090, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 34
# 	Average loss: 0.027264
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.014726, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 35
# 	Average loss: 0.018667
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.011042, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 36
# 	Average loss: 0.069467
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.009022, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 37
# 	Average loss: 0.016020
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.011502, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 38
# 	Average loss: 0.017039
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.008905, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 39
# 	Average loss: 0.080583
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.009110, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 40
# 	Average loss: 0.009860
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.011259, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 41
# 	Average loss: 0.012965
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.013341, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 42
# 	Average loss: 0.166394
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.037449, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 43
# 	Average loss: 0.199886
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.336903, Accuracy: 0.750000
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.81        46
#          1.0       1.00      0.45      0.62        38
#
#     accuracy                           0.75        84
#    macro avg       0.84      0.72      0.72        84
# weighted avg       0.83      0.75      0.73        84
#
# Epoch: 44
# 	Average loss: 0.018917
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.144675, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 45
# 	Average loss: 0.026898
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.043094, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 46
# 	Average loss: 0.027887
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.113794, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 47
# 	Average loss: 0.024009
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.071451, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 48
# 	Average loss: 0.019901
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.025804, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 49
# 	Average loss: 0.018553
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.012566, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 50
# 	Average loss: 0.049424
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.075553, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 51
# 	Average loss: 0.112958
# 	Accuracy: 0.974227
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.577023, Accuracy: 0.690476
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.43      0.61        46
#          1.0       0.59      1.00      0.75        38
#
#     accuracy                           0.69        84
#    macro avg       0.80      0.72      0.68        84
# weighted avg       0.82      0.69      0.67        84
#
# Epoch: 52
# 	Average loss: 0.313200
# 	Accuracy: 0.989691
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       2.0
#          1.0       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
#
#
# Test set: Total loss: 0.010526, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 53
# 	Average loss: 0.132404
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.974241, Accuracy: 0.583333
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.72        46
#          1.0       1.00      0.08      0.15        38
#
#     accuracy                           0.58        84
#    macro avg       0.78      0.54      0.44        84
# weighted avg       0.76      0.58      0.46        84
#
# Epoch: 54
# 	Average loss: 0.023540
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.112217, Accuracy: 0.988095
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99        46
#          1.0       1.00      0.97      0.99        38
#
#     accuracy                           0.99        84
#    macro avg       0.99      0.99      0.99        84
# weighted avg       0.99      0.99      0.99        84
#
# Epoch: 55
# 	Average loss: 0.028021
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.110400, Accuracy: 0.964286
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.93      0.97        46
#          1.0       0.93      1.00      0.96        38
#
#     accuracy                           0.96        84
#    macro avg       0.96      0.97      0.96        84
# weighted avg       0.97      0.96      0.96        84
#
# Epoch: 56
# 	Average loss: 0.010923
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.161099, Accuracy: 0.928571
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.87      0.93        46
#          1.0       0.86      1.00      0.93        38
#
#     accuracy                           0.93        84
#    macro avg       0.93      0.93      0.93        84
# weighted avg       0.94      0.93      0.93        84
#
# Epoch: 57
# 	Average loss: 0.325333
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.50      0.67         2
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.084851, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 58
# 	Average loss: 0.009953
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.020269, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 59
# 	Average loss: 0.112819
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.014480, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 60
# 	Average loss: 0.156525
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.571873, Accuracy: 0.654762
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76        46
#          1.0       1.00      0.24      0.38        38
#
#     accuracy                           0.65        84
#    macro avg       0.81      0.62      0.57        84
# weighted avg       0.79      0.65      0.59        84
#
# Epoch: 61
# 	Average loss: 0.109436
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.015737, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 62
# 	Average loss: 0.093578
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.021140, Accuracy: 1.000000
# ...
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 99
# 	Average loss: 0.012885
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.045333, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 100
# 	Average loss: 0.013890
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.035428, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 101
# 	Average loss: 0.090066
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.109090, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 102
# 	Average loss: 0.007521
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.617097, Accuracy: 0.690476
#               precision    recall  f1-score   support
#
#          0.0       0.64      1.00      0.78        46
#          1.0       1.00      0.32      0.48        38
#
#     accuracy                           0.69        84
#    macro avg       0.82      0.66      0.63        84
# weighted avg       0.80      0.69      0.64        84
#
# Epoch: 103
# 	Average loss: 0.005672
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.430990, Accuracy: 0.785714
#               precision    recall  f1-score   support
#
#          0.0       0.72      1.00      0.84        46
#          1.0       1.00      0.53      0.69        38
#
#     accuracy                           0.79        84
#    macro avg       0.86      0.76      0.76        84
# weighted avg       0.85      0.79      0.77        84
#
# Epoch: 104
# 	Average loss: 0.198988
# 	Accuracy: 0.989691
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.003798, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 105
# 	Average loss: 0.008361
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 4.061312, Accuracy: 0.452381
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        46
#          1.0       0.45      1.00      0.62        38
#
#     accuracy                           0.45        84
#    macro avg       0.23      0.50      0.31        84
# weighted avg       0.20      0.45      0.28        84
#
# Epoch: 106
# 	Average loss: 0.017469
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 2.606833, Accuracy: 0.464286
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.02      0.04        46
#          1.0       0.46      1.00      0.63        38
#
#     accuracy                           0.46        84
#    macro avg       0.73      0.51      0.34        84
# weighted avg       0.75      0.46      0.31        84
#
# Epoch: 107
# 	Average loss: 0.047098
# 	Accuracy: 0.989691
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.626164, Accuracy: 0.690476
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.43      0.61        46
#          1.0       0.59      1.00      0.75        38
#
#     accuracy                           0.69        84
#    macro avg       0.80      0.72      0.68        84
# weighted avg       0.82      0.69      0.67        84
#
# Epoch: 108
# 	Average loss: 0.205794
# 	Accuracy: 0.994845
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Test set: Total loss: 0.042371, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 109
# 	Average loss: 0.021338
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.020921, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 110
# 	Average loss: 0.028077
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.027977, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 111
# 	Average loss: 0.023909
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.059816, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 112
# 	Average loss: 0.017271
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.067601, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 113
# 	Average loss: 0.011180
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.062887, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 114
# 	Average loss: 0.011116
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.042475, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 115
# 	Average loss: 0.008002
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.030919, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 116
# 	Average loss: 0.007049
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.026297, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 117
# 	Average loss: 0.015067
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.015737, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 118
# 	Average loss: 0.254391
# 	Accuracy: 0.989691
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       2.0
#          1.0       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
#
#
# Test set: Total loss: 0.005133, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
#
# Epoch: 119
# 	Average loss: 0.015515
# 	Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Test set: Total loss: 0.003860, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84

# %%
pyplot.plot(plots["train acc"], "royalblue", label = "train")
pyplot.plot(plots["test acc"], "darkorange", label = "test")
pyplot.title("accuracy over training")
pyplot.legend()
pyplot.show()

# %%
# tload = torch.utils.data.TensorDataset(X_train, X_actual)
# tloader = torch.utils.data.DataLoader(tload, batch_size = X_train.shape[0], shuffle = True)
# _, _, _, _ = test(CNNPoor, device, tloader)
_, _, _, _ = test(CNNPoor, device, test_loader)
# Out:
# Test set: Total loss: 0.003860, Accuracy: 1.000000
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        46
#          1.0       1.00      1.00      1.00        38
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
