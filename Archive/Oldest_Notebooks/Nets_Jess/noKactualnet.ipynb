# %% [markdown]
# # Loose EEGNet
# This notebook is a neural network that is based as much off of the EEGNet paper as I could understand.

# %% [markdown]
# ---

# %% [markdown]
# # Import/Install all necessary packages and libraries

# %%
import numpy as np

from sklearn.metrics import roc_auc_score, precision_score, recall_score, accuracy_score, classification_report
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable, gradcheck
from torch.utils.data import TensorDataset, DataLoader

import pandas as pd

from matplotlib import pyplot

import math

import glob

from os import walk

# %% [markdown]
# # Check for GPU availability and set device

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %% [markdown]
# # Load and format the data

# %%
master_data, master_label = [], []
datafix, labelfix = ".pkl", ".csv"
for (dirpath, dirnames, filenames) in walk('/content/drive/My Drive/Processed Data Files'):
    new_data = [dirpath + '/' + name for name in filenames if datafix in name]
    master_data.extend(new_data)

    new_labels = [dirpath + '/' + name for name in filenames if labelfix in name]
    master_label.extend(new_labels)
assert len(master_data) == len(master_label)
master_data.sort()
master_label.sort()
for index in range(len(master_data)):
    try: 
        assert master_data[index][:-4] == master_label[index][:-11]
    except:
        print(index)
        print(master_data[index][:-4])
        print(master_label[index][:-11])

# %%
# pkllabels = pd.read_csv(r'/content/drive/My Drive/data/OpenBCI-RAW-2020-09-14_RileyYesNoTwoMin_labels.csv', delimiter=',', header=None)
# pkllabels = pkllabels.T
# pkllabels = np.array(pkllabels)
# pkllabels = pkllabels.reshape((pkllabels.shape[0], 1))
# pkllabels = pkllabels[1:, :]
# for i in range(pkllabels.shape[0]):
#     if i % 2 == 0:
#         pkllabels[i][0] = 1
#     else:
#         pkllabels[i][0] = 0

pkllabels = np.zeros((1, 1))
pkldata = np.zeros((1, 7, 500))


# pkldata = pd.read_pickle(r'/content/drive/My Drive/data/OpenBCI-RAW-2020-09-14_RileyYesNoTwoMin.pkl')
# pkldata = pkldata[1:, :, :]

for i in range(len(master_data)):

    if "Unprocessed" in master_data[i]:
        new_data = pd.read_pickle(master_data[i])

        new_labels = pd.read_csv(master_label[i], delimiter=',', header=None)
        if new_labels.shape[0] == 1 and new_labels.shape[1] > new_labels.shape[0]:
            new_labels = new_labels.T
        new_labels = np.array(new_labels)
        new_labels = new_labels.reshape((new_labels.shape[0], 1))

        pkldata = np.concatenate((pkldata, new_data), axis = 0)
        pkllabels = np.concatenate((pkllabels, new_labels), axis = 0)

pkllabels = pkllabels[1:, :]
pkldata = pkldata[1:, :, :]

# %%
print(pkldata.shape, pkllabels.shape)
print(pkllabels.shape)
x = pkldata[0]
only_no = [pkldata[i] for i in range(pkldata.shape[0]) if pkllabels[i][0] == 0]
only_no = np.array(only_no)
only_yes = [pkldata[i] for i in range(pkldata.shape[0]) if pkllabels[i][0] == 1]
only_yes = np.array(only_yes)
print(only_no.shape, only_yes.shape)
for i in range(pkldata.shape[1]):
    g = i + 1
    pyplot.plot(only_yes[0:, i, :].T, )
    pyplot.plot(only_no[0:, i, :].T, alpha = .3)
    pyplot.title("Value for channel {} over all {} chunks".format(i, pkldata.shape[0]))
    #pyplot.savefig(f"/content/drive/My Drive/Extra/processed_data_Riley_channel_{g}.png")
    pyplot.show()
# Out:
# (416, 7, 500) (416, 1)
# (416, 1)
# (208, 7, 500) (208, 7, 500)

# %%
torch.manual_seed(4)
torch.cuda.manual_seed(4)

# %%
channels = pkldata.shape[1]
timepoints = pkldata.shape[2]
print(channels, timepoints)
# Out:
# 7 500

# %%
BATCH_SIZE = 32

pkllabels = pkllabels.astype(np.float32)
X_actual = torch.from_numpy(pkllabels)

scaler = StandardScaler()
X_train = pkldata
for i in range(len(X_train)):
    X_train[i] = scaler.fit_transform(X_train[i])
X_train = torch.from_numpy(X_train)
X_train = X_train.unsqueeze(1)

train_data, test_data, labels_train, labels_test = train_test_split(X_train, X_actual, test_size=0.3, random_state=4)

trainset = torch.utils.data.TensorDataset(train_data, labels_train)
testset = torch.utils.data.TensorDataset(test_data, labels_test)

train_loader = torch.utils.data.DataLoader(trainset, batch_size = BATCH_SIZE, shuffle = True)
test_loader = torch.utils.data.DataLoader(testset, batch_size = test_data.shape[0], shuffle = True)

print(train_data.shape, test_data.shape)
# Out:
# torch.Size([291, 1, 7, 500]) torch.Size([125, 1, 7, 500])

# %% [markdown]
# # Build the model and train
# A short breakdown of the paper:
# > EEGNet is a CNN for classification and interpretation of EEG-based BCI's
#
# > Benefits of EEGNet:
# > 1. Can be applied to different BCI paradagims (MI, ERP, SSVEP)
# > 2. Can be trained with very limited data
# > 3. Can produce neurophysiologically interpretable features
#
# > The model architecture:
# > 1. Fit 2D convolutional filters of size (1, sampling rate//2)
# > 2. Use a depthwise convolution of size (# of channels, 1)
# > 3. Add a separable convolution of size (1, 16)
# > 4. Flatten the data and feed it through a classification layer

# %%
# hyperparameters
freq, avg1stride, avg2stride = 250, (1, 4), (1, 8)
convstride = 1 # stride for each conv2D
conv1_neurons = 8
conv2_neurons = 16
conv3_neurons = 32
conv4_neurons = 16
kern1size = freq // 2
kern3size = 32

# %%
padding_needed = (kern1size - 1) / 2
conv1outx, conv1outy = (channels, (timepoints + (2 * padding_needed) - kern1size)/convstride + 1)

print("1st layer output size:", conv1outx, conv1outy)

conv2outx, conv2outy = ((conv1outx - channels)/convstride + 1, conv1outy)
conv2outx, conv2outy = conv2outx // avg1stride[0], conv2outy // avg1stride[1]

print("2nd layer output size:", conv2outx, conv2outy)

conv3outx, conv3outy = (conv2outx, (conv2outy - kern3size)/convstride + 1)

print("3rd layer output size:", conv3outx, conv3outy)

conv4outx, conv4outy = (conv3outx, conv3outy)
conv4outx, conv4outy = (conv4outx // avg2stride[0], conv4outy // avg2stride[1])

print("4th layer output size:", conv4outx, conv4outy)

flat1_in = int(conv4outx * conv4outy * conv4_neurons)
# Out:
# 1st layer output size: 7 500.0
# 2nd layer output size: 1.0 125.0
# 3rd layer output size: 1.0 94.0
# 4th layer output size: 1.0 11.0

# %% [markdown]
# Model description, layer by layer
#
# 1. Temporal convolution
# > * - Uses filters of (1, sampling frequency // 2)
# > * - Learns frequency filters at 2Hz and above
# 2. Depthwise convolution
# > * - Learns spatial filters
# 3. Separable Convolution
# > * - Conists of a deptwise convolution followed by a pointwise convolution
# > * - First learnes a kernel summarizing each feature map, then merges the outputs
# 4. Fully connected layer
# > * - Consists of a linear layer that reduces the channels, followed by a sigmoid classification

# %%
class ConstrainedConv2d(nn.Conv2d):
    def forward(self, input):
        return F.conv2d(input, self.weight.clamp(min=-1.0, max=1.0), self.bias, self.stride,
                        self.padding, self.dilation, self.groups)

# %%
CNNPoor = nn.Sequential(
    nn.ZeroPad2d((math.floor(padding_needed), math.ceil(padding_needed), 0, 0)),
    nn.Conv2d(1, conv1_neurons, (1, kern1size), bias=False),
    nn.ELU(),
    nn.BatchNorm2d(conv1_neurons),
    
    ConstrainedConv2d(conv1_neurons, conv2_neurons, (channels, 1), bias=False, groups=conv1_neurons),
    nn.ELU(),
    nn.BatchNorm2d(conv2_neurons),
    nn.MaxPool2d(avg1stride),
    nn.Dropout(),
    
    nn.Conv2d(conv2_neurons, conv3_neurons, (1, kern3size), bias=False, groups=conv2_neurons),
    nn.Conv2d(conv3_neurons, conv4_neurons, kernel_size=1, bias=False),
    nn.ELU(),
    nn.BatchNorm2d(conv4_neurons),
    nn.MaxPool2d(avg2stride),
    nn.Dropout(),
    
    nn.Flatten(),

    nn.Linear(flat1_in, 1),
    nn.Sigmoid(),
)

CNNPoor = CNNPoor.to(device)

# %%
loss_function = nn.BCELoss()
optimizer = optim.Adam(CNNPoor.parameters(), lr = 0.001)

# %%
def test(model, device, test_loader):
    
    model.eval()
    correct = 0
    tot_loss = 0
    acc_score, prec_score, rec_score = 0, 0, 0
    with torch.no_grad():
        for (data, labels) in test_loader:
            data, labels = data.to(device), labels.to(device)
            
            classification = model(data.float())
            loss = loss_function(classification, labels)

            pred = torch.round(classification)
            correct += pred.eq(labels.view_as(pred)).sum().item()
            tot_loss += loss.item()

            acc_score += accuracy_score(labels, pred)
            prec_score += precision_score(labels, pred)
            rec_score += recall_score(labels, pred)

        print("\nTest set: Total loss: {:.6f}, Accuracy: {:.6f}".format(tot_loss, 
                                                                          correct / len(test_loader.dataset)))
        print(classification_report(labels, pred))
        return (tot_loss, acc_score, prec_score, rec_score)

# %%
def train(model, device, train_loader, optimizer, epoch):

    model.train()
    correct = 0
    tot_loss = 0
    for batch, (data, labels) in enumerate(train_loader):
        data, labels = data.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        classification = model(data.float())
        loss = loss_function(classification, labels)

        loss.backward()
        optimizer.step()

        pred = torch.round(classification)
        correct += pred.eq(labels.view_as(pred)).sum().item()
        tot_loss += loss.item()
    print("Epoch: {}".format(epoch))
    print("\tAverage loss: {:.6f}".format(tot_loss / (batch + 1)))
    print("\tAccuracy: {:.6f}".format(correct / len(train_loader.dataset)))
    return (tot_loss / (batch + 1), correct / len(train_loader.dataset))

# %%
plots = {"train loss": [],
         "train acc": [],
         "test loss": [],
         "test acc": [],
         "test prec": [],
         "test rec": []}

for epoch in range(120):
    trl, tra = train(CNNPoor, device, train_loader, optimizer, epoch)
    plots["train loss"].append(trl)
    plots["train acc"].append(tra)
    tl, ta, tp, tr = test(CNNPoor, device, test_loader)
    plots["test loss"].append(tl)
    plots["test acc"].append(ta)
    plots["test prec"].append(tp)
    plots["test rec"].append(tr)
# Out:
# Epoch: 0
# 	Average loss: 0.697023
# 	Accuracy: 0.539519
#
# Test set: Total loss: 0.686674, Accuracy: 0.752000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.76      0.75        62
#          1.0       0.76      0.75      0.75        63
#
#     accuracy                           0.75       125
#    macro avg       0.75      0.75      0.75       125
# weighted avg       0.75      0.75      0.75       125
#
# Epoch: 1
# 	Average loss: 0.675168
# 	Accuracy: 0.649485
#
# Test set: Total loss: 0.667526, Accuracy: 0.640000
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.47      0.56        62
#          1.0       0.61      0.81      0.69        63
#
#     accuracy                           0.64       125
#    macro avg       0.66      0.64      0.63       125
# weighted avg       0.66      0.64      0.63       125
#
# Epoch: 2
# 	Average loss: 0.567405
# 	Accuracy: 0.718213
#
# Test set: Total loss: 0.641874, Accuracy: 0.824000
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.84      0.83        62
#          1.0       0.84      0.81      0.82        63
#
#     accuracy                           0.82       125
#    macro avg       0.82      0.82      0.82       125
# weighted avg       0.82      0.82      0.82       125
#
# Epoch: 3
# 	Average loss: 0.559815
# 	Accuracy: 0.735395
#
# Test set: Total loss: 0.604304, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.84      0.82        62
#          1.0       0.83      0.79      0.81        63
#
#     accuracy                           0.82       125
#    macro avg       0.82      0.82      0.82       125
# weighted avg       0.82      0.82      0.82       125
#
# Epoch: 4
# 	Average loss: 0.521865
# 	Accuracy: 0.807560
#
# Test set: Total loss: 0.545205, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.85      0.82        62
#          1.0       0.84      0.76      0.80        63
#
#     accuracy                           0.81       125
#    macro avg       0.81      0.81      0.81       125
# weighted avg       0.81      0.81      0.81       125
#
# Epoch: 5
# 	Average loss: 0.530158
# 	Accuracy: 0.780069
#
# Test set: Total loss: 0.485326, Accuracy: 0.824000
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.89      0.83        62
#          1.0       0.87      0.76      0.81        63
#
#     accuracy                           0.82       125
#    macro avg       0.83      0.82      0.82       125
# weighted avg       0.83      0.82      0.82       125
#
# Epoch: 6
# 	Average loss: 0.435807
# 	Accuracy: 0.841924
#
# Test set: Total loss: 0.444244, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.81      0.81        62
#          1.0       0.81      0.81      0.81        63
#
#     accuracy                           0.81       125
#    macro avg       0.81      0.81      0.81       125
# weighted avg       0.81      0.81      0.81       125
#
# Epoch: 7
# 	Average loss: 0.428373
# 	Accuracy: 0.786942
#
# Test set: Total loss: 0.400766, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.89      0.83        62
#          1.0       0.87      0.75      0.80        63
#
#     accuracy                           0.82       125
#    macro avg       0.82      0.82      0.82       125
# weighted avg       0.82      0.82      0.82       125
#
# Epoch: 8
# 	Average loss: 0.423994
# 	Accuracy: 0.824742
#
# Test set: Total loss: 0.411269, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 9
# 	Average loss: 0.447305
# 	Accuracy: 0.814433
#
# Test set: Total loss: 0.371929, Accuracy: 0.880000
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.81      0.87        62
#          1.0       0.83      0.95      0.89        63
#
#     accuracy                           0.88       125
#    macro avg       0.89      0.88      0.88       125
# weighted avg       0.89      0.88      0.88       125
#
# Epoch: 10
# 	Average loss: 0.377081
# 	Accuracy: 0.817869
#
# Test set: Total loss: 0.619540, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.98      0.83        62
#          1.0       0.97      0.62      0.76        63
#
#     accuracy                           0.80       125
#    macro avg       0.85      0.80      0.79       125
# weighted avg       0.85      0.80      0.79       125
#
# Epoch: 11
# 	Average loss: 0.368704
# 	Accuracy: 0.835052
#
# Test set: Total loss: 0.426186, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 12
# 	Average loss: 0.354334
# 	Accuracy: 0.814433
#
# Test set: Total loss: 0.393391, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.90      0.82        62
#          1.0       0.88      0.71      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 13
# 	Average loss: 0.322046
# 	Accuracy: 0.845361
#
# Test set: Total loss: 0.418582, Accuracy: 0.776000
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.92      0.80        62
#          1.0       0.89      0.63      0.74        63
#
#     accuracy                           0.78       125
#    macro avg       0.80      0.78      0.77       125
# weighted avg       0.80      0.78      0.77       125
#
# Epoch: 14
# 	Average loss: 0.318326
# 	Accuracy: 0.838488
#
# Test set: Total loss: 0.421301, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 15
# 	Average loss: 0.335814
# 	Accuracy: 0.838488
#
# Test set: Total loss: 0.380581, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 16
# 	Average loss: 0.352007
# 	Accuracy: 0.824742
#
# Test set: Total loss: 0.352815, Accuracy: 0.832000
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.87      0.84        62
#          1.0       0.86      0.79      0.83        63
#
#     accuracy                           0.83       125
#    macro avg       0.83      0.83      0.83       125
# weighted avg       0.83      0.83      0.83       125
#
# Epoch: 17
# 	Average loss: 0.391841
# 	Accuracy: 0.835052
#
# Test set: Total loss: 0.371761, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.87      0.82        62
#          1.0       0.86      0.76      0.81        63
#
#     accuracy                           0.82       125
#    macro avg       0.82      0.82      0.82       125
# weighted avg       0.82      0.82      0.82       125
#
# Epoch: 18
# 	Average loss: 0.344681
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.394306, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 19
# 	Average loss: 0.372692
# 	Accuracy: 0.841924
#
# Test set: Total loss: 0.405707, Accuracy: 0.792000
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.90      0.81        62
#          1.0       0.88      0.68      0.77        63
#
#     accuracy                           0.79       125
#    macro avg       0.81      0.79      0.79       125
# weighted avg       0.81      0.79      0.79       125
#
# Epoch: 20
# 	Average loss: 0.360879
# 	Accuracy: 0.831615
#
# Test set: Total loss: 0.483228, Accuracy: 0.736000
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.92      0.78        62
#          1.0       0.88      0.56      0.68        63
#
#     accuracy                           0.74       125
#    macro avg       0.77      0.74      0.73       125
# weighted avg       0.77      0.74      0.73       125
#
# Epoch: 21
# 	Average loss: 0.387555
# 	Accuracy: 0.804124
#
# Test set: Total loss: 0.551995, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.98      0.84        62
#          1.0       0.98      0.63      0.77        63
#
#     accuracy                           0.81       125
#    macro avg       0.85      0.81      0.80       125
# weighted avg       0.85      0.81      0.80       125
#
# Epoch: 22
# 	Average loss: 0.321786
# 	Accuracy: 0.838488
#
# Test set: Total loss: 0.415854, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.90      0.82        62
#          1.0       0.88      0.71      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 23
# 	Average loss: 0.351044
# 	Accuracy: 0.838488
#
# Test set: Total loss: 0.375064, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 24
# 	Average loss: 0.437714
# 	Accuracy: 0.790378
#
# Test set: Total loss: 0.468610, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.97      0.83        62
#          1.0       0.95      0.63      0.76        63
#
#     accuracy                           0.80       125
#    macro avg       0.84      0.80      0.79       125
# weighted avg       0.84      0.80      0.79       125
#
# Epoch: 25
# 	Average loss: 0.308788
# 	Accuracy: 0.848797
#
# Test set: Total loss: 0.557363, Accuracy: 0.776000
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.98      0.81        62
#          1.0       0.97      0.57      0.72        63
#
#     accuracy                           0.78       125
#    macro avg       0.83      0.78      0.77       125
# weighted avg       0.83      0.78      0.77       125
#
# Epoch: 26
# 	Average loss: 0.434007
# 	Accuracy: 0.821306
#
# Test set: Total loss: 0.410398, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 27
# 	Average loss: 0.359117
# 	Accuracy: 0.814433
#
# Test set: Total loss: 0.348910, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.87      0.82        62
#          1.0       0.86      0.76      0.81        63
#
#     accuracy                           0.82       125
#    macro avg       0.82      0.82      0.82       125
# weighted avg       0.82      0.82      0.82       125
#
# Epoch: 28
# 	Average loss: 0.355111
# 	Accuracy: 0.786942
#
# Test set: Total loss: 0.360627, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.90      0.82        62
#          1.0       0.88      0.71      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 29
# 	Average loss: 0.455359
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.352453, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.89      0.83        62
#          1.0       0.87      0.75      0.80        63
#
#     accuracy                           0.82       125
#    macro avg       0.82      0.82      0.82       125
# weighted avg       0.82      0.82      0.82       125
#
# Epoch: 30
# 	Average loss: 0.392045
# 	Accuracy: 0.810997
#
# Test set: Total loss: 0.324450, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.90      0.83        62
#          1.0       0.88      0.73      0.80        63
#
#     accuracy                           0.82       125
#    macro avg       0.83      0.82      0.81       125
# weighted avg       0.83      0.82      0.81       125
#
# Epoch: 31
# 	Average loss: 0.383234
# 	Accuracy: 0.817869
#
# Test set: Total loss: 0.397356, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 32
# 	Average loss: 0.394426
# 	Accuracy: 0.835052
#
# Test set: Total loss: 0.408993, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 33
# 	Average loss: 0.529677
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.353715, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.87      0.82        62
#          1.0       0.86      0.76      0.81        63
#
#     accuracy                           0.82       125
#    macro avg       0.82      0.82      0.82       125
# weighted avg       0.82      0.82      0.82       125
#
# Epoch: 34
# 	Average loss: 0.324978
# 	Accuracy: 0.807560
#
# Test set: Total loss: 0.397706, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 35
# 	Average loss: 0.365496
# 	Accuracy: 0.831615
#
# Test set: Total loss: 0.500272, Accuracy: 0.768000
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.98      0.81        62
#          1.0       0.97      0.56      0.71        63
#
#     accuracy                           0.77       125
#    macro avg       0.83      0.77      0.76       125
# weighted avg       0.83      0.77      0.76       125
#
# Epoch: 36
# 	Average loss: 0.363261
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.364655, Accuracy: 0.832000
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.82      0.83        62
#          1.0       0.83      0.84      0.83        63
#
#     accuracy                           0.83       125
#    macro avg       0.83      0.83      0.83       125
# weighted avg       0.83      0.83      0.83       125
#
# Epoch: 37
# 	Average loss: 0.544897
# 	Accuracy: 0.804124
#
# Test set: Total loss: 0.426345, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.90      0.83        62
#          1.0       0.88      0.73      0.80        63
#
#     accuracy                           0.82       125
#    macro avg       0.83      0.82      0.81       125
# weighted avg       0.83      0.82      0.81       125
#
# Epoch: 38
# 	Average loss: 0.401698
# 	Accuracy: 0.841924
#
# Test set: Total loss: 0.870149, Accuracy: 0.592000
#               precision    recall  f1-score   support
#
#          0.0       0.55      1.00      0.71        62
#          1.0       1.00      0.19      0.32        63
#
#     accuracy                           0.59       125
#    macro avg       0.77      0.60      0.51       125
# weighted avg       0.78      0.59      0.51       125
#
# Epoch: 39
# 	Average loss: 0.373531
# 	Accuracy: 0.835052
#
# Test set: Total loss: 0.398139, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.90      0.82        62
#          1.0       0.88      0.71      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 40
# 	Average loss: 0.371271
# 	Accuracy: 0.800687
#
# Test set: Total loss: 0.337156, Accuracy: 0.824000
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.87      0.83        62
#          1.0       0.86      0.78      0.82        63
#
#     accuracy                           0.82       125
#    macro avg       0.83      0.82      0.82       125
# weighted avg       0.83      0.82      0.82       125
#
# Epoch: 41
# 	Average loss: 0.349431
# 	Accuracy: 0.800687
#
# Test set: Total loss: 0.512797, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.98      0.84        62
#          1.0       0.98      0.63      0.77        63
#
#     accuracy                           0.81       125
#    macro avg       0.85      0.81      0.80       125
# weighted avg       0.85      0.81      0.80       125
#
# Epoch: 42
# 	Average loss: 0.329197
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.458168, Accuracy: 0.776000
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.92      0.80        62
#          1.0       0.89      0.63      0.74        63
#
#     accuracy                           0.78       125
#    macro avg       0.80      0.78      0.77       125
# weighted avg       0.80      0.78      0.77       125
#
# Epoch: 43
# 	Average loss: 0.307188
# 	Accuracy: 0.831615
#
# Test set: Total loss: 0.435147, Accuracy: 0.792000
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.90      0.81        62
#          1.0       0.88      0.68      0.77        63
#
#     accuracy                           0.79       125
#    macro avg       0.81      0.79      0.79       125
# weighted avg       0.81      0.79      0.79       125
#
# Epoch: 44
# 	Average loss: 0.316208
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.343494, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.90      0.82        62
#          1.0       0.88      0.71      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 45
# 	Average loss: 0.384563
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.366063, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 46
# 	Average loss: 0.323970
# 	Accuracy: 0.824742
#
# Test set: Total loss: 0.522650, Accuracy: 0.784000
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.98      0.82        62
#          1.0       0.97      0.59      0.73        63
#
#     accuracy                           0.78       125
#    macro avg       0.84      0.79      0.78       125
# weighted avg       0.84      0.78      0.78       125
#
# Epoch: 47
# 	Average loss: 0.400164
# 	Accuracy: 0.824742
#
# Test set: Total loss: 0.361867, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.90      0.82        62
#          1.0       0.88      0.71      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 48
# 	Average loss: 0.413192
# 	Accuracy: 0.831615
#
# Test set: Total loss: 0.330183, Accuracy: 0.848000
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.82      0.84        62
#          1.0       0.83      0.87      0.85        63
#
#     accuracy                           0.85       125
#    macro avg       0.85      0.85      0.85       125
# weighted avg       0.85      0.85      0.85       125
#
# Epoch: 49
# 	Average loss: 0.318051
# 	Accuracy: 0.824742
#
# Test set: Total loss: 0.424453, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.92      0.83        62
#          1.0       0.90      0.70      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 50
# 	Average loss: 0.302906
# 	Accuracy: 0.831615
#
# Test set: Total loss: 0.457045, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.92      0.82        62
#          1.0       0.90      0.68      0.77        63
#
#     accuracy                           0.80       125
#    macro avg       0.82      0.80      0.80       125
# weighted avg       0.82      0.80      0.80       125
#
# Epoch: 51
# 	Average loss: 0.319262
# 	Accuracy: 0.831615
#
# Test set: Total loss: 0.422479, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 52
# 	Average loss: 0.341211
# 	Accuracy: 0.821306
#
# Test set: Total loss: 0.404684, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 53
# 	Average loss: 0.293228
# 	Accuracy: 0.841924
#
# Test set: Total loss: 0.360306, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.90      0.82        62
#          1.0       0.88      0.71      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 54
# 	Average loss: 0.292993
# 	Accuracy: 0.852234
#
# Test set: Total loss: 0.394411, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 55
# 	Average loss: 0.339064
# 	Accuracy: 0.845361
#
# Test set: Total loss: 0.445615, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.94      0.82        62
#          1.0       0.91      0.67      0.77        63
#
#     accuracy                           0.80       125
#    macro avg       0.82      0.80      0.80       125
# weighted avg       0.82      0.80      0.80       125
#
# Epoch: 56
# 	Average loss: 0.352837
# 	Accuracy: 0.821306
#
# Test set: Total loss: 0.368739, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 57
# 	Average loss: 0.320633
# 	Accuracy: 0.831615
#
# Test set: Total loss: 0.436348, Accuracy: 0.792000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.92      0.81        62
#          1.0       0.89      0.67      0.76        63
#
#     accuracy                           0.79       125
#    macro avg       0.81      0.79      0.79       125
# weighted avg       0.81      0.79      0.79       125
#
# Epoch: 58
# 	Average loss: 0.300124
# 	Accuracy: 0.824742
#
# Test set: Total loss: 0.406572, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 59
# 	Average loss: 0.349075
# 	Accuracy: 0.821306
#
# Test set: Total loss: 0.443072, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.92      0.82        62
#          1.0       0.90      0.68      0.77        63
#
#     accuracy                           0.80       125
#    macro avg       0.82      0.80      0.80       125
# weighted avg       0.82      0.80      0.80       125
#
# Epoch: 60
# 	Average loss: 0.345697
# 	Accuracy: 0.807560
#
# Test set: Total loss: 0.415499, Accuracy: 0.792000
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.90      0.81        62
#          1.0       0.88      0.68      0.77        63
#
#     accuracy                           0.79       125
#    macro avg       0.81      0.79      0.79       125
# weighted avg       0.81      0.79      0.79       125
#
# Epoch: 61
# 	Average loss: 0.327771
# 	Accuracy: 0.817869
#
# Test set: Total loss: 0.464530, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.98      0.84        62
#          1.0       0.98      0.63      0.77        63
#
#     accuracy                           0.81       125
#    macro avg       0.85      0.81      0.80       125
# weighted avg       0.85      0.81      0.80       125
#
# Epoch: 62
# 	Average loss: 0.347257
# 	Accuracy: 0.824742
#
# Test set: Total loss: 0.391805, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 63
# 	Average loss: 0.330770
# 	Accuracy: 0.841924
#
# Test set: Total loss: 0.459598, Accuracy: 0.776000
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.94      0.81        62
#          1.0       0.91      0.62      0.74        63
#
#     accuracy                           0.78       125
#    macro avg       0.81      0.78      0.77       125
# weighted avg       0.81      0.78      0.77       125
#
# Epoch: 64
# 	Average loss: 0.307479
# 	Accuracy: 0.859107
#
# Test set: Total loss: 0.423012, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.92      0.83        62
#          1.0       0.90      0.71      0.80        63
#
#     accuracy                           0.82       125
#    macro avg       0.83      0.82      0.81       125
# weighted avg       0.83      0.82      0.81       125
#
# Epoch: 65
# 	Average loss: 0.301161
# 	Accuracy: 0.831615
#
# Test set: Total loss: 0.382848, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.90      0.82        62
#          1.0       0.88      0.71      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 66
# 	Average loss: 0.284979
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.353322, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.90      0.83        62
#          1.0       0.88      0.73      0.80        63
#
#     accuracy                           0.82       125
#    macro avg       0.83      0.82      0.81       125
# weighted avg       0.83      0.82      0.81       125
#
# Epoch: 67
# 	Average loss: 0.284182
# 	Accuracy: 0.859107
#
# Test set: Total loss: 0.366205, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.90      0.82        62
#          1.0       0.88      0.71      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 68
# 	Average loss: 0.279095
# 	Accuracy: 0.848797
#
# Test set: Total loss: 0.400766, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.90      0.82        62
#          1.0       0.88      0.71      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 69
# 	Average loss: 0.359229
# 	Accuracy: 0.838488
#
# Test set: Total loss: 0.459773, Accuracy: 0.784000
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.94      0.81        62
#          1.0       0.91      0.63      0.75        63
#
#     accuracy                           0.78       125
#    macro avg       0.81      0.79      0.78       125
# weighted avg       0.81      0.78      0.78       125
#
# Epoch: 70
# 	Average loss: 0.399958
# 	Accuracy: 0.835052
#
# Test set: Total loss: 0.365314, Accuracy: 0.864000
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.74      0.84        62
#          1.0       0.79      0.98      0.88        63
#
#     accuracy                           0.86       125
#    macro avg       0.89      0.86      0.86       125
# weighted avg       0.89      0.86      0.86       125
#
# Epoch: 71
# 	Average loss: 0.320193
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.479482, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.98      0.84        62
#          1.0       0.98      0.63      0.77        63
#
#     accuracy                           0.81       125
#    macro avg       0.85      0.81      0.80       125
# weighted avg       0.85      0.81      0.80       125
#
# Epoch: 72
# 	Average loss: 0.295636
# 	Accuracy: 0.855670
#
# Test set: Total loss: 0.414254, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 73
# 	Average loss: 0.322817
# 	Accuracy: 0.841924
#
# Test set: Total loss: 0.405681, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 74
# 	Average loss: 0.506214
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.371947, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 75
# 	Average loss: 0.319942
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.471645, Accuracy: 0.792000
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.95      0.82        62
#          1.0       0.93      0.63      0.75        63
#
#     accuracy                           0.79       125
#    macro avg       0.82      0.79      0.79       125
# weighted avg       0.83      0.79      0.79       125
#
# Epoch: 76
# 	Average loss: 0.395547
# 	Accuracy: 0.835052
#
# Test set: Total loss: 0.510810, Accuracy: 0.784000
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.98      0.82        62
#          1.0       0.97      0.59      0.73        63
#
#     accuracy                           0.78       125
#    macro avg       0.84      0.79      0.78       125
# weighted avg       0.84      0.78      0.78       125
#
# Epoch: 77
# 	Average loss: 0.316246
# 	Accuracy: 0.838488
#
# Test set: Total loss: 0.804710, Accuracy: 0.616000
#               precision    recall  f1-score   support
#
#          0.0       0.56      1.00      0.72        62
#          1.0       1.00      0.24      0.38        63
#
#     accuracy                           0.62       125
#    macro avg       0.78      0.62      0.55       125
# weighted avg       0.78      0.62      0.55       125
#
# Epoch: 78
# 	Average loss: 0.319851
# 	Accuracy: 0.848797
#
# Test set: Total loss: 0.439697, Accuracy: 0.784000
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.94      0.81        62
#          1.0       0.91      0.63      0.75        63
#
#     accuracy                           0.78       125
#    macro avg       0.81      0.79      0.78       125
# weighted avg       0.81      0.78      0.78       125
#
# Epoch: 79
# 	Average loss: 0.386688
# 	Accuracy: 0.838488
#
# Test set: Total loss: 0.381530, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 80
# 	Average loss: 0.367326
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.366502, Accuracy: 0.824000
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.90      0.84        62
#          1.0       0.89      0.75      0.81        63
#
#     accuracy                           0.82       125
#    macro avg       0.83      0.82      0.82       125
# weighted avg       0.83      0.82      0.82       125
#
# Epoch: 81
# 	Average loss: 0.396351
# 	Accuracy: 0.800687
#
# Test set: Total loss: 0.532913, Accuracy: 0.792000
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.95      0.82        62
#          1.0       0.93      0.63      0.75        63
#
#     accuracy                           0.79       125
#    macro avg       0.82      0.79      0.79       125
# weighted avg       0.83      0.79      0.79       125
#
# Epoch: 82
# 	Average loss: 0.302267
# 	Accuracy: 0.841924
#
# Test set: Total loss: 0.471739, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.92      0.82        62
#          1.0       0.90      0.68      0.77        63
#
#     accuracy                           0.80       125
#    macro avg       0.82      0.80      0.80       125
# weighted avg       0.82      0.80      0.80       125
#
# Epoch: 83
# 	Average loss: 0.350172
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.449833, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.92      0.83        62
#          1.0       0.90      0.70      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 84
# 	Average loss: 0.313820
# 	Accuracy: 0.838488
#
# Test set: Total loss: 0.439955, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.92      0.83        62
#          1.0       0.90      0.70      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 85
# 	Average loss: 0.387453
# 	Accuracy: 0.814433
#
# Test set: Total loss: 0.428812, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.92      0.83        62
#          1.0       0.90      0.70      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 86
# 	Average loss: 0.276792
# 	Accuracy: 0.838488
#
# Test set: Total loss: 0.586299, Accuracy: 0.744000
#               precision    recall  f1-score   support
#
#          0.0       0.66      1.00      0.79        62
#          1.0       1.00      0.49      0.66        63
#
#     accuracy                           0.74       125
#    macro avg       0.83      0.75      0.73       125
# weighted avg       0.83      0.74      0.73       125
#
# Epoch: 87
# 	Average loss: 0.303157
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.475565, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.98      0.84        62
#          1.0       0.98      0.63      0.77        63
#
#     accuracy                           0.81       125
#    macro avg       0.85      0.81      0.80       125
# weighted avg       0.85      0.81      0.80       125
#
# Epoch: 88
# 	Average loss: 0.290830
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.358066, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.90      0.82        62
#          1.0       0.88      0.71      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 89
# 	Average loss: 0.317754
# 	Accuracy: 0.835052
#
# Test set: Total loss: 0.369511, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.89      0.83        62
#          1.0       0.87      0.75      0.80        63
#
#     accuracy                           0.82       125
#    macro avg       0.82      0.82      0.82       125
# weighted avg       0.82      0.82      0.82       125
#
# Epoch: 90
# 	Average loss: 0.269776
# 	Accuracy: 0.835052
#
# Test set: Total loss: 0.455757, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.92      0.83        62
#          1.0       0.90      0.70      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 91
# 	Average loss: 0.431008
# 	Accuracy: 0.817869
#
# Test set: Total loss: 0.456381, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.92      0.83        62
#          1.0       0.90      0.70      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 92
# 	Average loss: 0.447859
# 	Accuracy: 0.835052
#
# Test set: Total loss: 0.400549, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.92      0.83        62
#          1.0       0.90      0.71      0.80        63
#
#     accuracy                           0.82       125
#    macro avg       0.83      0.82      0.81       125
# weighted avg       0.83      0.82      0.81       125
#
# Epoch: 93
# 	Average loss: 0.287565
# 	Accuracy: 0.838488
#
# Test set: Total loss: 0.517851, Accuracy: 0.768000
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.98      0.81        62
#          1.0       0.97      0.56      0.71        63
#
#     accuracy                           0.77       125
#    macro avg       0.83      0.77      0.76       125
# weighted avg       0.83      0.77      0.76       125
#
# Epoch: 94
# 	Average loss: 0.279706
# 	Accuracy: 0.852234
#
# Test set: Total loss: 0.476220, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.98      0.84        62
#          1.0       0.98      0.63      0.77        63
#
#     accuracy                           0.81       125
#    macro avg       0.85      0.81      0.80       125
# weighted avg       0.85      0.81      0.80       125
#
# Epoch: 95
# 	Average loss: 0.306586
# 	Accuracy: 0.824742
#
# Test set: Total loss: 0.443946, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.98      0.84        62
#          1.0       0.98      0.63      0.77        63
#
#     accuracy                           0.81       125
#    macro avg       0.85      0.81      0.80       125
# weighted avg       0.85      0.81      0.80       125
#
# Epoch: 96
# 	Average loss: 0.336974
# 	Accuracy: 0.831615
#
# Test set: Total loss: 0.387935, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 97
# 	Average loss: 0.285819
# 	Accuracy: 0.831615
#
# Test set: Total loss: 0.353510, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.90      0.82        62
#          1.0       0.88      0.71      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 98
# 	Average loss: 0.344303
# 	Accuracy: 0.845361
#
# Test set: Total loss: 0.363237, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 99
# 	Average loss: 0.350343
# 	Accuracy: 0.824742
#
# Test set: Total loss: 0.433293, Accuracy: 0.752000
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.90      0.78        62
#          1.0       0.86      0.60      0.71        63
#
#     accuracy                           0.75       125
#    macro avg       0.78      0.75      0.75       125
# weighted avg       0.78      0.75      0.75       125
#
# Epoch: 100
# 	Average loss: 0.286663
# 	Accuracy: 0.848797
#
# Test set: Total loss: 0.459205, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.98      0.84        62
#          1.0       0.98      0.63      0.77        63
#
#     accuracy                           0.81       125
#    macro avg       0.85      0.81      0.80       125
# weighted avg       0.85      0.81      0.80       125
#
# Epoch: 101
# 	Average loss: 0.276669
# 	Accuracy: 0.817869
#
# Test set: Total loss: 0.503512, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.98      0.84        62
#          1.0       0.98      0.63      0.77        63
#
#     accuracy                           0.81       125
#    macro avg       0.85      0.81      0.80       125
# weighted avg       0.85      0.81      0.80       125
#
# Epoch: 102
# 	Average loss: 0.333144
# 	Accuracy: 0.838488
#
# Test set: Total loss: 0.440001, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.94      0.83        62
#          1.0       0.91      0.68      0.78        63
#
#     accuracy                           0.81       125
#    macro avg       0.83      0.81      0.81       125
# weighted avg       0.83      0.81      0.81       125
#
# Epoch: 103
# 	Average loss: 0.304951
# 	Accuracy: 0.862543
#
# Test set: Total loss: 0.399590, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 104
# 	Average loss: 0.256697
# 	Accuracy: 0.845361
#
# Test set: Total loss: 0.405910, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 105
# 	Average loss: 0.262448
# 	Accuracy: 0.848797
#
# Test set: Total loss: 0.399261, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 106
# 	Average loss: 0.344958
# 	Accuracy: 0.831615
#
# Test set: Total loss: 0.407947, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.90      0.82        62
#          1.0       0.88      0.70      0.78        63
#
#     accuracy                           0.80       125
#    macro avg       0.81      0.80      0.80       125
# weighted avg       0.81      0.80      0.80       125
#
# Epoch: 107
# 	Average loss: 0.302502
# 	Accuracy: 0.821306
#
# Test set: Total loss: 0.462460, Accuracy: 0.792000
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.90      0.81        62
#          1.0       0.88      0.68      0.77        63
#
#     accuracy                           0.79       125
#    macro avg       0.81      0.79      0.79       125
# weighted avg       0.81      0.79      0.79       125
#
# Epoch: 108
# 	Average loss: 0.370135
# 	Accuracy: 0.814433
#
# Test set: Total loss: 0.524861, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.98      0.84        62
#          1.0       0.98      0.63      0.77        63
#
#     accuracy                           0.81       125
#    macro avg       0.85      0.81      0.80       125
# weighted avg       0.85      0.81      0.80       125
#
# Epoch: 109
# 	Average loss: 0.267919
# 	Accuracy: 0.821306
#
# Test set: Total loss: 0.431607, Accuracy: 0.800000
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.92      0.82        62
#          1.0       0.90      0.68      0.77        63
#
#     accuracy                           0.80       125
#    macro avg       0.82      0.80      0.80       125
# weighted avg       0.82      0.80      0.80       125
#
# Epoch: 110
# 	Average loss: 0.282336
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.426856, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.92      0.83        62
#          1.0       0.90      0.70      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 111
# 	Average loss: 0.271272
# 	Accuracy: 0.848797
#
# Test set: Total loss: 0.455487, Accuracy: 0.792000
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.95      0.82        62
#          1.0       0.93      0.63      0.75        63
#
#     accuracy                           0.79       125
#    macro avg       0.82      0.79      0.79       125
# weighted avg       0.83      0.79      0.79       125
#
# Epoch: 112
# 	Average loss: 0.269705
# 	Accuracy: 0.845361
#
# Test set: Total loss: 0.451948, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.98      0.84        62
#          1.0       0.98      0.63      0.77        63
#
#     accuracy                           0.81       125
#    macro avg       0.85      0.81      0.80       125
# weighted avg       0.85      0.81      0.80       125
#
# Epoch: 113
# 	Average loss: 0.635445
# 	Accuracy: 0.831615
#
# Test set: Total loss: 0.428461, Accuracy: 0.784000
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.94      0.81        62
#          1.0       0.91      0.63      0.75        63
#
#     accuracy                           0.78       125
#    macro avg       0.81      0.79      0.78       125
# weighted avg       0.81      0.78      0.78       125
#
# Epoch: 114
# 	Average loss: 0.344875
# 	Accuracy: 0.814433
#
# Test set: Total loss: 0.472052, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.98      0.84        62
#          1.0       0.98      0.63      0.77        63
#
#     accuracy                           0.81       125
#    macro avg       0.85      0.81      0.80       125
# weighted avg       0.85      0.81      0.80       125
#
# Epoch: 115
# 	Average loss: 0.273868
# 	Accuracy: 0.838488
#
# Test set: Total loss: 0.470706, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.98      0.84        62
#          1.0       0.98      0.63      0.77        63
#
#     accuracy                           0.81       125
#    macro avg       0.85      0.81      0.80       125
# weighted avg       0.85      0.81      0.80       125
#
# Epoch: 116
# 	Average loss: 0.267430
# 	Accuracy: 0.835052
#
# Test set: Total loss: 0.430998, Accuracy: 0.808000
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.92      0.83        62
#          1.0       0.90      0.70      0.79        63
#
#     accuracy                           0.81       125
#    macro avg       0.82      0.81      0.81       125
# weighted avg       0.82      0.81      0.81       125
#
# Epoch: 117
# 	Average loss: 0.276665
# 	Accuracy: 0.824742
#
# Test set: Total loss: 0.380805, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.87      0.82        62
#          1.0       0.86      0.76      0.81        63
#
#     accuracy                           0.82       125
#    macro avg       0.82      0.82      0.82       125
# weighted avg       0.82      0.82      0.82       125
#
# Epoch: 118
# 	Average loss: 0.358245
# 	Accuracy: 0.859107
#
# Test set: Total loss: 0.391058, Accuracy: 0.816000
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.87      0.82        62
#          1.0       0.86      0.76      0.81        63
#
#     accuracy                           0.82       125
#    macro avg       0.82      0.82      0.82       125
# weighted avg       0.82      0.82      0.82       125
#
# Epoch: 119
# 	Average loss: 0.295173
# 	Accuracy: 0.828179
#
# Test set: Total loss: 0.444659, Accuracy: 0.832000
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.73      0.81        62
#          1.0       0.78      0.94      0.85        63
#
#     accuracy                           0.83       125
#    macro avg       0.85      0.83      0.83       125
# weighted avg       0.85      0.83      0.83       125

# %%
pyplot.plot(plots["train acc"], "royalblue", label = "train")
#pyplot.plot(plots["test acc"], "darkorange", label = "test")
pyplot.title("accuracy over training")
pyplot.legend()
pyplot.show()

# %%
# tload = torch.utils.data.TensorDataset(X_train, X_actual)
# tloader = torch.utils.data.DataLoader(tload, batch_size = X_train.shape[0], shuffle = True)
# _, _, _, _ = test(CNNPoor, device, tloader)
_, _, _, _ = test(CNNPoor, device, test_loader)
# Out:
# Test set: Total loss: 0.448311, Accuracy: 0.824519
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.71      0.80       208
#          1.0       0.76      0.94      0.84       208
#
#     accuracy                           0.82       416
#    macro avg       0.84      0.82      0.82       416
# weighted avg       0.84      0.82      0.82       416
#
#
# Test set: Total loss: 0.444659, Accuracy: 0.832000
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.73      0.81        62
#          1.0       0.78      0.94      0.85        63
#
#     accuracy                           0.83       125
#    macro avg       0.85      0.83      0.83       125
# weighted avg       0.85      0.83      0.83       125
