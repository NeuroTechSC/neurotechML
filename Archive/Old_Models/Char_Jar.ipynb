# %% [markdown]
# # Loose EEGNet
# This notebook is a neural network that is based as much off of the EEGNet paper as I could understand.

# %% [markdown]
# ---

# %% [markdown]
# # Import/Install all necessary packages and libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np

from sklearn.metrics import roc_auc_score, precision_score, recall_score, accuracy_score, classification_report
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable, gradcheck
from torch.utils.data import TensorDataset, DataLoader

import pandas as pd

from matplotlib import pyplot

import math

from os import walk

# %% [markdown]
# # Check for GPU availability and set device

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %% [markdown]
# # Load and format the data

# %% [markdown]
# Here is a brief rundown of the data:
#
# > Each data segment (chunk) is a two second recording in which a subject subvocalized either "yes" or "no" at any point in the recording
#
# > The data is taken with a sampling frequency of 250hz, so in the end there are 500 timepoints for each chunk
#
# > The hardware we are using has 7 channels
#
# > After all these data cells are run the data is in the shape (# of chunks, 1, # of channels, # of timepoints)

# %%
master_data, master_label = [], []
datafix, labelfix = ".pkl", ".csv"
# paste path below
for (dirpath, dirnames, filenames) in walk('/content/drive/Shareddrives/NeuroTech ML/Processed Data Files'):
    new_data = [dirpath + '/' + name for name in filenames if datafix in name]
    master_data.extend(new_data)

    new_labels = [dirpath + '/' + name for name in filenames if labelfix in name]
    master_label.extend(new_labels)
assert len(master_data) == len(master_label)
master_data.sort()
master_label.sort()
for index in range(len(master_data)):
    try: 
        assert master_data[index][:-4] == master_label[index][:-11]
    except:
        print(index)
        print(master_data[index][:-4])
        print(master_label[index][:-11])

# %%
pkllabels = np.zeros((1, 1))
pkldata = np.zeros((1, 7, 500))
pkllabels2 = np.zeros((1, 1))
pkldata2 = np.zeros((1, 7, 500))

for i in range(len(master_data)):

    # To train no ICA data change data type to ICA
    # To train no ICA and weaker filter change data type to Weaker
    # To train unprocessed data change data type to Unprocessed

    data_type = "Char_Jar"

    if data_type in master_data[i]:
        new_data = pd.read_pickle(master_data[i])

        new_labels = pd.read_csv(master_label[i], delimiter=',', header=None)
        if new_labels.shape[0] == 1 and new_labels.shape[1] > new_labels.shape[0]:
            new_labels = new_labels.T
        new_labels = np.array(new_labels)
        new_labels = new_labels.reshape((new_labels.shape[0], 1))

        pkldata = np.concatenate((pkldata, new_data), axis = 0)
        pkllabels = np.concatenate((pkllabels, new_labels), axis = 0)
    # elif data_type in master_data[i] and 'YESNO' in master_data[i]:
    #     new_data = pd.read_pickle(master_data[i])

    #     new_labels = pd.read_csv(master_label[i], delimiter=',', header=None)
    #     if new_labels.shape[0] == 1 and new_labels.shape[1] > new_labels.shape[0]:
    #         new_labels = new_labels.T
    #     new_labels = np.array(new_labels)
    #     new_labels = new_labels.reshape((new_labels.shape[0], 1))

    #     pkldata2 = np.concatenate((pkldata2, new_data), axis = 0)
    #     pkllabels2 = np.concatenate((pkllabels2, new_labels), axis = 0)

pkllabels = pkllabels[1:, :]
pkldata = pkldata[1:, :, :]
pkllabels2 = pkllabels2[1:, :]
pkldata2 = pkldata2[1:, :, :]

# %%
# Uncomment below if u wanna see a bunch of graphs of the data
print(pkldata.shape, pkllabels.shape)
print(pkllabels.shape)
x = pkldata[0]
only_no = [pkldata[i] for i in range(pkldata.shape[0]) if pkllabels[i][0] == 0]
only_no = np.array(only_no)
only_yes = [pkldata[i] for i in range(pkldata.shape[0]) if pkllabels[i][0] == 1]
only_yes = np.array(only_yes)
print(only_no.shape, only_yes.shape)
for i in range(pkldata.shape[1]):
    g = i + 1
    pyplot.plot(only_yes[0:, i, :].T, color="red")
    pyplot.plot(only_no[0:, i, :].T, alpha = .3, color="blue")
    pyplot.title("Value for channel {} over all {} chunks".format(i, pkldata.shape[0]))
    #pyplot.savefig(f"/content/drive/My Drive/Extra/processed_data_Riley_channel_{g}.png")
    pyplot.show()
# Out:
# (183, 7, 500) (183, 1)
# (183, 1)
# (91, 7, 500) (92, 7, 500)

# %%
torch.manual_seed(4)
torch.cuda.manual_seed(4)

# %%
channels = pkldata.shape[1]
timepoints = pkldata.shape[2]
print(channels, timepoints)
# Out:
# 7 500

# %%
BATCH_SIZE = 32

pkllabels = pkllabels.astype(np.float32)
X_actual = torch.from_numpy(pkllabels)

scaler = StandardScaler()
X_train = pkldata
# for i in range(len(X_train)):
#     X_train[i] = scaler.fit_transform(X_train[i])
X_train = torch.from_numpy(X_train)
X_train = X_train.unsqueeze(1)

# pkllabels2 = pkllabels2.astype(np.float32)
# X_test_labels = torch.from_numpy(pkllabels2)

# X_test = pkldata2
# X_test = torch.from_numpy(X_test)
# X_test = X_test.unsqueeze(1)

# splits the data into a train and dev set, and loads them into dataloaders
train_data, test_data, labels_train, labels_test = train_test_split(X_train, X_actual, test_size=0.2, random_state=4)

# test_data = X_test
# labels_test = X_test_labels

trainset = torch.utils.data.TensorDataset(train_data, labels_train)
testset = torch.utils.data.TensorDataset(test_data, labels_test)

train_loader = torch.utils.data.DataLoader(trainset, batch_size = BATCH_SIZE, shuffle = True, drop_last=True)
test_loader = torch.utils.data.DataLoader(testset, batch_size = test_data.shape[0], shuffle = True, drop_last=True)

print(train_data.shape, test_data.shape, labels_train.shape, labels_test.shape)
# Out:
# torch.Size([146, 1, 7, 500]) torch.Size([37, 1, 7, 500]) torch.Size([146, 1]) torch.Size([37, 1])

# %% [markdown]
# # Build the model and train
# A short breakdown of the paper:
# > EEGNet is a CNN for classification and interpretation of EEG-based BCI's
#
# > Benefits of EEGNet:
# > 1. Can be applied to different BCI paradagims (MI, ERP, SSVEP)
# > 2. Can be trained with very limited data
# > 3. Can produce neurophysiologically interpretable features
#
# > The model architecture:
# > 1. Fit 2D convolutional filters of size (1, sampling rate//2)
# > 2. Use a depthwise convolution of size (# of channels, 1)
# > 3. Add a separable convolution of size (1, 16)
# > 4. Flatten the data and feed it through a classification layer

# %%
# hyperparameters
freq, avg1stride, avg2stride = 250, (1, 4), (1, 8)
convstride = 1 # stride for each conv2D
conv1_neurons = 4
conv2_neurons = 8
conv3_neurons = 32
conv4_neurons = 16
kern1size = freq // 2
kern3size = 32

# %%
padding_needed = (kern1size - 1) / 2
conv1outx, conv1outy = (channels, (timepoints + (2 * padding_needed) - kern1size)/convstride + 1)

print("1st layer output size:", conv1outx, conv1outy)

conv2outx, conv2outy = ((conv1outx - channels)/convstride + 1, conv1outy)
conv2outx, conv2outy = conv2outx // avg1stride[0], conv2outy // avg1stride[1]

print("2nd layer output size:", conv2outx, conv2outy)

# conv3outx, conv3outy = (conv2outx, (conv2outy - kern3size)/convstride + 1)

# print("3rd layer output size:", conv3outx, conv3outy)

# conv4outx, conv4outy = (conv3outx, conv3outy)
# conv4outx, conv4outy = (conv4outx // avg2stride[0], conv4outy // avg2stride[1])

# print("4th layer output size:", conv4outx, conv4outy)

# flat1_in = int(conv4outx * conv4outy * conv4_neurons)

flat1_in = int(conv2outx * conv2outy * conv2_neurons)
# Out:
# 1st layer output size: 7 500.0
# 2nd layer output size: 1.0 125.0

# %% [markdown]
# Model description, layer by layer
#
# 1. Temporal convolution
# > * - Uses filters of (1, sampling frequency // 2)
# > * - Learns frequency filters at 2Hz and above
# 2. Depthwise convolution
# > * - Learns spatial filters
# 3. Separable Convolution
# > * - Conists of a deptwise convolution followed by a pointwise convolution
# > * - First learnes a kernel summarizing each feature map, then merges the outputs
# 4. Fully connected layer
# > * - Consists of a linear layer that reduces the channels, followed by a sigmoid classification

# %% [markdown]
# 3.5k research grant at school
#
# https://science.ucsc.edu/research-opportunities/undergraduate-research-in-science-and-technology-award/

# %%
class ConstrainedConv2d(nn.Conv2d):
    def forward(self, input):
        return F.conv2d(input, self.weight.clamp(min=-1.0, max=1.0), self.bias, self.stride,
                        self.padding, self.dilation, self.groups)

# %%
class EEGNet(nn.Module):
    def __init__(self):
        super(EEGNet, self).__init__()
        self.pad = nn.ZeroPad2d((math.floor(padding_needed), math.ceil(padding_needed), 0, 0))
        self.conv1 = nn.Conv2d(1, conv1_neurons, (1, kern1size), bias=False)
        self.norm1 = nn.BatchNorm2d(conv1_neurons)
        self.conv2 = ConstrainedConv2d(conv1_neurons, conv2_neurons, (channels, 1), bias=False)
        self.norm2 = nn.BatchNorm2d(conv2_neurons)
        self.pool = nn.MaxPool2d(avg1stride)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(flat1_in, 1)
        self.dropout = nn.Dropout()

        self.activation = nn.ELU()
        self.activation2 = nn.Sigmoid()

    def forward(self, x):
        out = self.pad(x)
        out = self.conv1(out)
        out = self.activation(out)
        out = self.norm1(out)

        out = self.conv2(out)
        out = self.activation(out)
        out = self.pool(self.norm2(out))
        out = self.dropout(out)

        out = self.activation2(self.fc1(self.flatten(out)))
        return out

CNNPoor = EEGNet()

# %%
# CNNPoor = nn.Sequential(
#     nn.ZeroPad2d((math.floor(padding_needed), math.ceil(padding_needed), 0, 0)),
#     nn.Conv2d(1, conv1_neurons, (1, kern1size), bias=False),
#     nn.ELU(),
#     nn.BatchNorm2d(conv1_neurons),
    
#     ConstrainedConv2d(conv1_neurons, conv2_neurons, (channels, 1), bias=False),
#     nn.ELU(),
#     nn.BatchNorm2d(conv2_neurons),
#     nn.MaxPool2d(avg1stride),
#     nn.Dropout(),
    
#     # nn.Conv2d(conv2_neurons, conv3_neurons, (1, kern3size), bias=False, groups=conv2_neurons),
#     # nn.Conv2d(conv3_neurons, conv4_neurons, kernel_size=1, bias=False),
#     # nn.ELU(),
#     # nn.BatchNorm2d(conv4_neurons),
#     # nn.MaxPool2d(avg2stride),
#     # nn.Dropout(),
    
#     nn.Flatten(),

#     nn.Linear(flat1_in, 1),
#     nn.Sigmoid(),
# )

CNNPoor = CNNPoor.to(device)

# %%
loss_function = nn.BCELoss()
optimizer = optim.Adam(CNNPoor.parameters(), lr = 0.001)

# %%
def test(model, device, test_loader):
    
    model.eval()
    correct = 0
    tot_loss = 0
    acc_score, prec_score, rec_score = 0, 0, 0
    with torch.no_grad():
        for (data, labels) in test_loader:
            data, labels = data.to(device), labels.to(device)
            
            classification = model(data.float())
            loss = loss_function(classification, labels)

            pred = torch.round(classification)
            correct += pred.eq(labels.view_as(pred)).sum().item()
            tot_loss += loss.item()

            acc_score += accuracy_score(labels, pred)
            prec_score += precision_score(labels, pred)
            rec_score += recall_score(labels, pred)

        print("\nTest set: Total loss: {:.6f}, Accuracy: {:.6f}".format(tot_loss, 
                                                                          correct / len(test_loader.dataset)))
        # print(classification_report(labels, pred))
        return (tot_loss, acc_score, prec_score, rec_score)

# %%
def train(model, device, train_loader, optimizer, epoch):

    model.train()
    correct = 0
    tot_loss = 0
    for batch, (data, labels) in enumerate(train_loader):
        data, labels = data.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        classification = model(data.float())
        loss = loss_function(classification, labels)

        loss.backward()
        optimizer.step()

        pred = torch.round(classification)
        correct += pred.eq(labels.view_as(pred)).sum().item()
        tot_loss += loss.item()
    print("Epoch: {}".format(epoch))
    print("\tAverage loss: {:.6f}".format(tot_loss / (batch + 1)))
    print("\tAccuracy: {:.6f}".format(correct / len(train_loader.dataset)))

    labels_detached = labels.detach()
    preds_detached = pred.detach()
    print(classification_report(labels_detached, preds_detached))
    return (tot_loss / (batch + 1), correct / len(train_loader.dataset))

# %%
plots = {"train loss": [],
         "train acc": [],
         "test loss": [],
         "test acc": [],
         "test prec": [],
         "test rec": []}

for epoch in range(120):
    trl, tra = train(CNNPoor, device, train_loader, optimizer, epoch)
    plots["train loss"].append(trl)
    plots["train acc"].append(tra)
    tl, ta, tp, tr = test(CNNPoor, device, test_loader)
    plots["test loss"].append(tl)
    plots["test acc"].append(ta)
    plots["test prec"].append(tp)
    plots["test rec"].append(tr)
# Out:
# Epoch: 0
# 	Average loss: 0.808697
# 	Accuracy: 0.424658
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.71      0.62        17
#          1.0       0.50      0.33      0.40        15
#
#     accuracy                           0.53        32
#    macro avg       0.52      0.52      0.51        32
# weighted avg       0.52      0.53      0.51        32
#
#
# Test set: Total loss: 0.777800, Accuracy: 0.378378
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 1
# 	Average loss: 0.766438
# 	Accuracy: 0.431507
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.26      0.36        19
#          1.0       0.39      0.69      0.50        13
#
#     accuracy                           0.44        32
#    macro avg       0.47      0.48      0.43        32
# weighted avg       0.49      0.44      0.42        32
#
#
# Test set: Total loss: 0.734523, Accuracy: 0.378378
# Epoch: 2
# 	Average loss: 0.797961
# 	Accuracy: 0.424658
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.75      0.65        16
#          1.0       0.64      0.44      0.52        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.58        32
# weighted avg       0.60      0.59      0.58        32
#
#
# Test set: Total loss: 0.791846, Accuracy: 0.378378
# Epoch: 3
# 	Average loss: 0.777355
# 	Accuracy: 0.465753
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.80      0.73        20
#          1.0       0.50      0.33      0.40        12
#
#     accuracy                           0.62        32
#    macro avg       0.58      0.57      0.56        32
# weighted avg       0.60      0.62      0.60        32
#
#
# Test set: Total loss: 0.761755, Accuracy: 0.378378
# Epoch: 4
# 	Average loss: 0.748980
# 	Accuracy: 0.438356
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.59      0.54        17
#          1.0       0.42      0.33      0.37        15
#
#     accuracy                           0.47        32
#    macro avg       0.46      0.46      0.46        32
# weighted avg       0.46      0.47      0.46        32
#
#
# Test set: Total loss: 0.709853, Accuracy: 0.378378
# Epoch: 5
# 	Average loss: 0.775491
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.50      0.47        16
#          1.0       0.43      0.38      0.40        16
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.681947, Accuracy: 0.567568
# Epoch: 6
# 	Average loss: 0.733729
# 	Accuracy: 0.472603
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.50      0.44        14
#          1.0       0.50      0.39      0.44        18
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.45      0.44      0.44        32
#
#
# Test set: Total loss: 0.704276, Accuracy: 0.378378
# Epoch: 7
# 	Average loss: 0.683281
# 	Accuracy: 0.465753
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.65      0.63        17
#          1.0       0.57      0.53      0.55        15
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.59      0.59      0.59        32
#
#
# Test set: Total loss: 0.737390, Accuracy: 0.459459
# Epoch: 8
# 	Average loss: 0.718532
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.58      0.56        19
#          1.0       0.33      0.31      0.32        13
#
#     accuracy                           0.47        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.46      0.47      0.46        32
#
#
# Test set: Total loss: 0.731089, Accuracy: 0.432432
# Epoch: 9
# 	Average loss: 0.759844
# 	Accuracy: 0.404110
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.56      0.51        16
#          1.0       0.46      0.38      0.41        16
#
#     accuracy                           0.47        32
#    macro avg       0.47      0.47      0.46        32
# weighted avg       0.47      0.47      0.46        32
#
#
# Test set: Total loss: 0.755231, Accuracy: 0.378378
# Epoch: 10
# 	Average loss: 0.725532
# 	Accuracy: 0.486301
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.69      0.59        16
#          1.0       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Test set: Total loss: 0.723989, Accuracy: 0.378378
# Epoch: 11
# 	Average loss: 0.728603
# 	Accuracy: 0.417808
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.31      0.38        16
#          1.0       0.50      0.69      0.58        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.48        32
# weighted avg       0.50      0.50      0.48        32
#
#
# Test set: Total loss: 0.712023, Accuracy: 0.378378
# Epoch: 12
# 	Average loss: 0.733516
# 	Accuracy: 0.438356
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.60      0.51        15
#          1.0       0.50      0.35      0.41        17
#
#     accuracy                           0.47        32
#    macro avg       0.47      0.48      0.46        32
# weighted avg       0.48      0.47      0.46        32
#
#
# Test set: Total loss: 0.830539, Accuracy: 0.378378
# Epoch: 13
# 	Average loss: 0.737926
# 	Accuracy: 0.424658
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.71      0.60        17
#          1.0       0.44      0.27      0.33        15
#
#     accuracy                           0.50        32
#    macro avg       0.48      0.49      0.47        32
# weighted avg       0.49      0.50      0.47        32
#
#
# Test set: Total loss: 0.848004, Accuracy: 0.378378
# Epoch: 14
# 	Average loss: 0.745345
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.82      0.67        17
#          1.0       0.57      0.27      0.36        15
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.55      0.52        32
# weighted avg       0.57      0.56      0.52        32
#
#
# Test set: Total loss: 0.864365, Accuracy: 0.378378
# Epoch: 15
# 	Average loss: 0.703961
# 	Accuracy: 0.472603
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.61      0.59        18
#          1.0       0.46      0.43      0.44        14
#
#     accuracy                           0.53        32
#    macro avg       0.52      0.52      0.52        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Test set: Total loss: 0.827902, Accuracy: 0.378378
# Epoch: 16
# 	Average loss: 0.729659
# 	Accuracy: 0.424658
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.65      0.58        17
#          1.0       0.45      0.33      0.38        15
#
#     accuracy                           0.50        32
#    macro avg       0.49      0.49      0.48        32
# weighted avg       0.49      0.50      0.49        32
#
#
# Test set: Total loss: 0.845496, Accuracy: 0.378378
# Epoch: 17
# 	Average loss: 0.713376
# 	Accuracy: 0.438356
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.63      0.65        19
#          1.0       0.50      0.54      0.52        13
#
#     accuracy                           0.59        32
#    macro avg       0.58      0.59      0.58        32
# weighted avg       0.60      0.59      0.60        32
#
#
# Test set: Total loss: 0.844993, Accuracy: 0.378378
# Epoch: 18
# 	Average loss: 0.736702
# 	Accuracy: 0.404110
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.33      0.40        18
#          1.0       0.40      0.57      0.47        14
#
#     accuracy                           0.44        32
#    macro avg       0.45      0.45      0.44        32
# weighted avg       0.46      0.44      0.43        32
#
#
# Test set: Total loss: 0.794677, Accuracy: 0.378378
# Epoch: 19
# 	Average loss: 0.715263
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.75      0.51        12
#          1.0       0.67      0.30      0.41        20
#
#     accuracy                           0.47        32
#    macro avg       0.53      0.53      0.46        32
# weighted avg       0.56      0.47      0.45        32
#
#
# Test set: Total loss: 0.741777, Accuracy: 0.378378
# Epoch: 20
# 	Average loss: 0.730813
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.31      0.33        16
#          1.0       0.39      0.44      0.41        16
#
#     accuracy                           0.38        32
#    macro avg       0.37      0.38      0.37        32
# weighted avg       0.37      0.38      0.37        32
#
#
# Test set: Total loss: 0.727258, Accuracy: 0.351351
# Epoch: 21
# 	Average loss: 0.729697
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.82      0.70        17
#          1.0       0.67      0.40      0.50        15
#
#     accuracy                           0.62        32
#    macro avg       0.64      0.61      0.60        32
# weighted avg       0.64      0.62      0.61        32
#
#
# Test set: Total loss: 0.739690, Accuracy: 0.378378
# Epoch: 22
# 	Average loss: 0.717772
# 	Accuracy: 0.472603
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.65      0.65        20
#          1.0       0.42      0.42      0.42        12
#
#     accuracy                           0.56        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.56      0.56      0.56        32
#
#
# Test set: Total loss: 0.741477, Accuracy: 0.378378
# Epoch: 23
# 	Average loss: 0.719909
# 	Accuracy: 0.493151
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.85      0.56        13
#          1.0       0.67      0.21      0.32        19
#
#     accuracy                           0.47        32
#    macro avg       0.54      0.53      0.44        32
# weighted avg       0.57      0.47      0.42        32
#
#
# Test set: Total loss: 0.756896, Accuracy: 0.378378
# Epoch: 24
# 	Average loss: 0.690985
# 	Accuracy: 0.472603
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.67      0.54        15
#          1.0       0.50      0.29      0.37        17
#
#     accuracy                           0.47        32
#    macro avg       0.48      0.48      0.46        32
# weighted avg       0.48      0.47      0.45        32
#
#
# Test set: Total loss: 0.714670, Accuracy: 0.405405
# Epoch: 25
# 	Average loss: 0.690767
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.53      0.58        17
#          1.0       0.56      0.67      0.61        15
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.60      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Test set: Total loss: 0.680392, Accuracy: 0.621622
# Epoch: 26
# 	Average loss: 0.702022
# 	Accuracy: 0.417808
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.38      0.40        16
#          1.0       0.44      0.50      0.47        16
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.674442, Accuracy: 0.621622
# Epoch: 27
# 	Average loss: 0.722334
# 	Accuracy: 0.410959
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.39      0.50        23
#          1.0       0.26      0.56      0.36         9
#
#     accuracy                           0.44        32
#    macro avg       0.48      0.47      0.43        32
# weighted avg       0.57      0.44      0.46        32
#
#
# Test set: Total loss: 0.694234, Accuracy: 0.432432
# Epoch: 28
# 	Average loss: 0.701304
# 	Accuracy: 0.431507
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.71      0.57        14
#          1.0       0.64      0.39      0.48        18
#
#     accuracy                           0.53        32
#    macro avg       0.56      0.55      0.53        32
# weighted avg       0.57      0.53      0.52        32
#
#
# Test set: Total loss: 0.731971, Accuracy: 0.378378
# Epoch: 29
# 	Average loss: 0.724015
# 	Accuracy: 0.438356
#               precision    recall  f1-score   support
#
#          0.0       0.32      0.64      0.42        11
#          1.0       0.60      0.29      0.39        21
#
#     accuracy                           0.41        32
#    macro avg       0.46      0.46      0.41        32
# weighted avg       0.50      0.41      0.40        32
#
#
# Test set: Total loss: 0.685372, Accuracy: 0.621622
# Epoch: 30
# 	Average loss: 0.718531
# 	Accuracy: 0.431507
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.42      0.52        19
#          1.0       0.45      0.69      0.55        13
#
#     accuracy                           0.53        32
#    macro avg       0.56      0.56      0.53        32
# weighted avg       0.58      0.53      0.53        32
#
#
# Test set: Total loss: 0.678453, Accuracy: 0.621622
# Epoch: 31
# 	Average loss: 0.707626
# 	Accuracy: 0.472603
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.60      0.62        15
#          1.0       0.67      0.71      0.69        17
#
#     accuracy                           0.66        32
#    macro avg       0.65      0.65      0.65        32
# weighted avg       0.66      0.66      0.66        32
#
#
# Test set: Total loss: 0.691673, Accuracy: 0.648649
# Epoch: 32
# 	Average loss: 0.693615
# 	Accuracy: 0.479452
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.89      0.79        19
#          1.0       0.75      0.46      0.57        13
#
#     accuracy                           0.72        32
#    macro avg       0.73      0.68      0.68        32
# weighted avg       0.73      0.72      0.70        32
#
#
# Test set: Total loss: 0.749659, Accuracy: 0.378378
# Epoch: 33
# 	Average loss: 0.718875
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.75      0.59        16
#          1.0       0.43      0.19      0.26        16
#
#     accuracy                           0.47        32
#    macro avg       0.45      0.47      0.42        32
# weighted avg       0.45      0.47      0.42        32
#
#
# Test set: Total loss: 0.768295, Accuracy: 0.378378
# Epoch: 34
# 	Average loss: 0.733229
# 	Accuracy: 0.431507
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.53      0.50        17
#          1.0       0.38      0.33      0.36        15
#
#     accuracy                           0.44        32
#    macro avg       0.43      0.43      0.43        32
# weighted avg       0.43      0.44      0.43        32
#
#
# Test set: Total loss: 0.731904, Accuracy: 0.324324
# Epoch: 35
# 	Average loss: 0.689770
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.44      0.47        18
#          1.0       0.38      0.43      0.40        14
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.45      0.44      0.44        32
#
#
# Test set: Total loss: 0.702740, Accuracy: 0.486486
# Epoch: 36
# 	Average loss: 0.706134
# 	Accuracy: 0.479452
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.53      0.62        15
#          1.0       0.67      0.82      0.74        17
#
#     accuracy                           0.69        32
#    macro avg       0.70      0.68      0.68        32
# weighted avg       0.70      0.69      0.68        32
#
#
# Test set: Total loss: 0.723597, Accuracy: 0.378378
# Epoch: 37
# 	Average loss: 0.713057
# 	Accuracy: 0.479452
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.74      0.64        19
#          1.0       0.29      0.15      0.20        13
#
#     accuracy                           0.50        32
#    macro avg       0.42      0.45      0.42        32
# weighted avg       0.45      0.50      0.46        32
#
#
# Test set: Total loss: 0.756590, Accuracy: 0.351351
# Epoch: 38
# 	Average loss: 0.690979
# 	Accuracy: 0.534247
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.88      0.68        17
#          1.0       0.60      0.20      0.30        15
#
#     accuracy                           0.56        32
#    macro avg       0.58      0.54      0.49        32
# weighted avg       0.58      0.56      0.50        32
#
#
# Test set: Total loss: 0.754000, Accuracy: 0.351351
# Epoch: 39
# 	Average loss: 0.694331
# 	Accuracy: 0.479452
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.64      0.67        22
#          1.0       0.33      0.40      0.36        10
#
#     accuracy                           0.56        32
#    macro avg       0.52      0.52      0.52        32
# weighted avg       0.59      0.56      0.57        32
#
#
# Test set: Total loss: 0.724899, Accuracy: 0.351351
# Epoch: 40
# 	Average loss: 0.702788
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.62      0.61        16
#          1.0       0.60      0.56      0.58        16
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.59      0.59      0.59        32
#
#
# Test set: Total loss: 0.734686, Accuracy: 0.378378
# Epoch: 41
# 	Average loss: 0.714861
# 	Accuracy: 0.458904
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.64      0.49        14
#          1.0       0.44      0.22      0.30        18
#
#     accuracy                           0.41        32
#    macro avg       0.42      0.43      0.39        32
# weighted avg       0.42      0.41      0.38        32
#
#
# Test set: Total loss: 0.761042, Accuracy: 0.378378
# Epoch: 42
# 	Average loss: 0.711312
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.71      0.68        21
#          1.0       0.33      0.27      0.30        11
#
#     accuracy                           0.56        32
#    macro avg       0.49      0.49      0.49        32
# weighted avg       0.54      0.56      0.55        32
#
#
# Test set: Total loss: 0.724039, Accuracy: 0.351351
# Epoch: 43
# 	Average loss: 0.700947
# 	Accuracy: 0.424658
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.33      0.36        18
#          1.0       0.29      0.36      0.32        14
#
#     accuracy                           0.34        32
#    macro avg       0.35      0.35      0.34        32
# weighted avg       0.35      0.34      0.35        32
#
#
# Test set: Total loss: 0.720714, Accuracy: 0.378378
# Epoch: 44
# 	Average loss: 0.703129
# 	Accuracy: 0.472603
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.50      0.47        14
#          1.0       0.56      0.50      0.53        18
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.51      0.50      0.50        32
#
#
# Test set: Total loss: 0.736739, Accuracy: 0.324324
# Epoch: 45
# 	Average loss: 0.702855
# 	Accuracy: 0.486301
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.67      0.62        18
#          1.0       0.45      0.36      0.40        14
#
#     accuracy                           0.53        32
#    macro avg       0.51      0.51      0.51        32
# weighted avg       0.52      0.53      0.52        32
#
#
# Test set: Total loss: 0.717441, Accuracy: 0.432432
# Epoch: 46
# 	Average loss: 0.702749
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.38      0.47        21
#          1.0       0.32      0.55      0.40        11
#
#     accuracy                           0.44        32
#    macro avg       0.47      0.46      0.44        32
# weighted avg       0.51      0.44      0.45        32
#
#
# Test set: Total loss: 0.707099, Accuracy: 0.432432
# Epoch: 47
# 	Average loss: 0.714762
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.73      0.55        15
#          1.0       0.43      0.18      0.25        17
#
#     accuracy                           0.44        32
#    macro avg       0.43      0.45      0.40        32
# weighted avg       0.43      0.44      0.39        32
#
#
# Test set: Total loss: 0.725371, Accuracy: 0.378378
# Epoch: 48
# 	Average loss: 0.696216
# 	Accuracy: 0.458904
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.88      0.67        16
#          1.0       0.67      0.25      0.36        16
#
#     accuracy                           0.56        32
#    macro avg       0.60      0.56      0.52        32
# weighted avg       0.60      0.56      0.52        32
#
#
# Test set: Total loss: 0.734415, Accuracy: 0.351351
# Epoch: 49
# 	Average loss: 0.681191
# 	Accuracy: 0.472603
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.79      0.56        14
#          1.0       0.57      0.22      0.32        18
#
#     accuracy                           0.47        32
#    macro avg       0.51      0.50      0.44        32
# weighted avg       0.51      0.47      0.43        32
#
#
# Test set: Total loss: 0.721126, Accuracy: 0.378378
# Epoch: 50
# 	Average loss: 0.734059
# 	Accuracy: 0.404110
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50        18
#          1.0       0.36      0.36      0.36        14
#
#     accuracy                           0.44        32
#    macro avg       0.43      0.43      0.43        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.699847, Accuracy: 0.459459
# Epoch: 51
# 	Average loss: 0.713966
# 	Accuracy: 0.438356
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.65      0.56        17
#          1.0       0.40      0.27      0.32        15
#
#     accuracy                           0.47        32
#    macro avg       0.45      0.46      0.44        32
# weighted avg       0.45      0.47      0.45        32
#
#
# Test set: Total loss: 0.723780, Accuracy: 0.405405
# Epoch: 52
# 	Average loss: 0.719552
# 	Accuracy: 0.410959
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.60      0.60        20
#          1.0       0.33      0.33      0.33        12
#
#     accuracy                           0.50        32
#    macro avg       0.47      0.47      0.47        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Test set: Total loss: 0.733931, Accuracy: 0.432432
# Epoch: 53
# 	Average loss: 0.707045
# 	Accuracy: 0.417808
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.74      0.67        19
#          1.0       0.44      0.31      0.36        13
#
#     accuracy                           0.56        32
#    macro avg       0.53      0.52      0.52        32
# weighted avg       0.54      0.56      0.54        32
#
#
# Test set: Total loss: 0.730358, Accuracy: 0.351351
# Epoch: 54
# 	Average loss: 0.698488
# 	Accuracy: 0.472603
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.65      0.58        17
#          1.0       0.45      0.33      0.38        15
#
#     accuracy                           0.50        32
#    macro avg       0.49      0.49      0.48        32
# weighted avg       0.49      0.50      0.49        32
#
#
# Test set: Total loss: 0.754674, Accuracy: 0.378378
# Epoch: 55
# 	Average loss: 0.698591
# 	Accuracy: 0.465753
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.67      0.63        18
#          1.0       0.50      0.43      0.46        14
#
#     accuracy                           0.56        32
#    macro avg       0.55      0.55      0.55        32
# weighted avg       0.56      0.56      0.56        32
#
#
# Test set: Total loss: 0.737687, Accuracy: 0.378378
# Epoch: 56
# 	Average loss: 0.704032
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.29      0.33        17
#          1.0       0.37      0.47      0.41        15
#
#     accuracy                           0.38        32
#    macro avg       0.38      0.38      0.37        32
# weighted avg       0.38      0.38      0.37        32
#
#
# Test set: Total loss: 0.725927, Accuracy: 0.378378
# Epoch: 57
# 	Average loss: 0.661032
# 	Accuracy: 0.554795
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.76      0.70        17
#          1.0       0.67      0.53      0.59        15
#
#     accuracy                           0.66        32
#    macro avg       0.66      0.65      0.65        32
# weighted avg       0.66      0.66      0.65        32
#
#
# Test set: Total loss: 0.746611, Accuracy: 0.351351
# Epoch: 58
# 	Average loss: 0.686756
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.89      0.79        19
#          1.0       0.75      0.46      0.57        13
#
#     accuracy                           0.72        32
#    macro avg       0.73      0.68      0.68        32
# weighted avg       0.73      0.72      0.70        32
#
#
# Test set: Total loss: 0.759154, Accuracy: 0.378378
# Epoch: 59
# 	Average loss: 0.697042
# 	Accuracy: 0.486301
#               precision    recall  f1-score   support
#
#          0.0       0.55      1.00      0.71        16
#          1.0       1.00      0.19      0.32        16
#
#     accuracy                           0.59        32
#    macro avg       0.78      0.59      0.51        32
# weighted avg       0.78      0.59      0.51        32
#
#
# Test set: Total loss: 0.762343, Accuracy: 0.351351
# Epoch: 60
# 	Average loss: 0.707267
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.79      0.59        14
#          1.0       0.67      0.33      0.44        18
#
#     accuracy                           0.53        32
#    macro avg       0.57      0.56      0.52        32
# weighted avg       0.58      0.53      0.51        32
#
#
# Test set: Total loss: 0.750862, Accuracy: 0.324324
# Epoch: 61
# 	Average loss: 0.691784
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.62      0.56        16
#          1.0       0.50      0.38      0.43        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.49        32
# weighted avg       0.50      0.50      0.49        32
#
#
# Test set: Total loss: 0.752195, Accuracy: 0.378378
# Epoch: 62
# 	Average loss: 0.689671
# 	Accuracy: 0.479452
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.76      0.62        17
#          1.0       0.43      0.20      0.27        15
#
#     accuracy                           0.50        32
#    macro avg       0.47      0.48      0.45        32
# weighted avg       0.48      0.50      0.46        32
#
#
# Test set: Total loss: 0.747401, Accuracy: 0.378378
# Epoch: 63
# 	Average loss: 0.717700
# 	Accuracy: 0.424658
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.81      0.67        16
#          1.0       0.67      0.38      0.48        16
#
#     accuracy                           0.59        32
#    macro avg       0.62      0.59      0.57        32
# weighted avg       0.62      0.59      0.57        32
#
#
# Test set: Total loss: 0.717464, Accuracy: 0.378378
# Epoch: 64
# 	Average loss: 0.698160
# 	Accuracy: 0.431507
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.50      0.55        18
#          1.0       0.47      0.57      0.52        14
#
#     accuracy                           0.53        32
#    macro avg       0.54      0.54      0.53        32
# weighted avg       0.54      0.53      0.53        32
#
#
# Test set: Total loss: 0.696249, Accuracy: 0.432432
# Epoch: 65
# 	Average loss: 0.704423
# 	Accuracy: 0.431507
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.78      0.68        18
#          1.0       0.56      0.36      0.43        14
#
#     accuracy                           0.59        32
#    macro avg       0.58      0.57      0.56        32
# weighted avg       0.59      0.59      0.57        32
#
#
# Test set: Total loss: 0.719929, Accuracy: 0.378378
# Epoch: 66
# 	Average loss: 0.713053
# 	Accuracy: 0.486301
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.69      0.59        16
#          1.0       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Test set: Total loss: 0.747328, Accuracy: 0.378378
# Epoch: 67
# 	Average loss: 0.716249
# 	Accuracy: 0.383562
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.67      0.50        15
#          1.0       0.29      0.12      0.17        17
#
#     accuracy                           0.38        32
#    macro avg       0.34      0.39      0.33        32
# weighted avg       0.34      0.38      0.32        32
#
#
# Test set: Total loss: 0.772805, Accuracy: 0.378378
# Epoch: 68
# 	Average loss: 0.704197
# 	Accuracy: 0.458904
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.92      0.59        13
#          1.0       0.75      0.16      0.26        19
#
#     accuracy                           0.47        32
#    macro avg       0.59      0.54      0.42        32
# weighted avg       0.62      0.47      0.39        32
#
#
# Test set: Total loss: 0.745306, Accuracy: 0.351351
# Epoch: 69
# 	Average loss: 0.688636
# 	Accuracy: 0.506849
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.50      0.58        18
#          1.0       0.53      0.71      0.61        14
#
#     accuracy                           0.59        32
#    macro avg       0.61      0.61      0.59        32
# weighted avg       0.62      0.59      0.59        32
#
#
# Test set: Total loss: 0.701064, Accuracy: 0.432432
# Epoch: 70
# 	Average loss: 0.699727
# 	Accuracy: 0.493151
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.41      0.50        17
#          1.0       0.52      0.73      0.61        15
#
#     accuracy                           0.56        32
#    macro avg       0.58      0.57      0.56        32
# weighted avg       0.58      0.56      0.55        32
#
#
# Test set: Total loss: 0.695630, Accuracy: 0.621622
# Epoch: 71
# 	Average loss: 0.699667
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.35      0.45        20
#          1.0       0.38      0.67      0.48        12
#
#     accuracy                           0.47        32
#    macro avg       0.51      0.51      0.47        32
# weighted avg       0.54      0.47      0.46        32
#
#
# Test set: Total loss: 0.699362, Accuracy: 0.432432
# Epoch: 72
# 	Average loss: 0.697833
# 	Accuracy: 0.465753
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.83      0.59        12
#          1.0       0.80      0.40      0.53        20
#
#     accuracy                           0.56        32
#    macro avg       0.63      0.62      0.56        32
# weighted avg       0.67      0.56      0.55        32
#
#
# Test set: Total loss: 0.730176, Accuracy: 0.378378
# Epoch: 73
# 	Average loss: 0.705357
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.56      0.47        16
#          1.0       0.30      0.19      0.23        16
#
#     accuracy                           0.38        32
#    macro avg       0.35      0.38      0.35        32
# weighted avg       0.35      0.38      0.35        32
#
#
# Test set: Total loss: 0.732239, Accuracy: 0.351351
# Epoch: 74
# 	Average loss: 0.714093
# 	Accuracy: 0.404110
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.58      0.59        19
#          1.0       0.43      0.46      0.44        13
#
#     accuracy                           0.53        32
#    macro avg       0.52      0.52      0.52        32
# weighted avg       0.54      0.53      0.53        32
#
#
# Test set: Total loss: 0.721952, Accuracy: 0.432432
# Epoch: 75
# 	Average loss: 0.706328
# 	Accuracy: 0.465753
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.56      0.55        16
#          1.0       0.53      0.50      0.52        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Test set: Total loss: 0.714146, Accuracy: 0.432432
# Epoch: 76
# 	Average loss: 0.692349
# 	Accuracy: 0.486301
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.71      0.59        14
#          1.0       0.67      0.44      0.53        18
#
#     accuracy                           0.56        32
#    macro avg       0.58      0.58      0.56        32
# weighted avg       0.59      0.56      0.56        32
#
#
# Test set: Total loss: 0.721291, Accuracy: 0.351351
# Epoch: 77
# 	Average loss: 0.703708
# 	Accuracy: 0.472603
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.67      0.70        21
#          1.0       0.46      0.55      0.50        11
#
#     accuracy                           0.62        32
#    macro avg       0.60      0.61      0.60        32
# weighted avg       0.64      0.62      0.63        32
#
#
# Test set: Total loss: 0.736519, Accuracy: 0.378378
# Epoch: 78
# 	Average loss: 0.687892
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.67      0.56        15
#          1.0       0.55      0.35      0.43        17
#
#     accuracy                           0.50        32
#    macro avg       0.51      0.51      0.49        32
# weighted avg       0.51      0.50      0.49        32
#
#
# Test set: Total loss: 0.766110, Accuracy: 0.351351
# Epoch: 79
# 	Average loss: 0.703087
# 	Accuracy: 0.465753
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.75      0.63        16
#          1.0       0.60      0.38      0.46        16
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.56      0.55        32
# weighted avg       0.57      0.56      0.55        32
#
#
# Test set: Total loss: 0.759204, Accuracy: 0.378378
# Epoch: 80
# 	Average loss: 0.721669
# 	Accuracy: 0.424658
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.38      0.40        16
#          1.0       0.44      0.50      0.47        16
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.727641, Accuracy: 0.432432
# Epoch: 81
# 	Average loss: 0.740870
# 	Accuracy: 0.417808
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.29      0.41        21
#          1.0       0.38      0.82      0.51        11
#
#     accuracy                           0.47        32
#    macro avg       0.56      0.55      0.46        32
# weighted avg       0.62      0.47      0.45        32
#
#
# Test set: Total loss: 0.707704, Accuracy: 0.432432
# Epoch: 82
# 	Average loss: 0.737469
# 	Accuracy: 0.397260
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.75      0.63        16
#          1.0       0.60      0.38      0.46        16
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.56      0.55        32
# weighted avg       0.57      0.56      0.55        32
#
#
# Test set: Total loss: 0.737409, Accuracy: 0.351351
# Epoch: 83
# 	Average loss: 0.692804
# 	Accuracy: 0.520548
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.94      0.67        16
#          1.0       0.67      0.12      0.21        16
#
#     accuracy                           0.53        32
#    macro avg       0.59      0.53      0.44        32
# weighted avg       0.59      0.53      0.44        32
#
#
# Test set: Total loss: 0.780787, Accuracy: 0.378378
# Epoch: 84
# 	Average loss: 0.723033
# 	Accuracy: 0.438356
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.85      0.52        13
#          1.0       0.33      0.05      0.09        19
#
#     accuracy                           0.38        32
#    macro avg       0.36      0.45      0.31        32
# weighted avg       0.35      0.38      0.27        32
#
#
# Test set: Total loss: 0.755260, Accuracy: 0.378378
# Epoch: 85
# 	Average loss: 0.725606
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.70      0.65        20
#          1.0       0.33      0.25      0.29        12
#
#     accuracy                           0.53        32
#    macro avg       0.47      0.47      0.47        32
# weighted avg       0.51      0.53      0.51        32
#
#
# Test set: Total loss: 0.692857, Accuracy: 0.594595
# Epoch: 86
# 	Average loss: 0.701680
# 	Accuracy: 0.472603
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.46      0.44        13
#          1.0       0.61      0.58      0.59        19
#
#     accuracy                           0.53        32
#    macro avg       0.52      0.52      0.52        32
# weighted avg       0.54      0.53      0.53        32
#
#
# Test set: Total loss: 0.696885, Accuracy: 0.432432
# Epoch: 87
# 	Average loss: 0.700435
# 	Accuracy: 0.472603
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.41      0.55        22
#          1.0       0.38      0.80      0.52        10
#
#     accuracy                           0.53        32
#    macro avg       0.60      0.60      0.53        32
# weighted avg       0.68      0.53      0.54        32
#
#
# Test set: Total loss: 0.704161, Accuracy: 0.432432
# Epoch: 88
# 	Average loss: 0.702379
# 	Accuracy: 0.438356
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.87      0.65        15
#          1.0       0.71      0.29      0.42        17
#
#     accuracy                           0.56        32
#    macro avg       0.62      0.58      0.53        32
# weighted avg       0.62      0.56      0.53        32
#
#
# Test set: Total loss: 0.743161, Accuracy: 0.378378
# Epoch: 89
# 	Average loss: 0.723560
# 	Accuracy: 0.404110
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.63      0.59        19
#          1.0       0.30      0.23      0.26        13
#
#     accuracy                           0.47        32
#    macro avg       0.42      0.43      0.42        32
# weighted avg       0.45      0.47      0.45        32
#
#
# Test set: Total loss: 0.733621, Accuracy: 0.378378
# Epoch: 90
# 	Average loss: 0.678135
# 	Accuracy: 0.472603
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.64      0.46        14
#          1.0       0.29      0.11      0.16        18
#
#     accuracy                           0.34        32
#    macro avg       0.32      0.38      0.31        32
# weighted avg       0.32      0.34      0.29        32
#
#
# Test set: Total loss: 0.743871, Accuracy: 0.378378
# Epoch: 91
# 	Average loss: 0.698612
# 	Accuracy: 0.465753
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.53      0.51        17
#          1.0       0.43      0.40      0.41        15
#
#     accuracy                           0.47        32
#    macro avg       0.46      0.46      0.46        32
# weighted avg       0.47      0.47      0.47        32
#
#
# Test set: Total loss: 0.721247, Accuracy: 0.378378
# Epoch: 92
# 	Average loss: 0.719532
# 	Accuracy: 0.417808
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.57      0.62        21
#          1.0       0.36      0.45      0.40        11
#
#     accuracy                           0.53        32
#    macro avg       0.51      0.51      0.51        32
# weighted avg       0.56      0.53      0.54        32
#
#
# Test set: Total loss: 0.711919, Accuracy: 0.351351
# Epoch: 93
# 	Average loss: 0.706119
# 	Accuracy: 0.458904
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.82      0.67        17
#          1.0       0.57      0.27      0.36        15
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.55      0.52        32
# weighted avg       0.57      0.56      0.52        32
#
#
# Test set: Total loss: 0.727038, Accuracy: 0.378378
# Epoch: 94
# 	Average loss: 0.702291
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.50      0.53        18
#          1.0       0.44      0.50      0.47        14
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.51      0.50      0.50        32
#
#
# Test set: Total loss: 0.708244, Accuracy: 0.459459
# Epoch: 95
# 	Average loss: 0.685714
# 	Accuracy: 0.486301
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.60      0.53        15
#          1.0       0.54      0.41      0.47        17
#
#     accuracy                           0.50        32
#    macro avg       0.51      0.51      0.50        32
# weighted avg       0.51      0.50      0.50        32
#
#
# Test set: Total loss: 0.714808, Accuracy: 0.378378
# Epoch: 96
# 	Average loss: 0.704192
# 	Accuracy: 0.458904
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.82      0.72        17
#          1.0       0.70      0.47      0.56        15
#
#     accuracy                           0.66        32
#    macro avg       0.67      0.65      0.64        32
# weighted avg       0.67      0.66      0.64        32
#
#
# Test set: Total loss: 0.727110, Accuracy: 0.405405
# Epoch: 97
# 	Average loss: 0.725068
# 	Accuracy: 0.397260
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.71      0.50        14
#          1.0       0.33      0.11      0.17        18
#
#     accuracy                           0.38        32
#    macro avg       0.36      0.41      0.33        32
# weighted avg       0.36      0.38      0.31        32
#
#
# Test set: Total loss: 0.738104, Accuracy: 0.378378
# Epoch: 98
# 	Average loss: 0.700767
# 	Accuracy: 0.438356
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.71      0.65        17
#          1.0       0.58      0.47      0.52        15
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.58        32
# weighted avg       0.59      0.59      0.59        32
#
#
# Test set: Total loss: 0.717960, Accuracy: 0.432432
# Epoch: 99
# 	Average loss: 0.705779
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.62      0.59        16
#          1.0       0.57      0.50      0.53        16
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.56      0.56      0.56        32
#
#
# Test set: Total loss: 0.715418, Accuracy: 0.378378
# Epoch: 100
# 	Average loss: 0.709140
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.67      0.63        18
#          1.0       0.50      0.43      0.46        14
#
#     accuracy                           0.56        32
#    macro avg       0.55      0.55      0.55        32
# weighted avg       0.56      0.56      0.56        32
#
#
# Test set: Total loss: 0.717662, Accuracy: 0.432432
# Epoch: 101
# 	Average loss: 0.678343
# 	Accuracy: 0.438356
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.48      0.53        21
#          1.0       0.27      0.36      0.31        11
#
#     accuracy                           0.44        32
#    macro avg       0.43      0.42      0.42        32
# weighted avg       0.48      0.44      0.45        32
#
#
# Test set: Total loss: 0.728675, Accuracy: 0.405405
# Epoch: 102
# 	Average loss: 0.686234
# 	Accuracy: 0.493151
#               precision    recall  f1-score   support
#
#          0.0       0.48      1.00      0.65        13
#          1.0       1.00      0.26      0.42        19
#
#     accuracy                           0.56        32
#    macro avg       0.74      0.63      0.53        32
# weighted avg       0.79      0.56      0.51        32
#
#
# Test set: Total loss: 0.760880, Accuracy: 0.378378
# Epoch: 103
# 	Average loss: 0.710729
# 	Accuracy: 0.424658
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.75      0.67        20
#          1.0       0.29      0.17      0.21        12
#
#     accuracy                           0.53        32
#    macro avg       0.44      0.46      0.44        32
# weighted avg       0.48      0.53      0.50        32
#
#
# Test set: Total loss: 0.726026, Accuracy: 0.351351
# Epoch: 104
# 	Average loss: 0.708693
# 	Accuracy: 0.417808
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.56      0.49        16
#          1.0       0.36      0.25      0.30        16
#
#     accuracy                           0.41        32
#    macro avg       0.40      0.41      0.39        32
# weighted avg       0.40      0.41      0.39        32
#
#
# Test set: Total loss: 0.713165, Accuracy: 0.459459
# Epoch: 105
# 	Average loss: 0.693966
# 	Accuracy: 0.486301
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.55      0.67        20
#          1.0       0.53      0.83      0.65        12
#
#     accuracy                           0.66        32
#    macro avg       0.69      0.69      0.66        32
# weighted avg       0.73      0.66      0.66        32
#
#
# Test set: Total loss: 0.705822, Accuracy: 0.432432
# Epoch: 106
# 	Average loss: 0.708275
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.59      0.53        17
#          1.0       0.36      0.27      0.31        15
#
#     accuracy                           0.44        32
#    macro avg       0.42      0.43      0.42        32
# weighted avg       0.42      0.44      0.42        32
#
#
# Test set: Total loss: 0.726088, Accuracy: 0.432432
# Epoch: 107
# 	Average loss: 0.709641
# 	Accuracy: 0.390411
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.60      0.47        15
#          1.0       0.33      0.18      0.23        17
#
#     accuracy                           0.38        32
#    macro avg       0.36      0.39      0.35        32
# weighted avg       0.36      0.38      0.34        32
#
#
# Test set: Total loss: 0.731677, Accuracy: 0.351351
# Epoch: 108
# 	Average loss: 0.695050
# 	Accuracy: 0.479452
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.75      0.65        16
#          1.0       0.64      0.44      0.52        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.58        32
# weighted avg       0.60      0.59      0.58        32
#
#
# Test set: Total loss: 0.722119, Accuracy: 0.378378
# Epoch: 109
# 	Average loss: 0.718680
# 	Accuracy: 0.404110
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.33      0.41        18
#          1.0       0.43      0.64      0.51        14
#
#     accuracy                           0.47        32
#    macro avg       0.49      0.49      0.46        32
# weighted avg       0.49      0.47      0.46        32
#
#
# Test set: Total loss: 0.699639, Accuracy: 0.459459
# Epoch: 110
# 	Average loss: 0.699459
# 	Accuracy: 0.458904
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.67      0.69        15
#          1.0       0.72      0.76      0.74        17
#
#     accuracy                           0.72        32
#    macro avg       0.72      0.72      0.72        32
# weighted avg       0.72      0.72      0.72        32
#
#
# Test set: Total loss: 0.699827, Accuracy: 0.459459
# Epoch: 111
# 	Average loss: 0.712789
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.53      0.46        15
#          1.0       0.42      0.29      0.34        17
#
#     accuracy                           0.41        32
#    macro avg       0.41      0.41      0.40        32
# weighted avg       0.41      0.41      0.40        32
#
#
# Test set: Total loss: 0.721395, Accuracy: 0.378378
# Epoch: 112
# 	Average loss: 0.707003
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.65      0.67        20
#          1.0       0.46      0.50      0.48        12
#
#     accuracy                           0.59        32
#    macro avg       0.57      0.57      0.57        32
# weighted avg       0.60      0.59      0.60        32
#
#
# Test set: Total loss: 0.731772, Accuracy: 0.351351
# Epoch: 113
# 	Average loss: 0.697929
# 	Accuracy: 0.479452
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.87      0.63        15
#          1.0       0.67      0.24      0.35        17
#
#     accuracy                           0.53        32
#    macro avg       0.58      0.55      0.49        32
# weighted avg       0.59      0.53      0.48        32
#
#
# Test set: Total loss: 0.738844, Accuracy: 0.324324
# Epoch: 114
# 	Average loss: 0.684055
# 	Accuracy: 0.500000
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.60      0.49        15
#          1.0       0.40      0.24      0.30        17
#
#     accuracy                           0.41        32
#    macro avg       0.40      0.42      0.39        32
# weighted avg       0.40      0.41      0.39        32
#
#
# Test set: Total loss: 0.735968, Accuracy: 0.378378
# Epoch: 115
# 	Average loss: 0.696053
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.56      0.56        16
#          1.0       0.56      0.56      0.56        16
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.56      0.56      0.56        32
#
#
# Test set: Total loss: 0.717586, Accuracy: 0.432432
# Epoch: 116
# 	Average loss: 0.692959
# 	Accuracy: 0.445205
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.71      0.69        17
#          1.0       0.64      0.60      0.62        15
#
#     accuracy                           0.66        32
#    macro avg       0.65      0.65      0.65        32
# weighted avg       0.66      0.66      0.66        32
#
#
# Test set: Total loss: 0.714968, Accuracy: 0.432432
# Epoch: 117
# 	Average loss: 0.698141
# 	Accuracy: 0.465753
#               precision    recall  f1-score   support
#
#          0.0       0.32      0.86      0.46         7
#          1.0       0.92      0.48      0.63        25
#
#     accuracy                           0.56        32
#    macro avg       0.62      0.67      0.55        32
# weighted avg       0.79      0.56      0.59        32
#
#
# Test set: Total loss: 0.738375, Accuracy: 0.324324
# Epoch: 118
# 	Average loss: 0.708767
# 	Accuracy: 0.431507
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.59      0.61        17
#          1.0       0.56      0.60      0.58        15
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Test set: Total loss: 0.753217, Accuracy: 0.351351
# Epoch: 119
# 	Average loss: 0.698427
# 	Accuracy: 0.452055
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.60      0.62        20
#          1.0       0.38      0.42      0.40        12
#
#     accuracy                           0.53        32
#    macro avg       0.51      0.51      0.51        32
# weighted avg       0.54      0.53      0.53        32
#
#
# Test set: Total loss: 0.763911, Accuracy: 0.378378

# %%
conv1 = list(CNNPoor.children())
print(conv1[1].weight.shape)
weight1 = conv1[1].weight.reshape((4,125)).data.numpy()
#weight2 = conv1[4].weight.reshape((16,7)).data.numpy()
# weight3 = conv1[9].weight.reshape((32,32)).data.numpy()
#weight4 = conv1[10].weight.reshape((16,32)).data.numpy()
# weight5 = conv1[16].weight.reshape((1,176)).data.numpy()
pyplot.figure(figsize=(20,10))
pyplot.imshow(weight1)

#pyplot.imshow(weight2)
#pyplot.imshow(weight3)
#pyplot.imshow(weight4)
# pyplot.imshow(weight5)
# Out:
# torch.Size([4, 1, 1, 125])

# %%
pyplot.plot(plots["train acc"], "royalblue", label = "train")
pyplot.plot(plots["test acc"], "darkorange", label = "test")
pyplot.title("accuracy over training")
pyplot.legend()
pyplot.show()

# %%
# tload = torch.utils.data.TensorDataset(X_train, X_actual)
# tloader = torch.utils.data.DataLoader(tload, batch_size = X_train.shape[0], shuffle = True)
# _, _, _, _ = test(CNNPoor, device, tloader)
_, _, _, _ = test(CNNPoor, device, test_loader)
# Out:
# Test set: Total loss: 0.763911, Accuracy: 0.378378
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# torch.save(CNNPoor.state_dict(), '/content/drive/Shared drives/NeuroTech ML/my_model.pt')

# %%
# import pickle

# pickle.dump(CNNPoor, open('model.pkl', 'wb'))
# # model = pickle.load(open('model.pkl', 'rb'))
