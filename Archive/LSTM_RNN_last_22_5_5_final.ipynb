# %% [markdown]
# ## Import Libraries
# Import necessary libraries for data processing, model building, and visualization (os, re, random, numpy, tensorflow, keras, scikit-learn, matplotlib, seaborn).

# %%
import os
import re
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.layers import Dropout, Conv2D, MaxPooling2D, BatchNormalization
from sklearn.model_selection import train_test_split
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# ## Set Hyperparameters and Filenames
# Define the hyperparameters of the dataset, including phonemes and classes. Load the training data and parse the filenames.

# %%
PHONEMES = ['_', 'h', 'j', 'l', 'n', 'r', 'w', 'y', 'ch', 'sh', 'ng', 'th(e)', 'th(in)', 'zh', 'wh', 'ā(r)', 'i(r)', 'o(r)', 'u(r)', 'ō', 'o', 'ōō', 'ow']
CLASSES = len(PHONEMES)

def get_files_with_prefix(directory, prefix):
    files = os.listdir(directory)
    filtered_files = [file for file in files if file.startswith(prefix)]
    return filtered_files

directory = "/content"
X_filename = get_files_with_prefix(directory, f"X_last22")[0]
y_filename = get_files_with_prefix(directory, f"y_last22")[0]

print(f"X_filename: {X_filename}")
print(f"y_filename: {y_filename}")
print(f"CLASSES: {CLASSES}")
# Out:
# X_filename: X_last22_1923_4_5_5_final.npy
# y_filename: y_last22_1923_4_5_5_final.npy
# CLASSES: 23

# %% [markdown]
# ## Parse Filename

# %%
def parse_filename(filename):
    # Regular expression pattern to extract the required information from the filename
    pattern = r"X_last22_(\d+)_(\d+)_(\d+)_\d+_final.npy"

    # Use regular expression to search and extract the required information
    match = re.search(pattern, filename)

    if match:
        num_examples = int(match.group(1))
        channels = int(match.group(2))
        size = int(match.group(3))

        return num_examples, channels, size
    else:
        raise ValueError("Invalid filename format")

NUM_EXAMPLES, CHANNELS, SIZE = parse_filename(X_filename)

print("NUM_EXAMPLES:", NUM_EXAMPLES)
print("channels:", CHANNELS)
print("size:", SIZE)
# Out:
# NUM_EXAMPLES: 1923
# channels: 4
# size: 5

# %% [markdown]
# ## Train/Test Split

# %%
# Load the training data
X_train_og = np.load(X_filename)
y_train_og = np.load(y_filename)

# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X_train_og, y_train_og, test_size=0.2, random_state=351)

# Prepare the data - N training examples, 4 channels (muscle groups) per example, each 100 timesteps long
X_train = X_train.reshape(-1, CHANNELS, SIZE)
X_test = X_test.reshape(-1, CHANNELS, SIZE)

print(f"X_train.shape: {X_train.shape} - {X_train.shape[0]} training examples")
print(f"X_test.shape: {X_test.shape} - {X_test.shape[0]} testing examples")
# Out:
# X_train.shape: (1538, 4, 5) - 1538 training examples
# X_test.shape: (385, 4, 5) - 385 testing examples

# %% [markdown]
# ## Original/Training/Test Set Distributions
# Print info about training example distrubtions across phonemes/classes.

# %%
# # UNCOMMENT FOR SET DISTRIBUTIONS

# # Count the occurrences of each class in the training set
# y_og_counts = Counter(y_train_og)

# # Count the occurrences of each class in the training set
# y_train_counts = Counter(y_train)

# # Count the occurrences of each class in the test set
# y_test_counts = Counter(y_test)

# # Print the occurrences
# print("Occurrences in the original set:")
# for phoneme_index, count in sorted(y_og_counts.items()):
#     print(f"\tPhoneme {PHONEMES[phoneme_index]}: {count}")

# print("Occurrences in the training set:")
# for phoneme_index, count in sorted(y_train_counts.items()):
#     print(f"\tPhoneme {PHONEMES[phoneme_index]}: {count}")

# print("Occurrences in the test set:")
# for phoneme_index, count in sorted(y_test_counts.items()):
#     print(f"\tPhoneme {PHONEMES[phoneme_index]}: {count}")

# %% [markdown]
# ## Define the Model
# Create a sequential model using various layers such as Conv1D, Dropout, LSTM, and Dense, then compile the model with loss, optimizer, and metrics.

# %%
# Define the model
model = tf.keras.Sequential([
    layers.Conv1D(256, 3, activation='relu', input_shape=(CHANNELS, SIZE), padding='same'),
    layers.Dropout(0.5),
    layers.Conv1D(256, 3, activation='relu', strides=2, padding='same'),
    layers.Dropout(0.5),
    layers.LSTM(256, return_sequences=True, kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.5),
    layers.LSTM(256, kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.5),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dense(CLASSES, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_28 (Conv1D)          (None, 4, 256)            4096
#
#  dropout_73 (Dropout)        (None, 4, 256)            0
#
#  conv1d_29 (Conv1D)          (None, 2, 256)            196864
#
#  dropout_74 (Dropout)        (None, 2, 256)            0
#
#  lstm_28 (LSTM)              (None, 2, 256)            525312
#
#  dropout_75 (Dropout)        (None, 2, 256)            0
#
#  lstm_29 (LSTM)              (None, 256)               525312
#
#  dropout_76 (Dropout)        (None, 256)               0
#
#  dense_45 (Dense)            (None, 256)               65792
#
#  dropout_77 (Dropout)        (None, 256)               0
#
#  dense_46 (Dense)            (None, 128)               32896
#
#  dropout_78 (Dropout)        (None, 128)               0
#
#  dense_47 (Dense)            (None, 128)               16512
#
#  dense_48 (Dense)            (None, 23)                2967
#
# =================================================================
# Total params: 1,369,751
# Trainable params: 1,369,751
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Define Early Stopping callback
# Define an EarlyStopping callback function to prevent overfitting.

# %%
# Define Early Stopping callback
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=250,
    mode='max',
    restore_best_weights=True
)

# %% [markdown]
# ## Train the Model
# Fit the model on the training data and validate it on the testing data using the early stopping callback.

# %%
# Train the model
history = model.fit(
    X_train,
    y_train,
    batch_size=64,
    epochs=2000,
    verbose=1,
    validation_data=(X_test, y_test),
    callbacks=[callback]
)
# Out:
# Epoch 1/2000
# 25/25 [==============================] - 10s 139ms/step - loss: 3.1923 - accuracy: 0.0494 - val_loss: 3.1564 - val_accuracy: 0.0442
# Epoch 2/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 3.0032 - accuracy: 0.0631 - val_loss: 2.8211 - val_accuracy: 0.1247
# Epoch 3/2000
# 25/25 [==============================] - 3s 128ms/step - loss: 2.8331 - accuracy: 0.1138 - val_loss: 2.7600 - val_accuracy: 0.1662
# Epoch 4/2000
# 25/25 [==============================] - 3s 124ms/step - loss: 2.6815 - accuracy: 0.1112 - val_loss: 2.5256 - val_accuracy: 0.1766
# Epoch 5/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 2.5292 - accuracy: 0.1164 - val_loss: 2.4162 - val_accuracy: 0.1662
# Epoch 6/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 2.4317 - accuracy: 0.1508 - val_loss: 2.3296 - val_accuracy: 0.2130
# Epoch 7/2000
# 25/25 [==============================] - 2s 87ms/step - loss: 2.3446 - accuracy: 0.1625 - val_loss: 2.1996 - val_accuracy: 0.2286
# Epoch 8/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 2.1781 - accuracy: 0.1853 - val_loss: 1.9252 - val_accuracy: 0.2649
# Epoch 9/2000
# 25/25 [==============================] - 3s 133ms/step - loss: 2.0142 - accuracy: 0.2094 - val_loss: 1.7699 - val_accuracy: 0.3117
# Epoch 10/2000
# 25/25 [==============================] - 3s 126ms/step - loss: 1.8695 - accuracy: 0.2302 - val_loss: 1.6521 - val_accuracy: 0.2727
# Epoch 11/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 1.7833 - accuracy: 0.2666 - val_loss: 1.5115 - val_accuracy: 0.3948
# Epoch 12/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 1.7358 - accuracy: 0.2783 - val_loss: 1.4485 - val_accuracy: 0.4000
# Epoch 13/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 1.6794 - accuracy: 0.2861 - val_loss: 1.4198 - val_accuracy: 0.4052
# Epoch 14/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 1.6362 - accuracy: 0.2900 - val_loss: 1.3779 - val_accuracy: 0.3948
# Epoch 15/2000
# 25/25 [==============================] - 3s 136ms/step - loss: 1.6256 - accuracy: 0.2796 - val_loss: 1.3516 - val_accuracy: 0.4286
# Epoch 16/2000
# 25/25 [==============================] - 3s 105ms/step - loss: 1.5706 - accuracy: 0.3179 - val_loss: 1.3255 - val_accuracy: 0.4623
# Epoch 17/2000
# 25/25 [==============================] - 2s 86ms/step - loss: 1.6084 - accuracy: 0.2991 - val_loss: 1.3855 - val_accuracy: 0.4130
# Epoch 18/2000
# 25/25 [==============================] - 2s 87ms/step - loss: 1.5516 - accuracy: 0.3095 - val_loss: 1.2719 - val_accuracy: 0.4831
# Epoch 19/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 1.4677 - accuracy: 0.3498 - val_loss: 1.2544 - val_accuracy: 0.4831
# Epoch 20/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 1.4799 - accuracy: 0.3401 - val_loss: 1.2396 - val_accuracy: 0.4104
# Epoch 21/2000
# 25/25 [==============================] - 3s 132ms/step - loss: 1.4635 - accuracy: 0.3401 - val_loss: 1.2181 - val_accuracy: 0.5351
# Epoch 22/2000
# 25/25 [==============================] - 3s 103ms/step - loss: 1.4466 - accuracy: 0.3609 - val_loss: 1.2118 - val_accuracy: 0.3948
# Epoch 23/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 1.4242 - accuracy: 0.3648 - val_loss: 1.1480 - val_accuracy: 0.3896
# Epoch 24/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 1.3861 - accuracy: 0.3589 - val_loss: 1.1191 - val_accuracy: 0.4338
# Epoch 25/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 1.3721 - accuracy: 0.3849 - val_loss: 1.0834 - val_accuracy: 0.5117
# Epoch 26/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 1.3373 - accuracy: 0.4070 - val_loss: 0.9862 - val_accuracy: 0.6000
# Epoch 27/2000
# 25/25 [==============================] - 4s 143ms/step - loss: 1.2961 - accuracy: 0.4246 - val_loss: 1.0315 - val_accuracy: 0.5506
# Epoch 28/2000
# 25/25 [==============================] - 3s 112ms/step - loss: 1.3149 - accuracy: 0.4012 - val_loss: 1.0050 - val_accuracy: 0.5740
# Epoch 29/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 1.2523 - accuracy: 0.4200 - val_loss: 0.9575 - val_accuracy: 0.5325
# Epoch 30/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 1.3129 - accuracy: 0.4194 - val_loss: 1.0401 - val_accuracy: 0.5143
# Epoch 31/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 1.3198 - accuracy: 0.4057 - val_loss: 1.0218 - val_accuracy: 0.5610
# Epoch 32/2000
# 25/25 [==============================] - 3s 108ms/step - loss: 1.2580 - accuracy: 0.4285 - val_loss: 0.9437 - val_accuracy: 0.6753
# Epoch 33/2000
# 25/25 [==============================] - 3s 130ms/step - loss: 1.2064 - accuracy: 0.4493 - val_loss: 0.9396 - val_accuracy: 0.5870
# Epoch 34/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 1.1820 - accuracy: 0.4532 - val_loss: 0.9317 - val_accuracy: 0.6052
# Epoch 35/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 1.2434 - accuracy: 0.4363 - val_loss: 0.9767 - val_accuracy: 0.4883
# Epoch 36/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 1.1876 - accuracy: 0.4707 - val_loss: 0.9480 - val_accuracy: 0.6416
# Epoch 37/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 1.1871 - accuracy: 0.4454 - val_loss: 0.9207 - val_accuracy: 0.5558
# Epoch 38/2000
# 25/25 [==============================] - 3s 108ms/step - loss: 1.1638 - accuracy: 0.4766 - val_loss: 0.8614 - val_accuracy: 0.5896
# Epoch 39/2000
# 25/25 [==============================] - 3s 136ms/step - loss: 1.1712 - accuracy: 0.4824 - val_loss: 0.8793 - val_accuracy: 0.6545
# Epoch 40/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 1.1785 - accuracy: 0.4525 - val_loss: 0.8767 - val_accuracy: 0.5948
# Epoch 41/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 1.1395 - accuracy: 0.4701 - val_loss: 0.8733 - val_accuracy: 0.5688
# Epoch 42/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 1.1085 - accuracy: 0.4779 - val_loss: 0.9041 - val_accuracy: 0.6779
# Epoch 43/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 1.1162 - accuracy: 0.4941 - val_loss: 0.8676 - val_accuracy: 0.6494
# Epoch 44/2000
# 25/25 [==============================] - 3s 116ms/step - loss: 1.1503 - accuracy: 0.4720 - val_loss: 0.8334 - val_accuracy: 0.7195
# Epoch 45/2000
# 25/25 [==============================] - 3s 131ms/step - loss: 1.0955 - accuracy: 0.5007 - val_loss: 0.8842 - val_accuracy: 0.5922
# Epoch 46/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 1.1066 - accuracy: 0.4941 - val_loss: 0.8604 - val_accuracy: 0.6442
# Epoch 47/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 1.1140 - accuracy: 0.4987 - val_loss: 0.8153 - val_accuracy: 0.6597
# Epoch 48/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 1.1559 - accuracy: 0.4850 - val_loss: 0.8526 - val_accuracy: 0.6156
# Epoch 49/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 1.0894 - accuracy: 0.5052 - val_loss: 0.7871 - val_accuracy: 0.7273
# Epoch 50/2000
# 25/25 [==============================] - 3s 123ms/step - loss: 1.0907 - accuracy: 0.5046 - val_loss: 0.7977 - val_accuracy: 0.6805
# Epoch 51/2000
# 25/25 [==============================] - 3s 128ms/step - loss: 1.0862 - accuracy: 0.5039 - val_loss: 0.7824 - val_accuracy: 0.6779
# Epoch 52/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 1.1259 - accuracy: 0.5091 - val_loss: 0.8482 - val_accuracy: 0.6052
# Epoch 53/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 1.0707 - accuracy: 0.5299 - val_loss: 0.7740 - val_accuracy: 0.6779
# Epoch 54/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 1.0250 - accuracy: 0.5384 - val_loss: 0.7791 - val_accuracy: 0.6623
# Epoch 55/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 1.0439 - accuracy: 0.5351 - val_loss: 0.7496 - val_accuracy: 0.7091
# Epoch 56/2000
# 25/25 [==============================] - 3s 131ms/step - loss: 0.9886 - accuracy: 0.5423 - val_loss: 0.7761 - val_accuracy: 0.6571
# Epoch 57/2000
# 25/25 [==============================] - 3s 123ms/step - loss: 0.9958 - accuracy: 0.5273 - val_loss: 0.7672 - val_accuracy: 0.6494
# Epoch 58/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 1.0337 - accuracy: 0.5338 - val_loss: 0.7562 - val_accuracy: 0.6675
# Epoch 59/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 1.0213 - accuracy: 0.5319 - val_loss: 0.7110 - val_accuracy: 0.7325
# Epoch 60/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.9923 - accuracy: 0.5520 - val_loss: 0.6987 - val_accuracy: 0.7247
# Epoch 61/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 1.0162 - accuracy: 0.5416 - val_loss: 0.7200 - val_accuracy: 0.7740
# Epoch 62/2000
# 25/25 [==============================] - 3s 127ms/step - loss: 0.9868 - accuracy: 0.5676 - val_loss: 0.7107 - val_accuracy: 0.7584
# Epoch 63/2000
# 25/25 [==============================] - 3s 126ms/step - loss: 0.9959 - accuracy: 0.5579 - val_loss: 0.7435 - val_accuracy: 0.6805
# Epoch 64/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 1.0714 - accuracy: 0.5403 - val_loss: 0.7325 - val_accuracy: 0.7039
# Epoch 65/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.9758 - accuracy: 0.5709 - val_loss: 0.7216 - val_accuracy: 0.6857
# Epoch 66/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 1.1222 - accuracy: 0.4961 - val_loss: 0.7404 - val_accuracy: 0.7299
# Epoch 67/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 1.0286 - accuracy: 0.5592 - val_loss: 0.7073 - val_accuracy: 0.7403
# Epoch 68/2000
# 25/25 [==============================] - 3s 128ms/step - loss: 1.0999 - accuracy: 0.5410 - val_loss: 0.7393 - val_accuracy: 0.6701
# Epoch 69/2000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.9942 - accuracy: 0.5540 - val_loss: 0.6441 - val_accuracy: 0.7221
# Epoch 70/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.9772 - accuracy: 0.5579 - val_loss: 0.7285 - val_accuracy: 0.6857
# Epoch 71/2000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.9560 - accuracy: 0.5735 - val_loss: 0.6443 - val_accuracy: 0.7870
# Epoch 72/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.9876 - accuracy: 0.5858 - val_loss: 0.6237 - val_accuracy: 0.7429
# Epoch 73/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.9554 - accuracy: 0.5852 - val_loss: 0.6437 - val_accuracy: 0.7169
# Epoch 74/2000
# 25/25 [==============================] - 3s 136ms/step - loss: 0.9640 - accuracy: 0.5806 - val_loss: 0.6730 - val_accuracy: 0.7351
# Epoch 75/2000
# 25/25 [==============================] - 3s 123ms/step - loss: 0.9660 - accuracy: 0.5468 - val_loss: 0.6560 - val_accuracy: 0.7221
# Epoch 76/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.9111 - accuracy: 0.5917 - val_loss: 0.7204 - val_accuracy: 0.6701
# Epoch 77/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 1.0570 - accuracy: 0.5650 - val_loss: 0.6805 - val_accuracy: 0.7610
# Epoch 78/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 1.0094 - accuracy: 0.5540 - val_loss: 0.6769 - val_accuracy: 0.7299
# Epoch 79/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.9781 - accuracy: 0.5728 - val_loss: 0.6633 - val_accuracy: 0.7455
# Epoch 80/2000
# 25/25 [==============================] - 3s 130ms/step - loss: 0.9081 - accuracy: 0.6079 - val_loss: 0.6186 - val_accuracy: 0.7610
# Epoch 81/2000
# 25/25 [==============================] - 3s 108ms/step - loss: 0.9515 - accuracy: 0.5767 - val_loss: 0.6311 - val_accuracy: 0.7766
# Epoch 82/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.8713 - accuracy: 0.5936 - val_loss: 0.5675 - val_accuracy: 0.8260
# Epoch 83/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.8370 - accuracy: 0.6333 - val_loss: 0.6233 - val_accuracy: 0.8078
# Epoch 84/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.9437 - accuracy: 0.5930 - val_loss: 0.6524 - val_accuracy: 0.7740
# Epoch 85/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 1.0603 - accuracy: 0.5475 - val_loss: 0.7142 - val_accuracy: 0.6442
# Epoch 86/2000
# 25/25 [==============================] - 3s 135ms/step - loss: 0.9624 - accuracy: 0.5676 - val_loss: 0.6541 - val_accuracy: 0.7610
# Epoch 87/2000
# 25/25 [==============================] - 3s 112ms/step - loss: 1.1314 - accuracy: 0.5156 - val_loss: 0.7136 - val_accuracy: 0.6416
# Epoch 88/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.9550 - accuracy: 0.5748 - val_loss: 0.7090 - val_accuracy: 0.7558
# Epoch 89/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.8861 - accuracy: 0.6034 - val_loss: 0.6187 - val_accuracy: 0.7636
# Epoch 90/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.8646 - accuracy: 0.6099 - val_loss: 0.6022 - val_accuracy: 0.7143
# Epoch 91/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.8362 - accuracy: 0.6261 - val_loss: 0.5665 - val_accuracy: 0.8156
# Epoch 92/2000
# 25/25 [==============================] - 3s 136ms/step - loss: 0.8532 - accuracy: 0.6281 - val_loss: 0.5765 - val_accuracy: 0.7870
# Epoch 93/2000
# 25/25 [==============================] - 3s 107ms/step - loss: 0.8315 - accuracy: 0.6307 - val_loss: 0.5771 - val_accuracy: 0.7558
# Epoch 94/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.8247 - accuracy: 0.6274 - val_loss: 0.6008 - val_accuracy: 0.7922
# Epoch 95/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.8143 - accuracy: 0.6476 - val_loss: 0.5550 - val_accuracy: 0.7584
# Epoch 96/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.8381 - accuracy: 0.6417 - val_loss: 0.5695 - val_accuracy: 0.7662
# Epoch 97/2000
# 25/25 [==============================] - 3s 114ms/step - loss: 0.8110 - accuracy: 0.6508 - val_loss: 0.5641 - val_accuracy: 0.7610
# Epoch 98/2000
# 25/25 [==============================] - 3s 139ms/step - loss: 0.7885 - accuracy: 0.6463 - val_loss: 0.5560 - val_accuracy: 0.7870
# Epoch 99/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.8051 - accuracy: 0.6547 - val_loss: 0.5390 - val_accuracy: 0.8182
# Epoch 100/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.7714 - accuracy: 0.6534 - val_loss: 0.5086 - val_accuracy: 0.8286
# Epoch 101/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.8748 - accuracy: 0.6131 - val_loss: 0.5898 - val_accuracy: 0.7506
# Epoch 102/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.8637 - accuracy: 0.6313 - val_loss: 0.5547 - val_accuracy: 0.8442
# Epoch 103/2000
# 25/25 [==============================] - 3s 109ms/step - loss: 0.8294 - accuracy: 0.6274 - val_loss: 0.5454 - val_accuracy: 0.8260
# Epoch 104/2000
# 25/25 [==============================] - 3s 129ms/step - loss: 0.7984 - accuracy: 0.6528 - val_loss: 0.5430 - val_accuracy: 0.7870
# Epoch 105/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.8191 - accuracy: 0.6281 - val_loss: 0.5231 - val_accuracy: 0.8000
# Epoch 106/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.7894 - accuracy: 0.6385 - val_loss: 0.5322 - val_accuracy: 0.8208
# Epoch 107/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.7667 - accuracy: 0.6573 - val_loss: 0.5072 - val_accuracy: 0.8182
# Epoch 108/2000
# 25/25 [==============================] - 2s 87ms/step - loss: 0.7792 - accuracy: 0.6567 - val_loss: 0.5458 - val_accuracy: 0.8416
# Epoch 109/2000
# 25/25 [==============================] - 3s 105ms/step - loss: 0.7604 - accuracy: 0.6769 - val_loss: 0.5071 - val_accuracy: 0.7870
# Epoch 110/2000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.7516 - accuracy: 0.6886 - val_loss: 0.5134 - val_accuracy: 0.8312
# Epoch 111/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.7584 - accuracy: 0.6664 - val_loss: 0.5531 - val_accuracy: 0.7221
# Epoch 112/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.7379 - accuracy: 0.6743 - val_loss: 0.4896 - val_accuracy: 0.8104
# Epoch 113/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.7426 - accuracy: 0.6775 - val_loss: 0.4724 - val_accuracy: 0.8182
# Epoch 114/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.7338 - accuracy: 0.7016 - val_loss: 0.4783 - val_accuracy: 0.8052
# Epoch 115/2000
# 25/25 [==============================] - 3s 104ms/step - loss: 0.7299 - accuracy: 0.6743 - val_loss: 0.4830 - val_accuracy: 0.8494
# Epoch 116/2000
# 25/25 [==============================] - 3s 130ms/step - loss: 0.7253 - accuracy: 0.7009 - val_loss: 0.4922 - val_accuracy: 0.8234
# Epoch 117/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.7431 - accuracy: 0.6788 - val_loss: 0.4685 - val_accuracy: 0.8545
# Epoch 118/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.7674 - accuracy: 0.6645 - val_loss: 0.5125 - val_accuracy: 0.8545
# Epoch 119/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.7186 - accuracy: 0.7003 - val_loss: 0.5079 - val_accuracy: 0.8260
# Epoch 120/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.7028 - accuracy: 0.6860 - val_loss: 0.4750 - val_accuracy: 0.8286
# Epoch 121/2000
# 25/25 [==============================] - 3s 103ms/step - loss: 0.7057 - accuracy: 0.6892 - val_loss: 0.4729 - val_accuracy: 0.8260
# Epoch 122/2000
# 25/25 [==============================] - 3s 135ms/step - loss: 0.7817 - accuracy: 0.6743 - val_loss: 0.4843 - val_accuracy: 0.8519
# Epoch 123/2000
# 25/25 [==============================] - 3s 99ms/step - loss: 0.6971 - accuracy: 0.6847 - val_loss: 0.5050 - val_accuracy: 0.8312
# Epoch 124/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.7306 - accuracy: 0.6860 - val_loss: 0.4864 - val_accuracy: 0.7922
# Epoch 125/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.7221 - accuracy: 0.6821 - val_loss: 0.4923 - val_accuracy: 0.8104
# Epoch 126/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.8024 - accuracy: 0.6619 - val_loss: 0.4817 - val_accuracy: 0.8442
# Epoch 127/2000
# 25/25 [==============================] - 3s 105ms/step - loss: 0.7948 - accuracy: 0.6476 - val_loss: 0.5415 - val_accuracy: 0.7714
# Epoch 128/2000
# 25/25 [==============================] - 3s 131ms/step - loss: 0.7586 - accuracy: 0.6736 - val_loss: 0.4771 - val_accuracy: 0.8597
# Epoch 129/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.6909 - accuracy: 0.7074 - val_loss: 0.4652 - val_accuracy: 0.8182
# Epoch 130/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.6988 - accuracy: 0.7042 - val_loss: 0.4598 - val_accuracy: 0.8416
# Epoch 131/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.7007 - accuracy: 0.6990 - val_loss: 0.4722 - val_accuracy: 0.8494
# Epoch 132/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.7328 - accuracy: 0.6866 - val_loss: 0.5043 - val_accuracy: 0.7506
# Epoch 133/2000
# 25/25 [==============================] - 3s 106ms/step - loss: 0.8656 - accuracy: 0.6534 - val_loss: 0.5197 - val_accuracy: 0.8182
# Epoch 134/2000
# 25/25 [==============================] - 3s 136ms/step - loss: 0.7443 - accuracy: 0.6983 - val_loss: 0.4927 - val_accuracy: 0.8364
# Epoch 135/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.7929 - accuracy: 0.6632 - val_loss: 0.5120 - val_accuracy: 0.8260
# Epoch 136/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.8470 - accuracy: 0.6450 - val_loss: 0.5639 - val_accuracy: 0.8364
# Epoch 137/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.7293 - accuracy: 0.6886 - val_loss: 0.4860 - val_accuracy: 0.8519
# Epoch 138/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.7706 - accuracy: 0.6547 - val_loss: 0.4939 - val_accuracy: 0.8727
# Epoch 139/2000
# 25/25 [==============================] - 3s 106ms/step - loss: 0.8077 - accuracy: 0.6586 - val_loss: 0.5102 - val_accuracy: 0.8208
# Epoch 140/2000
# 25/25 [==============================] - 3s 130ms/step - loss: 0.7346 - accuracy: 0.6957 - val_loss: 0.5092 - val_accuracy: 0.7922
# Epoch 141/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.7316 - accuracy: 0.6730 - val_loss: 0.5097 - val_accuracy: 0.8234
# Epoch 142/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.6727 - accuracy: 0.7035 - val_loss: 0.4895 - val_accuracy: 0.9065
# Epoch 143/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.6774 - accuracy: 0.7009 - val_loss: 0.4916 - val_accuracy: 0.7792
# Epoch 144/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.6765 - accuracy: 0.7048 - val_loss: 0.4551 - val_accuracy: 0.8364
# Epoch 145/2000
# 25/25 [==============================] - 3s 104ms/step - loss: 0.6657 - accuracy: 0.7263 - val_loss: 0.4657 - val_accuracy: 0.8364
# Epoch 146/2000
# 25/25 [==============================] - 3s 133ms/step - loss: 0.6819 - accuracy: 0.7074 - val_loss: 0.5120 - val_accuracy: 0.7584
# Epoch 147/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.7853 - accuracy: 0.6769 - val_loss: 0.5064 - val_accuracy: 0.8805
# Epoch 148/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.7727 - accuracy: 0.6918 - val_loss: 0.5105 - val_accuracy: 0.7896
# Epoch 149/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.7327 - accuracy: 0.6990 - val_loss: 0.5093 - val_accuracy: 0.8416
# Epoch 150/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.7732 - accuracy: 0.6645 - val_loss: 0.5108 - val_accuracy: 0.8182
# Epoch 151/2000
# 25/25 [==============================] - 3s 106ms/step - loss: 0.6827 - accuracy: 0.7165 - val_loss: 0.4726 - val_accuracy: 0.8364
# Epoch 152/2000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.8265 - accuracy: 0.6586 - val_loss: 0.5168 - val_accuracy: 0.8052
# Epoch 153/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.7217 - accuracy: 0.6860 - val_loss: 0.4742 - val_accuracy: 0.8545
# Epoch 154/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.7159 - accuracy: 0.6925 - val_loss: 0.4515 - val_accuracy: 0.9117
# Epoch 155/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.7313 - accuracy: 0.7035 - val_loss: 0.4490 - val_accuracy: 0.8779
# Epoch 156/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.6947 - accuracy: 0.7029 - val_loss: 0.4634 - val_accuracy: 0.8390
# Epoch 157/2000
# 25/25 [==============================] - 3s 112ms/step - loss: 0.6797 - accuracy: 0.7152 - val_loss: 0.4338 - val_accuracy: 0.8857
# Epoch 158/2000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.6650 - accuracy: 0.7074 - val_loss: 0.4517 - val_accuracy: 0.8442
# Epoch 159/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.6965 - accuracy: 0.7107 - val_loss: 0.4226 - val_accuracy: 0.9481
# Epoch 160/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.6303 - accuracy: 0.7315 - val_loss: 0.4330 - val_accuracy: 0.8260
# Epoch 161/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.6286 - accuracy: 0.7321 - val_loss: 0.4201 - val_accuracy: 0.8545
# Epoch 162/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.6517 - accuracy: 0.7237 - val_loss: 0.4205 - val_accuracy: 0.8753
# Epoch 163/2000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.6267 - accuracy: 0.7237 - val_loss: 0.4374 - val_accuracy: 0.8104
# Epoch 164/2000
# 25/25 [==============================] - 3s 129ms/step - loss: 0.6257 - accuracy: 0.7380 - val_loss: 0.4244 - val_accuracy: 0.8701
# Epoch 165/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.6239 - accuracy: 0.7406 - val_loss: 0.4082 - val_accuracy: 0.8805
# Epoch 166/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.6471 - accuracy: 0.7393 - val_loss: 0.5005 - val_accuracy: 0.7714
# Epoch 167/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.7185 - accuracy: 0.7087 - val_loss: 0.4483 - val_accuracy: 0.8052
# Epoch 168/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.6563 - accuracy: 0.7230 - val_loss: 0.4222 - val_accuracy: 0.8675
# Epoch 169/2000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.6930 - accuracy: 0.7107 - val_loss: 0.4629 - val_accuracy: 0.8026
# Epoch 170/2000
# 25/25 [==============================] - 3s 127ms/step - loss: 0.7174 - accuracy: 0.7035 - val_loss: 0.4909 - val_accuracy: 0.7948
# Epoch 171/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.6743 - accuracy: 0.7009 - val_loss: 0.4949 - val_accuracy: 0.7948
# Epoch 172/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.8866 - accuracy: 0.6599 - val_loss: 0.5147 - val_accuracy: 0.7870
# Epoch 173/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.7275 - accuracy: 0.6964 - val_loss: 0.4658 - val_accuracy: 0.8597
# Epoch 174/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.6723 - accuracy: 0.7074 - val_loss: 0.4411 - val_accuracy: 0.8519
# Epoch 175/2000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.6626 - accuracy: 0.7211 - val_loss: 0.4109 - val_accuracy: 0.8779
# Epoch 176/2000
# 25/25 [==============================] - 3s 129ms/step - loss: 0.6133 - accuracy: 0.7503 - val_loss: 0.3917 - val_accuracy: 0.8727
# Epoch 177/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.6230 - accuracy: 0.7347 - val_loss: 0.4179 - val_accuracy: 0.8312
# Epoch 178/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.6766 - accuracy: 0.7185 - val_loss: 0.4715 - val_accuracy: 0.8026
# Epoch 179/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.7755 - accuracy: 0.6970 - val_loss: 0.4812 - val_accuracy: 0.8727
# Epoch 180/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.8152 - accuracy: 0.6834 - val_loss: 0.4778 - val_accuracy: 0.8182
# Epoch 181/2000
# 25/25 [==============================] - 3s 122ms/step - loss: 0.6900 - accuracy: 0.7198 - val_loss: 0.4571 - val_accuracy: 0.8597
# Epoch 182/2000
# 25/25 [==============================] - 3s 129ms/step - loss: 0.6579 - accuracy: 0.7315 - val_loss: 0.4294 - val_accuracy: 0.8753
# Epoch 183/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.6509 - accuracy: 0.7386 - val_loss: 0.4130 - val_accuracy: 0.8935
# Epoch 184/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.7450 - accuracy: 0.7191 - val_loss: 0.4392 - val_accuracy: 0.8286
# Epoch 185/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.6686 - accuracy: 0.7334 - val_loss: 0.4176 - val_accuracy: 0.8442
# Epoch 186/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.6346 - accuracy: 0.7438 - val_loss: 0.3838 - val_accuracy: 0.8987
# Epoch 187/2000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.7274 - accuracy: 0.7087 - val_loss: 0.4256 - val_accuracy: 0.7870
# Epoch 188/2000
# 25/25 [==============================] - 3s 121ms/step - loss: 0.6180 - accuracy: 0.7497 - val_loss: 0.3948 - val_accuracy: 0.8597
# Epoch 189/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.5942 - accuracy: 0.7685 - val_loss: 0.3724 - val_accuracy: 0.8883
# Epoch 190/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.6248 - accuracy: 0.7451 - val_loss: 0.3782 - val_accuracy: 0.9013
# Epoch 191/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.6257 - accuracy: 0.7510 - val_loss: 0.3987 - val_accuracy: 0.8571
# Epoch 192/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.6319 - accuracy: 0.7412 - val_loss: 0.3986 - val_accuracy: 0.9013
# Epoch 193/2000
# 25/25 [==============================] - 4s 142ms/step - loss: 0.6080 - accuracy: 0.7568 - val_loss: 0.3729 - val_accuracy: 0.9039
# Epoch 194/2000
# 25/25 [==============================] - 3s 113ms/step - loss: 0.5850 - accuracy: 0.7685 - val_loss: 0.3736 - val_accuracy: 0.9143
# Epoch 195/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.5671 - accuracy: 0.7802 - val_loss: 0.3808 - val_accuracy: 0.9143
# Epoch 196/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.6067 - accuracy: 0.7692 - val_loss: 0.3824 - val_accuracy: 0.8649
# Epoch 197/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.7798 - accuracy: 0.7237 - val_loss: 0.3995 - val_accuracy: 0.9325
# Epoch 198/2000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.7252 - accuracy: 0.7048 - val_loss: 0.4053 - val_accuracy: 0.8571
# Epoch 199/2000
# 25/25 [==============================] - 4s 142ms/step - loss: 0.6201 - accuracy: 0.7386 - val_loss: 0.3939 - val_accuracy: 0.8494
# Epoch 200/2000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.7126 - accuracy: 0.7224 - val_loss: 0.4482 - val_accuracy: 0.8416
# Epoch 201/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.7230 - accuracy: 0.6996 - val_loss: 0.4063 - val_accuracy: 0.8727
# Epoch 202/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.6482 - accuracy: 0.7321 - val_loss: 0.4072 - val_accuracy: 0.8545
# Epoch 203/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.5850 - accuracy: 0.7614 - val_loss: 0.3918 - val_accuracy: 0.8961
# Epoch 204/2000
# 25/25 [==============================] - 3s 122ms/step - loss: 0.5906 - accuracy: 0.7601 - val_loss: 0.3846 - val_accuracy: 0.8779
# Epoch 205/2000
# 25/25 [==============================] - 3s 136ms/step - loss: 0.5556 - accuracy: 0.7757 - val_loss: 0.3848 - val_accuracy: 0.8935
# Epoch 206/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.8446 - accuracy: 0.7126 - val_loss: 0.4042 - val_accuracy: 0.8649
# Epoch 207/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.6377 - accuracy: 0.7412 - val_loss: 0.3930 - val_accuracy: 0.8805
# Epoch 208/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.6165 - accuracy: 0.7640 - val_loss: 0.3858 - val_accuracy: 0.9221
# Epoch 209/2000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.6316 - accuracy: 0.7685 - val_loss: 0.4005 - val_accuracy: 0.8519
# Epoch 210/2000
# 25/25 [==============================] - 3s 123ms/step - loss: 0.6468 - accuracy: 0.7477 - val_loss: 0.4022 - val_accuracy: 0.8571
# Epoch 211/2000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.7093 - accuracy: 0.7419 - val_loss: 0.4563 - val_accuracy: 0.9091
# Epoch 212/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.6600 - accuracy: 0.7399 - val_loss: 0.4047 - val_accuracy: 0.8519
# Epoch 213/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.6370 - accuracy: 0.7399 - val_loss: 0.4270 - val_accuracy: 0.8701
# Epoch 214/2000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.6165 - accuracy: 0.7523 - val_loss: 0.4082 - val_accuracy: 0.8442
# Epoch 215/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.5977 - accuracy: 0.7718 - val_loss: 0.3850 - val_accuracy: 0.9091
# Epoch 216/2000
# 25/25 [==============================] - 3s 136ms/step - loss: 0.6026 - accuracy: 0.7562 - val_loss: 0.3989 - val_accuracy: 0.8442
# Epoch 217/2000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.6033 - accuracy: 0.7555 - val_loss: 0.3958 - val_accuracy: 0.8494
# Epoch 218/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.5579 - accuracy: 0.7737 - val_loss: 0.3862 - val_accuracy: 0.8935
# Epoch 219/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.5840 - accuracy: 0.7763 - val_loss: 0.3748 - val_accuracy: 0.9091
# Epoch 220/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.5523 - accuracy: 0.7763 - val_loss: 0.3664 - val_accuracy: 0.8727
# Epoch 221/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.6186 - accuracy: 0.7445 - val_loss: 0.4082 - val_accuracy: 0.8909
# Epoch 222/2000
# 25/25 [==============================] - 3s 137ms/step - loss: 0.5702 - accuracy: 0.7666 - val_loss: 0.4005 - val_accuracy: 0.8442
# Epoch 223/2000
# 25/25 [==============================] - 3s 114ms/step - loss: 0.5632 - accuracy: 0.7711 - val_loss: 0.3843 - val_accuracy: 0.8805
# Epoch 224/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.5692 - accuracy: 0.7822 - val_loss: 0.3800 - val_accuracy: 0.8545
# Epoch 225/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.5519 - accuracy: 0.7965 - val_loss: 0.3569 - val_accuracy: 0.9091
# Epoch 226/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.5357 - accuracy: 0.7997 - val_loss: 0.3906 - val_accuracy: 0.8779
# Epoch 227/2000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.5565 - accuracy: 0.7900 - val_loss: 0.3573 - val_accuracy: 0.8649
# Epoch 228/2000
# 25/25 [==============================] - 3s 137ms/step - loss: 0.5417 - accuracy: 0.7906 - val_loss: 0.3625 - val_accuracy: 0.8545
# Epoch 229/2000
# 25/25 [==============================] - 3s 108ms/step - loss: 0.5845 - accuracy: 0.7861 - val_loss: 0.3432 - val_accuracy: 0.8857
# Epoch 230/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.5372 - accuracy: 0.7750 - val_loss: 0.3437 - val_accuracy: 0.9532
# Epoch 231/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.5475 - accuracy: 0.7952 - val_loss: 0.3407 - val_accuracy: 0.8935
# Epoch 232/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.5277 - accuracy: 0.7978 - val_loss: 0.3528 - val_accuracy: 0.9195
# Epoch 233/2000
# 25/25 [==============================] - 3s 106ms/step - loss: 0.5194 - accuracy: 0.8043 - val_loss: 0.3472 - val_accuracy: 0.8701
# Epoch 234/2000
# 25/25 [==============================] - 3s 138ms/step - loss: 0.5752 - accuracy: 0.7841 - val_loss: 0.3381 - val_accuracy: 0.9273
# Epoch 235/2000
# 25/25 [==============================] - 3s 103ms/step - loss: 0.6244 - accuracy: 0.7692 - val_loss: 0.4126 - val_accuracy: 0.9221
# Epoch 236/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.6495 - accuracy: 0.7588 - val_loss: 0.3956 - val_accuracy: 0.8390
# Epoch 237/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.6906 - accuracy: 0.7373 - val_loss: 0.3859 - val_accuracy: 0.9117
# Epoch 238/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.5682 - accuracy: 0.7932 - val_loss: 0.3451 - val_accuracy: 0.9013
# Epoch 239/2000
# 25/25 [==============================] - 3s 114ms/step - loss: 0.5449 - accuracy: 0.8010 - val_loss: 0.3160 - val_accuracy: 0.9481
# Epoch 240/2000
# 25/25 [==============================] - 3s 138ms/step - loss: 0.5502 - accuracy: 0.7952 - val_loss: 0.3015 - val_accuracy: 0.9481
# Epoch 241/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.5302 - accuracy: 0.7958 - val_loss: 0.3247 - val_accuracy: 0.9506
# Epoch 242/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.5798 - accuracy: 0.7783 - val_loss: 0.3632 - val_accuracy: 0.8468
# Epoch 243/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.5482 - accuracy: 0.7874 - val_loss: 0.3389 - val_accuracy: 0.8727
# Epoch 244/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.5595 - accuracy: 0.7796 - val_loss: 0.3709 - val_accuracy: 0.8571
# Epoch 245/2000
# 25/25 [==============================] - 3s 117ms/step - loss: 0.6112 - accuracy: 0.7659 - val_loss: 0.3593 - val_accuracy: 0.8831
# Epoch 246/2000
# 25/25 [==============================] - 3s 135ms/step - loss: 0.5751 - accuracy: 0.7919 - val_loss: 0.3132 - val_accuracy: 0.9636
# Epoch 247/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.5207 - accuracy: 0.8043 - val_loss: 0.3536 - val_accuracy: 0.8442
# Epoch 248/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.5335 - accuracy: 0.7835 - val_loss: 0.3256 - val_accuracy: 0.8545
# Epoch 249/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.5390 - accuracy: 0.7789 - val_loss: 0.3444 - val_accuracy: 0.9065
# Epoch 250/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.5641 - accuracy: 0.7783 - val_loss: 0.3498 - val_accuracy: 0.8442
# Epoch 251/2000
# 25/25 [==============================] - 3s 131ms/step - loss: 0.5523 - accuracy: 0.7874 - val_loss: 0.3372 - val_accuracy: 0.9247
# Epoch 252/2000
# 25/25 [==============================] - 3s 126ms/step - loss: 0.5295 - accuracy: 0.7809 - val_loss: 0.3207 - val_accuracy: 0.9195
# Epoch 253/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.4944 - accuracy: 0.8101 - val_loss: 0.3194 - val_accuracy: 0.9013
# Epoch 254/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.5766 - accuracy: 0.7776 - val_loss: 0.3403 - val_accuracy: 0.8883
# Epoch 255/2000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.5757 - accuracy: 0.7770 - val_loss: 0.3351 - val_accuracy: 0.8519
# Epoch 256/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.5811 - accuracy: 0.7893 - val_loss: 0.3504 - val_accuracy: 0.8519
# Epoch 257/2000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.5270 - accuracy: 0.7965 - val_loss: 0.2992 - val_accuracy: 0.9299
# Epoch 258/2000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.4671 - accuracy: 0.8257 - val_loss: 0.2772 - val_accuracy: 0.9506
# Epoch 259/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.5286 - accuracy: 0.8108 - val_loss: 0.2839 - val_accuracy: 0.9013
# Epoch 260/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.5163 - accuracy: 0.8121 - val_loss: 0.3067 - val_accuracy: 0.9247
# Epoch 261/2000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.5347 - accuracy: 0.7965 - val_loss: 0.3140 - val_accuracy: 0.8623
# Epoch 262/2000
# 25/25 [==============================] - 3s 107ms/step - loss: 0.5066 - accuracy: 0.7984 - val_loss: 0.2862 - val_accuracy: 0.9429
# Epoch 263/2000
# 25/25 [==============================] - 3s 136ms/step - loss: 0.5682 - accuracy: 0.7952 - val_loss: 0.3028 - val_accuracy: 0.9532
# Epoch 264/2000
# 25/25 [==============================] - 3s 108ms/step - loss: 0.4984 - accuracy: 0.8030 - val_loss: 0.3336 - val_accuracy: 0.9091
# Epoch 265/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.4924 - accuracy: 0.8062 - val_loss: 0.2777 - val_accuracy: 0.9584
# Epoch 266/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.4831 - accuracy: 0.8108 - val_loss: 0.2597 - val_accuracy: 0.9377
# Epoch 267/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.5101 - accuracy: 0.8127 - val_loss: 0.2663 - val_accuracy: 0.9455
# Epoch 268/2000
# 25/25 [==============================] - 3s 109ms/step - loss: 0.4798 - accuracy: 0.8238 - val_loss: 0.2554 - val_accuracy: 0.9558
# Epoch 269/2000
# 25/25 [==============================] - 3s 138ms/step - loss: 0.4727 - accuracy: 0.8251 - val_loss: 0.2489 - val_accuracy: 0.9844
# Epoch 270/2000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.4394 - accuracy: 0.8257 - val_loss: 0.2452 - val_accuracy: 0.9506
# Epoch 271/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.5025 - accuracy: 0.8173 - val_loss: 0.2672 - val_accuracy: 0.8987
# Epoch 272/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.5144 - accuracy: 0.8056 - val_loss: 0.2849 - val_accuracy: 0.9351
# Epoch 273/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.5219 - accuracy: 0.8127 - val_loss: 0.2755 - val_accuracy: 0.9403
# Epoch 274/2000
# 25/25 [==============================] - 3s 119ms/step - loss: 0.4451 - accuracy: 0.8342 - val_loss: 0.2826 - val_accuracy: 0.8857
# Epoch 275/2000
# 25/25 [==============================] - 3s 137ms/step - loss: 0.4904 - accuracy: 0.8205 - val_loss: 0.2539 - val_accuracy: 0.9013
# Epoch 276/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.4341 - accuracy: 0.8524 - val_loss: 0.2322 - val_accuracy: 0.9610
# Epoch 277/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.4900 - accuracy: 0.8095 - val_loss: 0.2819 - val_accuracy: 0.8701
# Epoch 278/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.5219 - accuracy: 0.8049 - val_loss: 0.2516 - val_accuracy: 0.9247
# Epoch 279/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.4779 - accuracy: 0.8101 - val_loss: 0.2490 - val_accuracy: 0.9169
# Epoch 280/2000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.5151 - accuracy: 0.8231 - val_loss: 0.2412 - val_accuracy: 0.9532
# Epoch 281/2000
# 25/25 [==============================] - 3s 133ms/step - loss: 0.4494 - accuracy: 0.8342 - val_loss: 0.2829 - val_accuracy: 0.9273
# Epoch 282/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.5027 - accuracy: 0.8121 - val_loss: 0.2748 - val_accuracy: 0.8935
# Epoch 283/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.4793 - accuracy: 0.8322 - val_loss: 0.2801 - val_accuracy: 0.9377
# Epoch 284/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.4871 - accuracy: 0.8238 - val_loss: 0.2553 - val_accuracy: 0.9506
# Epoch 285/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.5539 - accuracy: 0.8023 - val_loss: 0.3157 - val_accuracy: 0.8779
# Epoch 286/2000
# 25/25 [==============================] - 3s 137ms/step - loss: 0.5208 - accuracy: 0.8095 - val_loss: 0.2663 - val_accuracy: 0.9351
# Epoch 287/2000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.4887 - accuracy: 0.8212 - val_loss: 0.3008 - val_accuracy: 0.9325
# Epoch 288/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.4927 - accuracy: 0.8134 - val_loss: 0.2973 - val_accuracy: 0.9013
# Epoch 289/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.4566 - accuracy: 0.8270 - val_loss: 0.2662 - val_accuracy: 0.9221
# Epoch 290/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.5352 - accuracy: 0.8212 - val_loss: 0.2693 - val_accuracy: 0.9662
# Epoch 291/2000
# 25/25 [==============================] - 3s 100ms/step - loss: 0.4983 - accuracy: 0.8108 - val_loss: 0.3321 - val_accuracy: 0.8649
# Epoch 292/2000
# 25/25 [==============================] - 3s 136ms/step - loss: 0.4829 - accuracy: 0.8231 - val_loss: 0.2749 - val_accuracy: 0.9013
# Epoch 293/2000
# 25/25 [==============================] - 3s 110ms/step - loss: 0.5085 - accuracy: 0.7861 - val_loss: 0.3167 - val_accuracy: 0.8649
# Epoch 294/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.5122 - accuracy: 0.8127 - val_loss: 0.2666 - val_accuracy: 0.9662
# Epoch 295/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.4802 - accuracy: 0.8147 - val_loss: 0.3060 - val_accuracy: 0.9455
# Epoch 296/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.4498 - accuracy: 0.8303 - val_loss: 0.2767 - val_accuracy: 0.9247
# Epoch 297/2000
# 25/25 [==============================] - 3s 119ms/step - loss: 0.5163 - accuracy: 0.8088 - val_loss: 0.3041 - val_accuracy: 0.9377
# Epoch 298/2000
# 25/25 [==============================] - 4s 144ms/step - loss: 0.5138 - accuracy: 0.8010 - val_loss: 0.2629 - val_accuracy: 0.9117
# Epoch 299/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.5476 - accuracy: 0.7978 - val_loss: 0.2773 - val_accuracy: 0.9065
# Epoch 300/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.7049 - accuracy: 0.7711 - val_loss: 0.2978 - val_accuracy: 0.9688
# Epoch 301/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.5561 - accuracy: 0.7919 - val_loss: 0.2877 - val_accuracy: 0.9558
# Epoch 302/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.5106 - accuracy: 0.8095 - val_loss: 0.2671 - val_accuracy: 0.9584
# Epoch 303/2000
# 25/25 [==============================] - 3s 123ms/step - loss: 0.5261 - accuracy: 0.8010 - val_loss: 0.2625 - val_accuracy: 0.9481
# Epoch 304/2000
# 25/25 [==============================] - 3s 130ms/step - loss: 0.5062 - accuracy: 0.8199 - val_loss: 0.2656 - val_accuracy: 0.9221
# Epoch 305/2000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.4940 - accuracy: 0.8218 - val_loss: 0.2443 - val_accuracy: 0.9740
# Epoch 306/2000
# 25/25 [==============================] - 3s 100ms/step - loss: 0.5113 - accuracy: 0.8127 - val_loss: 0.3100 - val_accuracy: 0.8831
# Epoch 307/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.5046 - accuracy: 0.8134 - val_loss: 0.2517 - val_accuracy: 0.9610
# Epoch 308/2000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.4898 - accuracy: 0.8199 - val_loss: 0.2653 - val_accuracy: 0.9584
# Epoch 309/2000
# 25/25 [==============================] - 4s 145ms/step - loss: 0.4476 - accuracy: 0.8362 - val_loss: 0.2517 - val_accuracy: 0.9221
# Epoch 310/2000
# 25/25 [==============================] - 3s 118ms/step - loss: 0.4908 - accuracy: 0.8277 - val_loss: 0.2591 - val_accuracy: 0.9377
# Epoch 311/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.4742 - accuracy: 0.8355 - val_loss: 0.2346 - val_accuracy: 0.9870
# Epoch 312/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.6100 - accuracy: 0.7815 - val_loss: 0.3025 - val_accuracy: 0.9039
# Epoch 313/2000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.5976 - accuracy: 0.7685 - val_loss: 0.3053 - val_accuracy: 0.9273
# Epoch 314/2000
# 25/25 [==============================] - 3s 106ms/step - loss: 0.5799 - accuracy: 0.7880 - val_loss: 0.3118 - val_accuracy: 0.9273
# Epoch 315/2000
# 25/25 [==============================] - 4s 143ms/step - loss: 0.5537 - accuracy: 0.7861 - val_loss: 0.2872 - val_accuracy: 0.9506
# Epoch 316/2000
# 25/25 [==============================] - 3s 103ms/step - loss: 0.4936 - accuracy: 0.8108 - val_loss: 0.2654 - val_accuracy: 0.9558
# Epoch 317/2000
# 25/25 [==============================] - 3s 100ms/step - loss: 0.5020 - accuracy: 0.8147 - val_loss: 0.2518 - val_accuracy: 0.9610
# Epoch 318/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.4789 - accuracy: 0.8342 - val_loss: 0.2682 - val_accuracy: 0.9377
# Epoch 319/2000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.5165 - accuracy: 0.8075 - val_loss: 0.2464 - val_accuracy: 0.9584
# Epoch 320/2000
# 25/25 [==============================] - 3s 126ms/step - loss: 0.4546 - accuracy: 0.8479 - val_loss: 0.2701 - val_accuracy: 0.9429
# Epoch 321/2000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.4279 - accuracy: 0.8453 - val_loss: 0.2529 - val_accuracy: 0.9429
# Epoch 322/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.4674 - accuracy: 0.8283 - val_loss: 0.2367 - val_accuracy: 0.9455
# Epoch 323/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.4805 - accuracy: 0.8264 - val_loss: 0.2482 - val_accuracy: 0.9403
# Epoch 324/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.4797 - accuracy: 0.8231 - val_loss: 0.2374 - val_accuracy: 0.9558
# Epoch 325/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.4178 - accuracy: 0.8557 - val_loss: 0.2491 - val_accuracy: 0.9506
# Epoch 326/2000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.4942 - accuracy: 0.8283 - val_loss: 0.2541 - val_accuracy: 0.9558
# Epoch 327/2000
# 25/25 [==============================] - 3s 121ms/step - loss: 0.4868 - accuracy: 0.8355 - val_loss: 0.2424 - val_accuracy: 0.9195
# Epoch 328/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.4360 - accuracy: 0.8453 - val_loss: 0.2638 - val_accuracy: 0.9273
# Epoch 329/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.5052 - accuracy: 0.8179 - val_loss: 0.2539 - val_accuracy: 0.9325
# Epoch 330/2000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.5271 - accuracy: 0.8030 - val_loss: 0.2695 - val_accuracy: 0.9636
# Epoch 331/2000
# ...
# 25/25 [==============================] - 3s 112ms/step - loss: 0.3379 - accuracy: 0.9018 - val_loss: 0.1553 - val_accuracy: 0.9870
# Epoch 668/2000
# 25/25 [==============================] - 3s 104ms/step - loss: 0.3185 - accuracy: 0.9155 - val_loss: 0.1688 - val_accuracy: 0.9792
# Epoch 669/2000
# 25/25 [==============================] - 3s 100ms/step - loss: 0.2947 - accuracy: 0.9070 - val_loss: 0.1867 - val_accuracy: 0.9481
# Epoch 670/2000
# 25/25 [==============================] - 3s 123ms/step - loss: 0.3636 - accuracy: 0.8843 - val_loss: 0.1841 - val_accuracy: 0.9532
# Epoch 671/2000
# 25/25 [==============================] - 3s 136ms/step - loss: 0.3557 - accuracy: 0.8960 - val_loss: 0.1604 - val_accuracy: 0.9766
# Epoch 672/2000
# 25/25 [==============================] - 3s 109ms/step - loss: 0.3208 - accuracy: 0.9096 - val_loss: 0.1572 - val_accuracy: 0.9740
# Epoch 673/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.3227 - accuracy: 0.9038 - val_loss: 0.1667 - val_accuracy: 0.9688
# Epoch 674/2000
# 25/25 [==============================] - 3s 103ms/step - loss: 0.3277 - accuracy: 0.9025 - val_loss: 0.1688 - val_accuracy: 0.9688
# Epoch 675/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.3330 - accuracy: 0.8940 - val_loss: 0.1645 - val_accuracy: 0.9818
# Epoch 676/2000
# 25/25 [==============================] - 3s 139ms/step - loss: 0.3229 - accuracy: 0.9103 - val_loss: 0.1689 - val_accuracy: 0.9844
# Epoch 677/2000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.3185 - accuracy: 0.8999 - val_loss: 0.1658 - val_accuracy: 0.9844
# Epoch 678/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.3296 - accuracy: 0.8973 - val_loss: 0.1946 - val_accuracy: 0.9481
# Epoch 679/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.3284 - accuracy: 0.8921 - val_loss: 0.1683 - val_accuracy: 0.9662
# Epoch 680/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.3399 - accuracy: 0.8947 - val_loss: 0.1644 - val_accuracy: 0.9714
# Epoch 681/2000
# 25/25 [==============================] - 3s 109ms/step - loss: 0.3782 - accuracy: 0.8836 - val_loss: 0.2416 - val_accuracy: 0.9065
# Epoch 682/2000
# 25/25 [==============================] - 4s 143ms/step - loss: 0.3457 - accuracy: 0.8908 - val_loss: 0.1838 - val_accuracy: 0.9792
# Epoch 683/2000
# 25/25 [==============================] - 3s 116ms/step - loss: 0.3199 - accuracy: 0.8986 - val_loss: 0.1598 - val_accuracy: 0.9870
# Epoch 684/2000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.3179 - accuracy: 0.9077 - val_loss: 0.1594 - val_accuracy: 0.9844
# Epoch 685/2000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.3212 - accuracy: 0.9031 - val_loss: 0.1738 - val_accuracy: 0.9766
# Epoch 686/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.4736 - accuracy: 0.8524 - val_loss: 0.2108 - val_accuracy: 0.9662
# Epoch 687/2000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.4210 - accuracy: 0.8758 - val_loss: 0.1945 - val_accuracy: 0.9714
# Epoch 688/2000
# 25/25 [==============================] - 3s 137ms/step - loss: 0.3520 - accuracy: 0.8908 - val_loss: 0.1938 - val_accuracy: 0.9584
# Epoch 689/2000
# 25/25 [==============================] - 2s 99ms/step - loss: 0.3295 - accuracy: 0.8940 - val_loss: 0.1758 - val_accuracy: 0.9818
# Epoch 690/2000
# 25/25 [==============================] - 2s 99ms/step - loss: 0.3288 - accuracy: 0.8960 - val_loss: 0.1798 - val_accuracy: 0.9610
# Epoch 691/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.3057 - accuracy: 0.9051 - val_loss: 0.1906 - val_accuracy: 0.9481
# Epoch 692/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.4315 - accuracy: 0.8745 - val_loss: 0.1853 - val_accuracy: 0.9610
# Epoch 693/2000
# 25/25 [==============================] - 3s 135ms/step - loss: 0.3503 - accuracy: 0.8986 - val_loss: 0.1686 - val_accuracy: 0.9896
# Epoch 694/2000
# 25/25 [==============================] - 3s 132ms/step - loss: 0.2855 - accuracy: 0.9142 - val_loss: 0.1734 - val_accuracy: 0.9714
# Epoch 695/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.3172 - accuracy: 0.9057 - val_loss: 0.1603 - val_accuracy: 0.9870
# Epoch 696/2000
# 25/25 [==============================] - 2s 99ms/step - loss: 0.3344 - accuracy: 0.9051 - val_loss: 0.1654 - val_accuracy: 0.9662
# Epoch 697/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.2908 - accuracy: 0.9051 - val_loss: 0.1627 - val_accuracy: 0.9818
# Epoch 698/2000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.2720 - accuracy: 0.9220 - val_loss: 0.1473 - val_accuracy: 0.9766
# Epoch 699/2000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.2617 - accuracy: 0.9246 - val_loss: 0.1476 - val_accuracy: 0.9844
# Epoch 700/2000
# 25/25 [==============================] - 3s 128ms/step - loss: 0.2612 - accuracy: 0.9298 - val_loss: 0.2654 - val_accuracy: 0.9247
# Epoch 701/2000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.5139 - accuracy: 0.8322 - val_loss: 0.2438 - val_accuracy: 0.9013
# Epoch 702/2000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.3652 - accuracy: 0.8843 - val_loss: 0.2225 - val_accuracy: 0.9610
# Epoch 703/2000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.3646 - accuracy: 0.8693 - val_loss: 0.2266 - val_accuracy: 0.9636
# Epoch 704/2000
# 25/25 [==============================] - 3s 110ms/step - loss: 0.3560 - accuracy: 0.8940 - val_loss: 0.2232 - val_accuracy: 0.9584
# Epoch 705/2000
# 25/25 [==============================] - 3s 138ms/step - loss: 0.3717 - accuracy: 0.8882 - val_loss: 0.2011 - val_accuracy: 0.9844
# Epoch 706/2000
# 25/25 [==============================] - 3s 116ms/step - loss: 0.3600 - accuracy: 0.8849 - val_loss: 0.2052 - val_accuracy: 0.9740
# Epoch 707/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.3390 - accuracy: 0.8843 - val_loss: 0.1884 - val_accuracy: 0.9870
# Epoch 708/2000
# 25/25 [==============================] - 2s 99ms/step - loss: 0.3512 - accuracy: 0.8882 - val_loss: 0.2007 - val_accuracy: 0.9766
# Epoch 709/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.3775 - accuracy: 0.8784 - val_loss: 0.2023 - val_accuracy: 0.9558
# Epoch 710/2000
# 25/25 [==============================] - 3s 119ms/step - loss: 0.3825 - accuracy: 0.8791 - val_loss: 0.2064 - val_accuracy: 0.9792
# Epoch 711/2000
# 25/25 [==============================] - 3s 138ms/step - loss: 0.3619 - accuracy: 0.8797 - val_loss: 0.2423 - val_accuracy: 0.9506
# Epoch 712/2000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.3572 - accuracy: 0.8979 - val_loss: 0.1896 - val_accuracy: 0.9844
# Epoch 713/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.3534 - accuracy: 0.9057 - val_loss: 0.1760 - val_accuracy: 0.9870
# Epoch 714/2000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.3282 - accuracy: 0.9044 - val_loss: 0.1708 - val_accuracy: 0.9870
# Epoch 715/2000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.2943 - accuracy: 0.9129 - val_loss: 0.1764 - val_accuracy: 0.9532
# Epoch 716/2000
# 25/25 [==============================] - 3s 133ms/step - loss: 0.3156 - accuracy: 0.9090 - val_loss: 0.1899 - val_accuracy: 0.9455
# Epoch 717/2000
# 25/25 [==============================] - 3s 132ms/step - loss: 0.3535 - accuracy: 0.8849 - val_loss: 0.1873 - val_accuracy: 0.9766
# Epoch 718/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.3236 - accuracy: 0.9012 - val_loss: 0.1817 - val_accuracy: 0.9844
# Epoch 719/2000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.3097 - accuracy: 0.9005 - val_loss: 0.1805 - val_accuracy: 0.9844
# Epoch 720/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.2818 - accuracy: 0.9116 - val_loss: 0.1681 - val_accuracy: 0.9662
# Epoch 721/2000
# 25/25 [==============================] - 2s 99ms/step - loss: 0.3221 - accuracy: 0.8953 - val_loss: 0.1625 - val_accuracy: 0.9792
# Epoch 722/2000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.3370 - accuracy: 0.8973 - val_loss: 0.1858 - val_accuracy: 0.9584
# Epoch 723/2000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.3984 - accuracy: 0.8810 - val_loss: 0.1897 - val_accuracy: 0.9766
# Epoch 724/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.3374 - accuracy: 0.8979 - val_loss: 0.1831 - val_accuracy: 0.9818
# Epoch 725/2000
# 25/25 [==============================] - 2s 99ms/step - loss: 0.3074 - accuracy: 0.9096 - val_loss: 0.1910 - val_accuracy: 0.9558
# Epoch 726/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.3433 - accuracy: 0.8973 - val_loss: 0.1841 - val_accuracy: 0.9636
# Epoch 727/2000
# 25/25 [==============================] - 3s 105ms/step - loss: 0.3328 - accuracy: 0.8986 - val_loss: 0.1656 - val_accuracy: 0.9636
# Epoch 728/2000
# 25/25 [==============================] - 3s 133ms/step - loss: 0.3278 - accuracy: 0.8999 - val_loss: 0.1855 - val_accuracy: 0.9792
# Epoch 729/2000
# 25/25 [==============================] - 3s 121ms/step - loss: 0.3369 - accuracy: 0.8992 - val_loss: 0.1759 - val_accuracy: 0.9662
# Epoch 730/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.3242 - accuracy: 0.8973 - val_loss: 0.1704 - val_accuracy: 0.9688
# Epoch 731/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.3229 - accuracy: 0.9018 - val_loss: 0.1739 - val_accuracy: 0.9844
# Epoch 732/2000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.3899 - accuracy: 0.8895 - val_loss: 0.1715 - val_accuracy: 0.9662
# Epoch 733/2000
# 25/25 [==============================] - 3s 109ms/step - loss: 0.3476 - accuracy: 0.8973 - val_loss: 0.1826 - val_accuracy: 0.9662
# Epoch 734/2000
# 25/25 [==============================] - 3s 131ms/step - loss: 0.3471 - accuracy: 0.8953 - val_loss: 0.2337 - val_accuracy: 0.9169
# Epoch 735/2000
# 25/25 [==============================] - 3s 116ms/step - loss: 0.3325 - accuracy: 0.8914 - val_loss: 0.1798 - val_accuracy: 0.9714
# Epoch 736/2000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.3406 - accuracy: 0.8888 - val_loss: 0.1935 - val_accuracy: 0.9636
# Epoch 737/2000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.2902 - accuracy: 0.9090 - val_loss: 0.1874 - val_accuracy: 0.9610
# Epoch 738/2000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.3320 - accuracy: 0.9005 - val_loss: 0.1874 - val_accuracy: 0.9740
# Epoch 739/2000
# 25/25 [==============================] - 3s 117ms/step - loss: 0.3778 - accuracy: 0.8804 - val_loss: 0.1976 - val_accuracy: 0.9844
# Epoch 740/2000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.3550 - accuracy: 0.8862 - val_loss: 0.1922 - val_accuracy: 0.9610
# Epoch 741/2000
# 25/25 [==============================] - 3s 104ms/step - loss: 0.3328 - accuracy: 0.9018 - val_loss: 0.1888 - val_accuracy: 0.9662
# Epoch 742/2000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.3388 - accuracy: 0.8934 - val_loss: 0.1851 - val_accuracy: 0.9870
# Epoch 743/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.3095 - accuracy: 0.9135 - val_loss: 0.1636 - val_accuracy: 0.9844
# Epoch 744/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.2856 - accuracy: 0.9090 - val_loss: 0.1538 - val_accuracy: 0.9766
# Epoch 745/2000
# 25/25 [==============================] - 3s 118ms/step - loss: 0.3018 - accuracy: 0.9135 - val_loss: 0.2327 - val_accuracy: 0.9481
# Epoch 746/2000
# 25/25 [==============================] - 3s 139ms/step - loss: 0.3216 - accuracy: 0.9012 - val_loss: 0.1617 - val_accuracy: 0.9870
# Epoch 747/2000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.3180 - accuracy: 0.8979 - val_loss: 0.1781 - val_accuracy: 0.9766
# Epoch 748/2000
# 25/25 [==============================] - 2s 99ms/step - loss: 0.3333 - accuracy: 0.9012 - val_loss: 0.1624 - val_accuracy: 0.9870
# Epoch 749/2000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.4551 - accuracy: 0.8667 - val_loss: 0.1948 - val_accuracy: 0.9688
# Epoch 750/2000
# 25/25 [==============================] - 2s 99ms/step - loss: 0.3317 - accuracy: 0.9025 - val_loss: 0.1738 - val_accuracy: 0.9870
# Epoch 751/2000
# 25/25 [==============================] - 3s 135ms/step - loss: 0.3394 - accuracy: 0.8953 - val_loss: 0.2070 - val_accuracy: 0.9455
# Epoch 752/2000
# 25/25 [==============================] - 3s 131ms/step - loss: 0.3331 - accuracy: 0.9025 - val_loss: 0.2051 - val_accuracy: 0.9532
# Epoch 753/2000
# 25/25 [==============================] - 2s 99ms/step - loss: 0.4110 - accuracy: 0.8765 - val_loss: 0.2034 - val_accuracy: 0.9662
# Epoch 754/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.3075 - accuracy: 0.9057 - val_loss: 0.1767 - val_accuracy: 0.9662
# Epoch 755/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.2901 - accuracy: 0.9194 - val_loss: 0.1651 - val_accuracy: 0.9792
# Epoch 756/2000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.3019 - accuracy: 0.9194 - val_loss: 0.1683 - val_accuracy: 0.9740
# Epoch 757/2000
# 25/25 [==============================] - 3s 135ms/step - loss: 0.3196 - accuracy: 0.9090 - val_loss: 0.1755 - val_accuracy: 0.9610
# Epoch 758/2000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.2861 - accuracy: 0.9109 - val_loss: 0.1911 - val_accuracy: 0.9532
# Epoch 759/2000
# 25/25 [==============================] - 2s 100ms/step - loss: 0.3244 - accuracy: 0.9025 - val_loss: 0.1575 - val_accuracy: 0.9818
# Epoch 760/2000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.4472 - accuracy: 0.8492 - val_loss: 0.2295 - val_accuracy: 0.9481
# Epoch 761/2000
# 25/25 [==============================] - 3s 100ms/step - loss: 0.4594 - accuracy: 0.8466 - val_loss: 0.2676 - val_accuracy: 0.9351
# Epoch 762/2000
# 25/25 [==============================] - 3s 116ms/step - loss: 0.3544 - accuracy: 0.8713 - val_loss: 0.2228 - val_accuracy: 0.9584
# Epoch 763/2000
# 25/25 [==============================] - 3s 140ms/step - loss: 0.3547 - accuracy: 0.8862 - val_loss: 0.2014 - val_accuracy: 0.9870
# Epoch 764/2000
# 25/25 [==============================] - 3s 105ms/step - loss: 0.3300 - accuracy: 0.8960 - val_loss: 0.2050 - val_accuracy: 0.9299
# Epoch 765/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.3173 - accuracy: 0.8986 - val_loss: 0.1927 - val_accuracy: 0.9688
# Epoch 766/2000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.3256 - accuracy: 0.8960 - val_loss: 0.1846 - val_accuracy: 0.9766
# Epoch 767/2000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.3249 - accuracy: 0.9012 - val_loss: 0.1769 - val_accuracy: 0.9662
# Epoch 768/2000
# 25/25 [==============================] - 3s 127ms/step - loss: 0.3460 - accuracy: 0.8856 - val_loss: 0.1815 - val_accuracy: 0.9818
# Epoch 769/2000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.3303 - accuracy: 0.8986 - val_loss: 0.1953 - val_accuracy: 0.9610
# Epoch 770/2000
# 25/25 [==============================] - 3s 104ms/step - loss: 0.3986 - accuracy: 0.8680 - val_loss: 0.2096 - val_accuracy: 0.9584
# Epoch 771/2000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.3254 - accuracy: 0.8921 - val_loss: 0.1899 - val_accuracy: 0.9818
# Epoch 772/2000
# 25/25 [==============================] - 3s 100ms/step - loss: 0.3209 - accuracy: 0.9038 - val_loss: 0.1675 - val_accuracy: 0.9844
# Epoch 773/2000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.3132 - accuracy: 0.9038 - val_loss: 0.1688 - val_accuracy: 0.9766
# Epoch 774/2000
# 25/25 [==============================] - 3s 137ms/step - loss: 0.2768 - accuracy: 0.9161 - val_loss: 0.1596 - val_accuracy: 0.9688
# Epoch 775/2000
# 25/25 [==============================] - 3s 124ms/step - loss: 0.2713 - accuracy: 0.9233 - val_loss: 0.1536 - val_accuracy: 0.9610
# Epoch 776/2000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.3493 - accuracy: 0.8986 - val_loss: 0.1851 - val_accuracy: 0.9558

# %% [markdown]
# ## Evaluate the Model

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)

print(f"Test Example Count: {len(y_test)}")
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Correctness: {int(np.round(test_accuracy * len(y_test)))} / {len(y_test)}")
# Out:
# Test Example Count: 385
# Test Loss: 0.17598767578601837
# Test Accuracy: 0.9896103739738464
# Test Correctness: 381 / 385

# %% [markdown]
# ## Plotting Training and Validation Loss and Accuracy
# Create plots for training and validation loss, as well as training and validation accuracy.

# %%
# Plot training and validation loss
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Calculate and Display Confusion Matrix
# Get the predicted classes for the entire test set, then create and display the confusion matrix using a heatmap.

# %%
# Get the predicted classes for the entire test set
y_predicted = model.predict(X_test, verbose=0)
y_predicted_classes = np.argmax(y_predicted, axis=1)

# Create the confusion matrix
cm = confusion_matrix(y_test, y_predicted_classes)

# Display the confusion matrix using a heatmap
plt.figure(figsize=(8, 8))
heatmap = sns.heatmap(
                      cm,
                      annot=True,
                      cmap="Blues",
                      fmt='d',  # <- Set integer format for the annotations
                      xticklabels=[PHONEMES[i] for i in range(CLASSES)],
                      yticklabels=[PHONEMES[i] for i in range(CLASSES)],
)

# Modify the rotation of the y-axis labels
heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0)

plt.title("Confusion Matrix")
plt.xlabel("Predicted Phonemes")
plt.ylabel("Actual Phonemes")
plt.show()

# %% [markdown]
# ## Test Model on Random Examples
# Choose some random examples from the test set and display their actual and predicted phonemes.

# %%
# Choose 10 random examples from the test set
random_indices = random.sample(range(X_test.shape[0]), 10)
random_X = X_test[random_indices]
random_y_actual = y_test[random_indices]

# Predict the phoneme using the model
predictions = model.predict(random_X, verbose=0)
random_y_predicted = np.argmax(predictions, axis=1)

# Show actual and predicted phoneme for each picked example
for i in range(10):
    print(f"Example {i + 1}:")
    print(f"\tActual Phoneme: {PHONEMES[random_y_actual[i]]}")
    print(f"\tPredicted Phoneme: {PHONEMES[random_y_predicted[i]]}")
# Out:
# Example 1:
# 	Actual Phoneme: n
# 	Predicted Phoneme: n
# Example 2:
# 	Actual Phoneme: sh
# 	Predicted Phoneme: sh
# Example 3:
# 	Actual Phoneme: th(e)
# 	Predicted Phoneme: th(e)
# Example 4:
# 	Actual Phoneme: n
# 	Predicted Phoneme: n
# Example 5:
# 	Actual Phoneme: ch
# 	Predicted Phoneme: ch
# Example 6:
# 	Actual Phoneme: ng
# 	Predicted Phoneme: ng
# Example 7:
# 	Actual Phoneme: w
# 	Predicted Phoneme: w
# Example 8:
# 	Actual Phoneme: i(r)
# 	Predicted Phoneme: i(r)
# Example 9:
# 	Actual Phoneme: ng
# 	Predicted Phoneme: ng
# Example 10:
# 	Actual Phoneme: th(e)
# 	Predicted Phoneme: th(e)

# %% [markdown]
# ## Save Model
# Save to a formatted filename path, store not just weights but also hyperparameters for simpler model loading.

# %%
# Create filepath
filepath = 'LSTM_last22_seed351_5_5_final'

# Saving the model
model.save(filepath)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla, lstm_cell_28_layer_call_fn, lstm_cell_28_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
