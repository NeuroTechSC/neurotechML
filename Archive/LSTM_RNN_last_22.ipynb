# %% [markdown]
# ## Import Libraries
# Import necessary libraries for data processing, model building, and visualization (os, re, random, numpy, tensorflow, keras, scikit-learn, matplotlib, seaborn).

# %%
import os
import re
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.layers import Dropout, Conv2D, MaxPooling2D, BatchNormalization
from sklearn.model_selection import train_test_split
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# ## Set Hyperparameters and Filenames
# Define the hyperparameters of the dataset, including phonemes and classes. Load the training data and parse the filenames.

# %%
PHONEMES = ['_', 'h', 'j', 'l', 'n', 'r', 'w', 'y', 'ch', 'sh', 'ng', 'th(e)', 'th(in)', 'zh', 'wh', 'ā(r)', 'i(r)', 'o(r)', 'u(r)', 'ō', 'o', 'ōō', 'ow']
CLASSES = len(PHONEMES)

def get_files_with_prefix(directory, prefix):
    files = os.listdir(directory)
    filtered_files = [file for file in files if file.startswith(prefix)]
    return filtered_files

directory = "/content"
X_filename = get_files_with_prefix(directory, f"X_last22")[0]
y_filename = get_files_with_prefix(directory, f"y_last22")[0]

print(f"X_filename: {X_filename}")
print(f"y_filename: {y_filename}")
print(f"CLASSES: {CLASSES}")
# Out:
# X_filename: X_last22_904_4_10_10_final.npy
# y_filename: y_last22_904_4_10_10_final.npy
# CLASSES: 23

# %% [markdown]
# ## Parse Filename

# %%
def parse_filename(filename):
    # Regular expression pattern to extract the required information from the filename
    pattern = r"X_last22_(\d+)_(\d+)_(\d+)_\d+_final.npy"

    # Use regular expression to search and extract the required information
    match = re.search(pattern, filename)

    if match:
        num_examples = int(match.group(1))
        channels = int(match.group(2))
        size = int(match.group(3))

        return num_examples, channels, size
    else:
        raise ValueError("Invalid filename format")

NUM_EXAMPLES, CHANNELS, SIZE = parse_filename(X_filename)

print("NUM_EXAMPLES:", NUM_EXAMPLES)
print("channels:", CHANNELS)
print("size:", SIZE)
# Out:
# NUM_EXAMPLES: 904
# channels: 4
# size: 10

# %% [markdown]
# ## Train/Test Split

# %%
# Load the training data
X_train_og = np.load(X_filename)
y_train_og = np.load(y_filename)

# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X_train_og, y_train_og, test_size=0.2, random_state=351)

# Prepare the data - N training examples, 4 channels (muscle groups) per example, each 100 timesteps long
X_train = X_train.reshape(-1, CHANNELS, SIZE)
X_test = X_test.reshape(-1, CHANNELS, SIZE)

print(f"X_train.shape: {X_train.shape} - {X_train.shape[0]} training examples")
print(f"X_test.shape: {X_test.shape} - {X_test.shape[0]} testing examples")
# Out:
# X_train.shape: (723, 4, 10) - 723 training examples
# X_test.shape: (181, 4, 10) - 181 testing examples

# %% [markdown]
# ## Original/Training/Test Set Distributions
# Print info about training example distrubtions across phonemes/classes.

# %%
# # UNCOMMENT FOR SET DISTRIBUTIONS

# # Count the occurrences of each class in the training set
# y_og_counts = Counter(y_train_og)

# # Count the occurrences of each class in the training set
# y_train_counts = Counter(y_train)

# # Count the occurrences of each class in the test set
# y_test_counts = Counter(y_test)

# # Print the occurrences
# print("Occurrences in the original set:")
# for phoneme_index, count in sorted(y_og_counts.items()):
#     print(f"\tPhoneme {PHONEMES[phoneme_index]}: {count}")

# print("Occurrences in the training set:")
# for phoneme_index, count in sorted(y_train_counts.items()):
#     print(f"\tPhoneme {PHONEMES[phoneme_index]}: {count}")

# print("Occurrences in the test set:")
# for phoneme_index, count in sorted(y_test_counts.items()):
#     print(f"\tPhoneme {PHONEMES[phoneme_index]}: {count}")

# %% [markdown]
# ## Define the Model
# Create a sequential model using various layers such as Conv1D, Dropout, LSTM, and Dense, then compile the model with loss, optimizer, and metrics.

# %%
# Define the model
model = tf.keras.Sequential([
    layers.Conv1D(256, 3, activation='relu', input_shape=(CHANNELS, SIZE), padding='same'),
    layers.Dropout(0.5),
    layers.Conv1D(256, 3, activation='relu', strides=2, padding='same'),
    layers.Dropout(0.5),
    layers.LSTM(256, return_sequences=True, kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.5),
    layers.LSTM(256, kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.5),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dense(CLASSES, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_26 (Conv1D)          (None, 4, 256)            7936
#
#  dropout_67 (Dropout)        (None, 4, 256)            0
#
#  conv1d_27 (Conv1D)          (None, 2, 256)            196864
#
#  dropout_68 (Dropout)        (None, 2, 256)            0
#
#  lstm_26 (LSTM)              (None, 2, 256)            525312
#
#  dropout_69 (Dropout)        (None, 2, 256)            0
#
#  lstm_27 (LSTM)              (None, 256)               525312
#
#  dropout_70 (Dropout)        (None, 256)               0
#
#  dense_41 (Dense)            (None, 256)               65792
#
#  dropout_71 (Dropout)        (None, 256)               0
#
#  dense_42 (Dense)            (None, 128)               32896
#
#  dropout_72 (Dropout)        (None, 128)               0
#
#  dense_43 (Dense)            (None, 128)               16512
#
#  dense_44 (Dense)            (None, 23)                2967
#
# =================================================================
# Total params: 1,373,591
# Trainable params: 1,373,591
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Define Early Stopping callback
# Define an EarlyStopping callback function to prevent overfitting.

# %%
# Define Early Stopping callback
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=250,
    mode='max',
    restore_best_weights=True
)

# %% [markdown]
# ## Train the Model
# Fit the model on the training data and validate it on the testing data using the early stopping callback.

# %%
# Train the model
history = model.fit(
    X_train,
    y_train,
    batch_size=64,
    epochs=2000,
    verbose=1,
    validation_data=(X_test, y_test),
    callbacks=[callback]
)
# Out:
# Epoch 1/2000
# 12/12 [==============================] - 9s 172ms/step - loss: 3.2073 - accuracy: 0.0470 - val_loss: 3.1929 - val_accuracy: 0.0442
# Epoch 2/2000
# 12/12 [==============================] - 1s 88ms/step - loss: 3.1828 - accuracy: 0.0539 - val_loss: 3.1740 - val_accuracy: 0.0442
# Epoch 3/2000
# 12/12 [==============================] - 1s 88ms/step - loss: 3.1577 - accuracy: 0.0692 - val_loss: 3.1489 - val_accuracy: 0.0387
# Epoch 23/2000
# 12/12 [==============================] - 1s 91ms/step - loss: 1.7103 - accuracy: 0.2849 - val_loss: 1.4508 - val_accuracy: 0.4033
# Epoch 24/2000
# 12/12 [==============================] - 1s 91ms/step - loss: 1.6572 - accuracy: 0.2808 - val_loss: 1.4051 - val_accuracy: 0.3702
# Epoch 25/2000
# 12/12 [==============================] - 1s 91ms/step - loss: 1.5947 - accuracy: 0.3015 - val_loss: 1.3648 - val_accuracy: 0.4530
# Epoch 26/2000
# 12/12 [==============================] - 1s 88ms/step - loss: 1.5827 - accuracy: 0.3181 - val_loss: 1.3587 - val_accuracy: 0.3702
# Epoch 27/2000
# 12/12 [==============================] - 1s 89ms/step - loss: 1.5637 - accuracy: 0.3320 - val_loss: 1.3453 - val_accuracy: 0.4309
# Epoch 28/2000
# 12/12 [==============================] - 1s 93ms/step - loss: 1.5863 - accuracy: 0.3306 - val_loss: 1.3040 - val_accuracy: 0.4641
# Epoch 29/2000
# 12/12 [==============================] - 1s 89ms/step - loss: 1.5335 - accuracy: 0.3458 - val_loss: 1.2556 - val_accuracy: 0.5359
# Epoch 30/2000
# 12/12 [==============================] - 1s 92ms/step - loss: 1.4450 - accuracy: 0.3707 - val_loss: 1.2322 - val_accuracy: 0.4862
# Epoch 31/2000
# 12/12 [==============================] - 2s 141ms/step - loss: 1.4644 - accuracy: 0.3651 - val_loss: 1.1825 - val_accuracy: 0.5414
# Epoch 32/2000
# 12/12 [==============================] - 2s 141ms/step - loss: 1.5096 - accuracy: 0.3416 - val_loss: 1.2223 - val_accuracy: 0.4530
# Epoch 33/2000
# 12/12 [==============================] - 2s 128ms/step - loss: 1.4512 - accuracy: 0.3333 - val_loss: 1.2186 - val_accuracy: 0.5525
# Epoch 34/2000
# 12/12 [==============================] - 1s 92ms/step - loss: 1.3941 - accuracy: 0.3804 - val_loss: 1.1792 - val_accuracy: 0.5470
# Epoch 35/2000
# 12/12 [==============================] - 1s 95ms/step - loss: 1.4382 - accuracy: 0.3914 - val_loss: 1.1534 - val_accuracy: 0.5635
# Epoch 36/2000
# 12/12 [==============================] - 1s 89ms/step - loss: 1.4759 - accuracy: 0.3444 - val_loss: 1.1780 - val_accuracy: 0.4641
# Epoch 37/2000
# 12/12 [==============================] - 1s 89ms/step - loss: 1.4555 - accuracy: 0.3610 - val_loss: 1.1817 - val_accuracy: 0.5912
# Epoch 38/2000
# 12/12 [==============================] - 1s 92ms/step - loss: 1.4179 - accuracy: 0.3499 - val_loss: 1.1636 - val_accuracy: 0.5470
# Epoch 39/2000
# 12/12 [==============================] - 1s 93ms/step - loss: 1.3878 - accuracy: 0.3665 - val_loss: 1.1459 - val_accuracy: 0.4641
# Epoch 40/2000
# 12/12 [==============================] - 1s 93ms/step - loss: 1.3545 - accuracy: 0.4122 - val_loss: 1.0906 - val_accuracy: 0.5359
# Epoch 41/2000
# 12/12 [==============================] - 1s 96ms/step - loss: 1.3719 - accuracy: 0.3721 - val_loss: 1.1614 - val_accuracy: 0.4475
# Epoch 42/2000
# 12/12 [==============================] - 1s 98ms/step - loss: 1.3948 - accuracy: 0.3873 - val_loss: 1.1429 - val_accuracy: 0.5856
# Epoch 43/2000
# 12/12 [==============================] - 2s 135ms/step - loss: 1.4059 - accuracy: 0.3679 - val_loss: 1.1409 - val_accuracy: 0.4475
# Epoch 44/2000
# 12/12 [==============================] - 2s 138ms/step - loss: 1.3837 - accuracy: 0.3942 - val_loss: 1.1526 - val_accuracy: 0.5193
# Epoch 45/2000
# 12/12 [==============================] - 2s 137ms/step - loss: 1.3572 - accuracy: 0.4122 - val_loss: 1.1034 - val_accuracy: 0.6519
# Epoch 46/2000
# 12/12 [==============================] - 1s 90ms/step - loss: 1.3486 - accuracy: 0.3817 - val_loss: 1.1242 - val_accuracy: 0.5635
# Epoch 47/2000
# 12/12 [==============================] - 1s 89ms/step - loss: 1.3235 - accuracy: 0.4302 - val_loss: 1.0677 - val_accuracy: 0.6077
# Epoch 48/2000
# 12/12 [==============================] - 1s 89ms/step - loss: 1.2754 - accuracy: 0.4066 - val_loss: 1.0364 - val_accuracy: 0.5912
# Epoch 49/2000
# 12/12 [==============================] - 1s 89ms/step - loss: 1.3384 - accuracy: 0.3900 - val_loss: 1.0256 - val_accuracy: 0.6409
# Epoch 50/2000
# 12/12 [==============================] - 1s 87ms/step - loss: 1.3284 - accuracy: 0.3887 - val_loss: 1.0187 - val_accuracy: 0.5801
# Epoch 51/2000
# 12/12 [==============================] - 1s 91ms/step - loss: 1.2475 - accuracy: 0.4357 - val_loss: 0.9568 - val_accuracy: 0.6851
# Epoch 52/2000
# 12/12 [==============================] - 1s 90ms/step - loss: 1.2363 - accuracy: 0.4730 - val_loss: 0.9220 - val_accuracy: 0.6519
# Epoch 53/2000
# 12/12 [==============================] - 1s 87ms/step - loss: 1.2545 - accuracy: 0.4288 - val_loss: 0.9067 - val_accuracy: 0.5856
# Epoch 54/2000
# 12/12 [==============================] - 1s 84ms/step - loss: 1.2250 - accuracy: 0.4758 - val_loss: 0.8988 - val_accuracy: 0.6188
# Epoch 55/2000
# 12/12 [==============================] - 1s 119ms/step - loss: 1.2589 - accuracy: 0.4094 - val_loss: 0.8988 - val_accuracy: 0.6685
# Epoch 56/2000
# 12/12 [==============================] - 2s 133ms/step - loss: 1.2027 - accuracy: 0.4578 - val_loss: 0.8857 - val_accuracy: 0.6409
# Epoch 57/2000
# 12/12 [==============================] - 2s 134ms/step - loss: 1.1716 - accuracy: 0.4855 - val_loss: 0.8825 - val_accuracy: 0.6851
# Epoch 58/2000
# 12/12 [==============================] - 1s 107ms/step - loss: 1.1762 - accuracy: 0.4786 - val_loss: 0.8886 - val_accuracy: 0.6298
# Epoch 59/2000
# 12/12 [==============================] - 1s 91ms/step - loss: 1.1958 - accuracy: 0.4564 - val_loss: 0.8645 - val_accuracy: 0.7348
# Epoch 60/2000
# 12/12 [==============================] - 1s 89ms/step - loss: 1.2496 - accuracy: 0.4412 - val_loss: 0.9338 - val_accuracy: 0.5912
# Epoch 61/2000
# 12/12 [==============================] - 2s 140ms/step - loss: 0.6827 - accuracy: 0.7151 - val_loss: 0.3954 - val_accuracy: 0.8619
# Epoch 291/2000
# 12/12 [==============================] - 2s 129ms/step - loss: 0.7091 - accuracy: 0.7026 - val_loss: 0.4102 - val_accuracy: 0.8453
# Epoch 292/2000
# 12/12 [==============================] - 1s 94ms/step - loss: 0.6965 - accuracy: 0.7248 - val_loss: 0.4519 - val_accuracy: 0.8177
# Epoch 293/2000
# 12/12 [==============================] - 1s 90ms/step - loss: 0.7677 - accuracy: 0.6722 - val_loss: 0.4411 - val_accuracy: 0.8619
# Epoch 294/2000
# 12/12 [==============================] - 1s 92ms/step - loss: 0.6558 - accuracy: 0.7082 - val_loss: 0.4618 - val_accuracy: 0.8398
# Epoch 295/2000
# 12/12 [==============================] - 1s 93ms/step - loss: 0.6217 - accuracy: 0.7289 - val_loss: 0.4016 - val_accuracy: 0.9061
# Epoch 296/2000
# 12/12 [==============================] - 1s 94ms/step - loss: 0.5989 - accuracy: 0.7414 - val_loss: 0.3987 - val_accuracy: 0.8287
# Epoch 297/2000
# 12/12 [==============================] - 1s 91ms/step - loss: 0.6563 - accuracy: 0.7040 - val_loss: 0.4237 - val_accuracy: 0.8508
# Epoch 298/2000
# 12/12 [==============================] - 1s 92ms/step - loss: 0.6429 - accuracy: 0.7331 - val_loss: 0.3904 - val_accuracy: 0.8564
# Epoch 299/2000
# 12/12 [==============================] - 1s 90ms/step - loss: 0.6352 - accuracy: 0.7427 - val_loss: 0.4082 - val_accuracy: 0.7845
# Epoch 300/2000
# 12/12 [==============================] - 1s 97ms/step - loss: 0.6876 - accuracy: 0.7220 - val_loss: 0.3940 - val_accuracy: 0.9061
# Epoch 301/2000
# 12/12 [==============================] - 2s 136ms/step - loss: 0.6103 - accuracy: 0.7455 - val_loss: 0.3946 - val_accuracy: 0.8564
# Epoch 302/2000
# 12/12 [==============================] - 2s 138ms/step - loss: 0.6539 - accuracy: 0.7358 - val_loss: 0.3705 - val_accuracy: 0.9006
# Epoch 303/2000
# 12/12 [==============================] - 2s 139ms/step - loss: 0.6348 - accuracy: 0.7344 - val_loss: 0.4223 - val_accuracy: 0.8508
# Epoch 304/2000
# 12/12 [==============================] - 1s 95ms/step - loss: 0.6534 - accuracy: 0.7414 - val_loss: 0.4092 - val_accuracy: 0.8508
# Epoch 305/2000
# 12/12 [==============================] - 1s 92ms/step - loss: 0.6135 - accuracy: 0.7607 - val_loss: 0.3983 - val_accuracy: 0.8950
# Epoch 306/2000
# 12/12 [==============================] - 1s 90ms/step - loss: 0.6610 - accuracy: 0.7414 - val_loss: 0.4270 - val_accuracy: 0.8508
# Epoch 307/2000
# 12/12 [==============================] - 1s 94ms/step - loss: 0.6011 - accuracy: 0.7414 - val_loss: 0.4210 - val_accuracy: 0.8619
# Epoch 308/2000
# 12/12 [==============================] - 1s 96ms/step - loss: 0.6358 - accuracy: 0.7289 - val_loss: 0.3812 - val_accuracy: 0.8840
# Epoch 309/2000
# 12/12 [==============================] - 1s 96ms/step - loss: 0.6577 - accuracy: 0.7497 - val_loss: 0.4057 - val_accuracy: 0.8895
# Epoch 310/2000
# 12/12 [==============================] - 1s 93ms/step - loss: 0.6584 - accuracy: 0.7344 - val_loss: 0.3942 - val_accuracy: 0.8674
# Epoch 311/2000
# 12/12 [==============================] - 1s 104ms/step - loss: 0.5889 - accuracy: 0.7524 - val_loss: 0.3812 - val_accuracy: 0.9116
# Epoch 312/2000
# 12/12 [==============================] - 1s 104ms/step - loss: 0.6585 - accuracy: 0.7289 - val_loss: 0.3646 - val_accuracy: 0.8895
# Epoch 313/2000
# 12/12 [==============================] - 2s 145ms/step - loss: 0.6183 - accuracy: 0.7206 - val_loss: 0.4282 - val_accuracy: 0.8232
# Epoch 314/2000
# 12/12 [==============================] - 2s 145ms/step - loss: 0.6817 - accuracy: 0.7331 - val_loss: 0.4072 - val_accuracy: 0.8785
# Epoch 315/2000
# 12/12 [==============================] - 2s 129ms/step - loss: 0.6449 - accuracy: 0.7317 - val_loss: 0.3855 - val_accuracy: 0.8785
# Epoch 316/2000
# 12/12 [==============================] - 1s 92ms/step - loss: 0.6103 - accuracy: 0.7552 - val_loss: 0.3924 - val_accuracy: 0.8729
# Epoch 317/2000
# 12/12 [==============================] - 1s 94ms/step - loss: 0.6083 - accuracy: 0.7566 - val_loss: 0.3732 - val_accuracy: 0.9171
# Epoch 318/2000
# 12/12 [==============================] - 1s 93ms/step - loss: 0.6262 - accuracy: 0.7427 - val_loss: 0.3758 - val_accuracy: 0.8619
# Epoch 319/2000
# 12/12 [==============================] - 1s 94ms/step - loss: 0.5688 - accuracy: 0.7690 - val_loss: 0.3603 - val_accuracy: 0.8785
# Epoch 320/2000
# 12/12 [==============================] - 1s 94ms/step - loss: 0.5726 - accuracy: 0.7580 - val_loss: 0.3719 - val_accuracy: 0.8508
# Epoch 321/2000
# 12/12 [==============================] - 1s 94ms/step - loss: 0.5926 - accuracy: 0.7635 - val_loss: 0.3457 - val_accuracy: 0.9061
# Epoch 322/2000
# 12/12 [==============================] - 1s 95ms/step - loss: 0.5727 - accuracy: 0.7690 - val_loss: 0.3695 - val_accuracy: 0.8785
# Epoch 323/2000
# 12/12 [==============================] - 1s 99ms/step - loss: 0.6287 - accuracy: 0.7344 - val_loss: 0.3959 - val_accuracy: 0.8453
# Epoch 324/2000
# 12/12 [==============================] - 1s 125ms/step - loss: 0.5880 - accuracy: 0.7427 - val_loss: 0.3415 - val_accuracy: 0.9227
# Epoch 325/2000
# 12/12 [==============================] - 2s 134ms/step - loss: 0.5947 - accuracy: 0.7732 - val_loss: 0.3702 - val_accuracy: 0.9006
# Epoch 326/2000
# 12/12 [==============================] - 2s 146ms/step - loss: 0.6516 - accuracy: 0.7386 - val_loss: 0.3707 - val_accuracy: 0.8840
# Epoch 327/2000
# 12/12 [==============================] - 2s 127ms/step - loss: 0.6426 - accuracy: 0.7303 - val_loss: 0.4429 - val_accuracy: 0.8011
# Epoch 328/2000
# 12/12 [==============================] - 1s 91ms/step - loss: 0.6099 - accuracy: 0.7469 - val_loss: 0.3619 - val_accuracy: 0.8950
# Epoch 329/2000
# 12/12 [==============================] - 1s 93ms/step - loss: 0.5927 - accuracy: 0.7607 - val_loss: 0.3769 - val_accuracy: 0.9006
# Epoch 330/2000
# 12/12 [==============================] - 1s 95ms/step - loss: 0.7101 - accuracy: 0.7248 - val_loss: 0.3928 - val_accuracy: 0.8453
# Epoch 331/2000
# 12/12 [==============================] - 1s 100ms/step - loss: 0.7169 - accuracy: 0.7331 - val_loss: 0.3812 - val_accuracy: 0.8785
# ...
# Epoch 963/2000
# 12/12 [==============================] - 2s 130ms/step - loss: 0.4991 - accuracy: 0.8382 - val_loss: 0.1805 - val_accuracy: 0.9779
# Epoch 964/2000
# 12/12 [==============================] - 2s 135ms/step - loss: 0.4051 - accuracy: 0.8658 - val_loss: 0.1905 - val_accuracy: 0.9669
# Epoch 965/2000
# 12/12 [==============================] - 2s 138ms/step - loss: 0.4065 - accuracy: 0.8658 - val_loss: 0.1847 - val_accuracy: 0.9724
# Epoch 966/2000
# 12/12 [==============================] - 2s 146ms/step - loss: 0.3503 - accuracy: 0.8880 - val_loss: 0.1895 - val_accuracy: 0.9669
# Epoch 967/2000
# 12/12 [==============================] - 1s 103ms/step - loss: 0.3428 - accuracy: 0.9046 - val_loss: 0.1652 - val_accuracy: 0.9834
# Epoch 968/2000
# 12/12 [==============================] - 1s 102ms/step - loss: 0.3459 - accuracy: 0.8907 - val_loss: 0.1582 - val_accuracy: 0.9779
# Epoch 969/2000
# 12/12 [==============================] - 1s 105ms/step - loss: 0.3306 - accuracy: 0.8935 - val_loss: 0.1584 - val_accuracy: 0.9779
# Epoch 970/2000
# 12/12 [==============================] - 1s 104ms/step - loss: 0.2886 - accuracy: 0.9032 - val_loss: 0.1507 - val_accuracy: 0.9779
# Epoch 971/2000
# 12/12 [==============================] - 1s 102ms/step - loss: 0.3380 - accuracy: 0.8811 - val_loss: 0.1701 - val_accuracy: 0.9669
# Epoch 972/2000
# 12/12 [==============================] - 1s 98ms/step - loss: 0.3317 - accuracy: 0.8949 - val_loss: 0.1708 - val_accuracy: 0.9779
# Epoch 973/2000
# 12/12 [==============================] - 1s 103ms/step - loss: 0.3940 - accuracy: 0.8631 - val_loss: 0.1750 - val_accuracy: 0.9558
# Epoch 974/2000
# 12/12 [==============================] - 1s 103ms/step - loss: 0.3162 - accuracy: 0.8976 - val_loss: 0.1805 - val_accuracy: 0.9779
# Epoch 975/2000
# 12/12 [==============================] - 2s 146ms/step - loss: 0.2928 - accuracy: 0.9073 - val_loss: 0.1785 - val_accuracy: 0.9503
# Epoch 976/2000
# 12/12 [==============================] - 2s 145ms/step - loss: 0.3190 - accuracy: 0.9087 - val_loss: 0.1938 - val_accuracy: 0.9337
# Epoch 977/2000
# 12/12 [==============================] - 2s 135ms/step - loss: 0.3754 - accuracy: 0.8631 - val_loss: 0.2196 - val_accuracy: 0.9337
# Epoch 978/2000
# 12/12 [==============================] - 2s 128ms/step - loss: 0.3605 - accuracy: 0.8645 - val_loss: 0.1823 - val_accuracy: 0.9669
# Epoch 979/2000
# 12/12 [==============================] - 1s 105ms/step - loss: 0.3879 - accuracy: 0.8755 - val_loss: 0.1911 - val_accuracy: 0.9669
# Epoch 980/2000
# 12/12 [==============================] - 1s 100ms/step - loss: 0.3525 - accuracy: 0.8811 - val_loss: 0.1835 - val_accuracy: 0.9613
# Epoch 981/2000
# 12/12 [==============================] - 1s 100ms/step - loss: 0.3346 - accuracy: 0.8866 - val_loss: 0.1861 - val_accuracy: 0.9613
# Epoch 982/2000
# 12/12 [==============================] - 1s 102ms/step - loss: 0.3097 - accuracy: 0.8963 - val_loss: 0.1940 - val_accuracy: 0.9613
# Epoch 983/2000
# 12/12 [==============================] - 1s 100ms/step - loss: 0.3382 - accuracy: 0.8921 - val_loss: 0.1720 - val_accuracy: 0.9779
# Epoch 984/2000
# 12/12 [==============================] - 1s 104ms/step - loss: 0.3767 - accuracy: 0.8811 - val_loss: 0.1985 - val_accuracy: 0.9613
# Epoch 985/2000
# 12/12 [==============================] - 1s 101ms/step - loss: 0.3586 - accuracy: 0.8880 - val_loss: 0.1799 - val_accuracy: 0.9669
# Epoch 986/2000
# 12/12 [==============================] - 1s 107ms/step - loss: 0.3999 - accuracy: 0.8672 - val_loss: 0.2483 - val_accuracy: 0.9116
# Epoch 987/2000
# 12/12 [==============================] - 2s 144ms/step - loss: 0.3797 - accuracy: 0.8769 - val_loss: 0.1807 - val_accuracy: 0.9779
# Epoch 988/2000
# 12/12 [==============================] - 2s 137ms/step - loss: 0.3347 - accuracy: 0.8907 - val_loss: 0.1915 - val_accuracy: 0.9503
# Epoch 989/2000
# 12/12 [==============================] - 2s 136ms/step - loss: 0.3478 - accuracy: 0.8949 - val_loss: 0.1866 - val_accuracy: 0.9669
# Epoch 990/2000
# 12/12 [==============================] - 2s 127ms/step - loss: 0.3521 - accuracy: 0.8921 - val_loss: 0.2117 - val_accuracy: 0.9558
# Epoch 991/2000
# 12/12 [==============================] - 1s 102ms/step - loss: 0.3519 - accuracy: 0.8838 - val_loss: 0.1794 - val_accuracy: 0.9724
# Epoch 992/2000
# 12/12 [==============================] - 1s 104ms/step - loss: 0.3787 - accuracy: 0.8769 - val_loss: 0.1836 - val_accuracy: 0.9724
# Epoch 993/2000
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4246 - accuracy: 0.8562 - val_loss: 0.1880 - val_accuracy: 0.9669
# Epoch 994/2000
# 12/12 [==============================] - 1s 102ms/step - loss: 0.3051 - accuracy: 0.9032 - val_loss: 0.1985 - val_accuracy: 0.9558
# Epoch 995/2000
# 12/12 [==============================] - 1s 103ms/step - loss: 0.3424 - accuracy: 0.8880 - val_loss: 0.1909 - val_accuracy: 0.9779
# Epoch 996/2000
# 12/12 [==============================] - 1s 104ms/step - loss: 0.3331 - accuracy: 0.9059 - val_loss: 0.1691 - val_accuracy: 0.9779
# Epoch 997/2000
# Epoch 1054/2000
# 12/12 [==============================] - 1s 101ms/step - loss: 0.3650 - accuracy: 0.8714 - val_loss: 0.2197 - val_accuracy: 0.9448
# Epoch 1055/2000
# 12/12 [==============================] - 1s 99ms/step - loss: 0.3576 - accuracy: 0.8852 - val_loss: 0.2148 - val_accuracy: 0.9503
# Epoch 1056/2000
# 12/12 [==============================] - 1s 104ms/step - loss: 0.3601 - accuracy: 0.8797 - val_loss: 0.2082 - val_accuracy: 0.9558
# Epoch 1057/2000
# 12/12 [==============================] - 2s 147ms/step - loss: 0.3425 - accuracy: 0.8852 - val_loss: 0.2120 - val_accuracy: 0.9613
# Epoch 1058/2000
# 12/12 [==============================] - 2s 141ms/step - loss: 0.3696 - accuracy: 0.8824 - val_loss: 0.2006 - val_accuracy: 0.9724
# Epoch 1059/2000
# 12/12 [==============================] - 2s 143ms/step - loss: 0.3491 - accuracy: 0.8880 - val_loss: 0.2018 - val_accuracy: 0.9669
# Epoch 1060/2000
# 12/12 [==============================] - 2s 135ms/step - loss: 0.3316 - accuracy: 0.9046 - val_loss: 0.1904 - val_accuracy: 0.9669
# Epoch 1061/2000
# 12/12 [==============================] - 1s 103ms/step - loss: 0.3294 - accuracy: 0.9018 - val_loss: 0.1703 - val_accuracy: 0.9669
# Epoch 1062/2000
# 12/12 [==============================] - 1s 107ms/step - loss: 0.3921 - accuracy: 0.8824 - val_loss: 0.2208 - val_accuracy: 0.9558
# Epoch 1063/2000
# 12/12 [==============================] - 1s 104ms/step - loss: 0.3327 - accuracy: 0.9004 - val_loss: 0.1674 - val_accuracy: 0.9779
# Epoch 1064/2000
# 12/12 [==============================] - 1s 102ms/step - loss: 0.3865 - accuracy: 0.8921 - val_loss: 0.1793 - val_accuracy: 0.9613
# Epoch 1065/2000
# 12/12 [==============================] - 1s 104ms/step - loss: 0.3312 - accuracy: 0.9004 - val_loss: 0.1791 - val_accuracy: 0.9779
# Epoch 1066/2000
# 12/12 [==============================] - 1s 110ms/step - loss: 0.3835 - accuracy: 0.8714 - val_loss: 0.1789 - val_accuracy: 0.9724
# Epoch 1067/2000
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4406 - accuracy: 0.8741 - val_loss: 0.2301 - val_accuracy: 0.9282
# Epoch 1068/2000
# 12/12 [==============================] - 1s 125ms/step - loss: 0.3993 - accuracy: 0.8631 - val_loss: 0.2219 - val_accuracy: 0.9669
# Epoch 1069/2000
# 12/12 [==============================] - 2s 147ms/step - loss: 0.4194 - accuracy: 0.8714 - val_loss: 0.2262 - val_accuracy: 0.9669
# Epoch 1070/2000
# 12/12 [==============================] - 2s 151ms/step - loss: 0.3322 - accuracy: 0.8907 - val_loss: 0.1952 - val_accuracy: 0.9503
# Epoch 1071/2000
# 12/12 [==============================] - 2s 149ms/step - loss: 0.3519 - accuracy: 0.8907 - val_loss: 0.1815 - val_accuracy: 0.9669

# %% [markdown]
# ## Evaluate the Model

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)

print(f"Test Example Count: {len(y_test)}")
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Correctness: {int(np.round(test_accuracy * len(y_test)))} / {len(y_test)}")
# Out:
# Test Example Count: 181
# Test Loss: 0.2176857888698578
# Test Accuracy: 0.9834254384040833
# Test Correctness: 178 / 181

# %% [markdown]
# ## Plotting Training and Validation Loss and Accuracy
# Create plots for training and validation loss, as well as training and validation accuracy.

# %%
# Plot training and validation loss
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Calculate and Display Confusion Matrix
# Get the predicted classes for the entire test set, then create and display the confusion matrix using a heatmap.

# %%
# Get the predicted classes for the entire test set
y_predicted = model.predict(X_test, verbose=0)
y_predicted_classes = np.argmax(y_predicted, axis=1)

# Create the confusion matrix
cm = confusion_matrix(y_test, y_predicted_classes)

# Display the confusion matrix using a heatmap
plt.figure(figsize=(8, 8))
heatmap = sns.heatmap(
                      cm,
                      annot=True,
                      cmap="Blues",
                      fmt='d',  # <- Set integer format for the annotations
                      xticklabels=[PHONEMES[i] for i in range(CLASSES)],
                      yticklabels=[PHONEMES[i] for i in range(CLASSES)],
)

# Modify the rotation of the y-axis labels
heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0)

plt.title("Confusion Matrix")
plt.xlabel("Predicted Phonemes")
plt.ylabel("Actual Phonemes")
plt.show()

# %% [markdown]
# ## Test Model on Random Examples
# Choose some random examples from the test set and display their actual and predicted phonemes.

# %%
# Choose 10 random examples from the test set
random_indices = random.sample(range(X_test.shape[0]), 10)
random_X = X_test[random_indices]
random_y_actual = y_test[random_indices]

# Predict the phoneme using the model
predictions = model.predict(random_X, verbose=0)
random_y_predicted = np.argmax(predictions, axis=1)

# Show actual and predicted phoneme for each picked example
for i in range(10):
    print(f"Example {i + 1}:")
    print(f"\tActual Phoneme: {PHONEMES[random_y_actual[i]]}")
    print(f"\tPredicted Phoneme: {PHONEMES[random_y_predicted[i]]}")
# Out:
# Example 1:
# 	Actual Phoneme: sh
# 	Predicted Phoneme: sh
# Example 2:
# 	Actual Phoneme: l
# 	Predicted Phoneme: l
# Example 3:
# 	Actual Phoneme: th(in)
# 	Predicted Phoneme: th(in)
# Example 4:
# 	Actual Phoneme: o
# 	Predicted Phoneme: o
# Example 5:
# 	Actual Phoneme: n
# 	Predicted Phoneme: n
# Example 6:
# 	Actual Phoneme: l
# 	Predicted Phoneme: l
# Example 7:
# 	Actual Phoneme: zh
# 	Predicted Phoneme: zh
# Example 8:
# 	Actual Phoneme: i(r)
# 	Predicted Phoneme: i(r)
# Example 9:
# 	Actual Phoneme: y
# 	Predicted Phoneme: y
# Example 10:
# 	Actual Phoneme: h
# 	Predicted Phoneme: h

# %% [markdown]
# ## Save Model
# Save to a formatted filename path, store not just weights but also hyperparameters for simpler model loading.

# %%
# Create filepath
filepath = 'LSTM_last22_seed351_final'

# Saving the model
model.save(filepath)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla, lstm_cell_26_layer_call_fn, lstm_cell_26_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
