# %% [markdown]
# # Loose EEGNet
# This notebook is a neural network that is based as much off of the EEGNet paper as I could understand.

# %% [markdown]
# ---

# %% [markdown]
# # Import/Install all necessary packages and libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np

from sklearn.metrics import roc_auc_score, precision_score, recall_score, accuracy_score, classification_report
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable, gradcheck
from torch.utils.data import TensorDataset, DataLoader

import pandas as pd

from matplotlib import pyplot

import math

from os import walk

# %% [markdown]
# # Check for GPU availability and set device

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %% [markdown]
# # Load and format the data

# %% [markdown]
# Here is a brief rundown of the data:
#
# > Each data segment (chunk) is a two second recording in which a subject subvocalized either "yes" or "no" at any point in the recording
#
# > The data is taken with a sampling frequency of 250hz, so in the end there are 500 timepoints for each chunk
#
# > The hardware we are using has 7 channels
#
# > After all these data cells are run the data is in the shape (# of chunks, 1, # of channels, # of timepoints)

# %%
master_data, master_label = [], []
datafix, labelfix = ".pkl", ".csv"
# paste path below
for (dirpath, dirnames, filenames) in walk('/content/drive/Shareddrives/NeuroTech ML/Processed Data Files'):
    new_data = [dirpath + '/' + name for name in filenames if datafix in name]
    master_data.extend(new_data)

    new_labels = [dirpath + '/' + name for name in filenames if labelfix in name]
    master_label.extend(new_labels)
assert len(master_data) == len(master_label)
master_data.sort()
master_label.sort()
for index in range(len(master_data)):
    try: 
        assert master_data[index][:-4] == master_label[index][:-11]
    except:
        print(index)
        print(master_data[index][:-4])
        print(master_label[index][:-11])

# %%
pkllabels = np.zeros((1, 1))
pkldata = np.zeros((1, 7, 500))
pkllabels2 = np.zeros((1, 1))
pkldata2 = np.zeros((1, 7, 500))

for i in range(len(master_data)):

    # To train no ICA data change data type to ICA
    # To train no ICA and weaker filter change data type to Weaker
    # To train unprocessed data change data type to Unprocessed

    data_type = "Pit_Bit"

    if data_type in master_data[i]:
        new_data = pd.read_pickle(master_data[i])

        new_labels = pd.read_csv(master_label[i], delimiter=',', header=None)
        if new_labels.shape[0] == 1 and new_labels.shape[1] > new_labels.shape[0]:
            new_labels = new_labels.T
        new_labels = np.array(new_labels)
        new_labels = new_labels.reshape((new_labels.shape[0], 1))

        pkldata = np.concatenate((pkldata, new_data), axis = 0)
        pkllabels = np.concatenate((pkllabels, new_labels), axis = 0)
    # elif data_type in master_data[i] and 'YESNO' in master_data[i]:
    #     new_data = pd.read_pickle(master_data[i])

    #     new_labels = pd.read_csv(master_label[i], delimiter=',', header=None)
    #     if new_labels.shape[0] == 1 and new_labels.shape[1] > new_labels.shape[0]:
    #         new_labels = new_labels.T
    #     new_labels = np.array(new_labels)
    #     new_labels = new_labels.reshape((new_labels.shape[0], 1))

    #     pkldata2 = np.concatenate((pkldata2, new_data), axis = 0)
    #     pkllabels2 = np.concatenate((pkllabels2, new_labels), axis = 0)

pkllabels = pkllabels[1:, :]
pkldata = pkldata[1:, :, :]
pkllabels2 = pkllabels2[1:, :]
pkldata2 = pkldata2[1:, :, :]

# %%
# # Uncomment below if u wanna see a bunch of graphs of the data
# print(pkldata.shape, pkllabels.shape)
# print(pkllabels.shape)
# x = pkldata[0]
# only_no = [pkldata[i] for i in range(pkldata.shape[0]) if pkllabels[i][0] == 0]
# only_no = np.array(only_no)
# only_yes = [pkldata[i] for i in range(pkldata.shape[0]) if pkllabels[i][0] == 1]
# only_yes = np.array(only_yes)
# print(only_no.shape, only_yes.shape)
# for i in range(pkldata.shape[1]):
#     g = i + 1
#     pyplot.plot(only_yes[0:, i, :].T, color="red")
#     pyplot.plot(only_no[0:, i, :].T, alpha = .3, color="blue")
#     pyplot.title("Value for channel {} over all {} chunks".format(i, pkldata.shape[0]))
#     #pyplot.savefig(f"/content/drive/My Drive/Extra/processed_data_Riley_channel_{g}.png")
#     pyplot.show()

# %%
torch.manual_seed(4)
torch.cuda.manual_seed(4)

# %%
channels = pkldata.shape[1]
timepoints = pkldata.shape[2]
print(channels, timepoints)
# Out:
# 7 500

# %%
BATCH_SIZE = 32

pkllabels = pkllabels.astype(np.float32)
X_actual = torch.from_numpy(pkllabels)

scaler = StandardScaler()
X_train = pkldata
# for i in range(len(X_train)):
#     X_train[i] = scaler.fit_transform(X_train[i])
X_train = torch.from_numpy(X_train)
X_train = X_train.unsqueeze(1)

# pkllabels2 = pkllabels2.astype(np.float32)
# X_test_labels = torch.from_numpy(pkllabels2)

# X_test = pkldata2
# X_test = torch.from_numpy(X_test)
# X_test = X_test.unsqueeze(1)

# splits the data into a train and dev set, and loads them into dataloaders
train_data, test_data, labels_train, labels_test = train_test_split(X_train, X_actual, test_size=0.2, random_state=4)

# test_data = X_test
# labels_test = X_test_labels

trainset = torch.utils.data.TensorDataset(train_data, labels_train)
testset = torch.utils.data.TensorDataset(test_data, labels_test)

train_loader = torch.utils.data.DataLoader(trainset, batch_size = BATCH_SIZE, shuffle = True, drop_last=True)
test_loader = torch.utils.data.DataLoader(testset, batch_size = test_data.shape[0], shuffle = True, drop_last=True)

print(train_data.shape, test_data.shape, labels_train.shape, labels_test.shape)
# Out:
# torch.Size([99, 1, 7, 500]) torch.Size([25, 1, 7, 500]) torch.Size([99, 1]) torch.Size([25, 1])

# %% [markdown]
# # Build the model and train
# A short breakdown of the paper:
# > EEGNet is a CNN for classification and interpretation of EEG-based BCI's
#
# > Benefits of EEGNet:
# > 1. Can be applied to different BCI paradagims (MI, ERP, SSVEP)
# > 2. Can be trained with very limited data
# > 3. Can produce neurophysiologically interpretable features
#
# > The model architecture:
# > 1. Fit 2D convolutional filters of size (1, sampling rate//2)
# > 2. Use a depthwise convolution of size (# of channels, 1)
# > 3. Add a separable convolution of size (1, 16)
# > 4. Flatten the data and feed it through a classification layer

# %%
# hyperparameters
freq, avg1stride, avg2stride = 250, (1, 4), (1, 8)
convstride = 1 # stride for each conv2D
conv1_neurons = 8
conv2_neurons = 16
conv3_neurons = 32
conv4_neurons = 16
kern1size = freq // 2
kern3size = 32

# %%
padding_needed = (kern1size - 1) / 2
conv1outx, conv1outy = (channels, (timepoints + (2 * padding_needed) - kern1size)/convstride + 1)

print("1st layer output size:", conv1outx, conv1outy)

conv2outx, conv2outy = ((conv1outx - channels)/convstride + 1, conv1outy)
conv2outx, conv2outy = conv2outx // avg1stride[0], conv2outy // avg1stride[1]

print("2nd layer output size:", conv2outx, conv2outy)

# conv3outx, conv3outy = (conv2outx, (conv2outy - kern3size)/convstride + 1)

# print("3rd layer output size:", conv3outx, conv3outy)

# conv4outx, conv4outy = (conv3outx, conv3outy)
# conv4outx, conv4outy = (conv4outx // avg2stride[0], conv4outy // avg2stride[1])

# print("4th layer output size:", conv4outx, conv4outy)

# flat1_in = int(conv4outx * conv4outy * conv4_neurons)

flat1_in = int(conv2outx * conv2outy * conv2_neurons)
# Out:
# 1st layer output size: 7 500.0
# 2nd layer output size: 1.0 125.0

# %% [markdown]
# Model description, layer by layer
#
# 1. Temporal convolution
# > * - Uses filters of (1, sampling frequency // 2)
# > * - Learns frequency filters at 2Hz and above
# 2. Depthwise convolution
# > * - Learns spatial filters
# 3. Separable Convolution
# > * - Conists of a deptwise convolution followed by a pointwise convolution
# > * - First learnes a kernel summarizing each feature map, then merges the outputs
# 4. Fully connected layer
# > * - Consists of a linear layer that reduces the channels, followed by a sigmoid classification

# %% [markdown]
# 3.5k research grant at school
#
# https://science.ucsc.edu/research-opportunities/undergraduate-research-in-science-and-technology-award/

# %%
class ConstrainedConv2d(nn.Conv2d):
    def forward(self, input):
        return F.conv2d(input, self.weight.clamp(min=-1.0, max=1.0), self.bias, self.stride,
                        self.padding, self.dilation, self.groups)

# %%
class EEGNet(nn.Module):
    def __init__(self):
        super(EEGNet, self).__init__()
        self.pad = nn.ZeroPad2d((math.floor(padding_needed), math.ceil(padding_needed), 0, 0))
        self.conv1 = nn.Conv2d(1, conv1_neurons, (1, kern1size), bias=False)
        self.norm1 = nn.BatchNorm2d(conv1_neurons)
        self.conv2 = ConstrainedConv2d(conv1_neurons, conv2_neurons, (channels, 1), bias=False)
        self.norm2 = nn.BatchNorm2d(conv2_neurons)
        self.pool = nn.MaxPool2d(avg1stride)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(flat1_in, 1)
        self.dropout = nn.Dropout()

        self.activation = nn.ELU()
        self.activation2 = nn.Sigmoid()

    def forward(self, x):
        out = self.pad(x)
        out = self.conv1(out)
        out = self.activation(out)
        out = self.norm1(out)

        out = self.conv2(out)
        out = self.activation(out)
        out = self.pool(self.norm2(out))
        out = self.dropout(out)

        out = self.activation2(self.fc1(self.flatten(out)))
        return out

CNNPoor = EEGNet()

# %%
# CNNPoor = nn.Sequential(
#     nn.ZeroPad2d((math.floor(padding_needed), math.ceil(padding_needed), 0, 0)),
#     nn.Conv2d(1, conv1_neurons, (1, kern1size), bias=False),
#     nn.ELU(),
#     nn.BatchNorm2d(conv1_neurons),
    
#     ConstrainedConv2d(conv1_neurons, conv2_neurons, (channels, 1), bias=False),
#     nn.ELU(),
#     nn.BatchNorm2d(conv2_neurons),
#     nn.MaxPool2d(avg1stride),
#     nn.Dropout(),
    
#     # nn.Conv2d(conv2_neurons, conv3_neurons, (1, kern3size), bias=False, groups=conv2_neurons),
#     # nn.Conv2d(conv3_neurons, conv4_neurons, kernel_size=1, bias=False),
#     # nn.ELU(),
#     # nn.BatchNorm2d(conv4_neurons),
#     # nn.MaxPool2d(avg2stride),
#     # nn.Dropout(),
    
#     nn.Flatten(),

#     nn.Linear(flat1_in, 1),
#     nn.Sigmoid(),
# )

CNNPoor = CNNPoor.to(device)

# %%
loss_function = nn.BCELoss()
optimizer = optim.Adam(CNNPoor.parameters(), lr = 0.0001)

# %%
def test(model, device, test_loader):
    
    model.eval()
    correct = 0
    tot_loss = 0
    acc_score, prec_score, rec_score = 0, 0, 0
    with torch.no_grad():
        for (data, labels) in test_loader:
            data, labels = data.to(device), labels.to(device)
            
            classification = model(data.float())
            loss = loss_function(classification, labels)

            pred = torch.round(classification)
            correct += pred.eq(labels.view_as(pred)).sum().item()
            tot_loss += loss.item()

            acc_score += accuracy_score(labels, pred)
            prec_score += precision_score(labels, pred)
            rec_score += recall_score(labels, pred)

        print("\nTest set: Total loss: {:.6f}, Accuracy: {:.6f}".format(tot_loss, 
                                                                          correct / len(test_loader.dataset)))
        # print(classification_report(labels, pred))
        return (tot_loss, acc_score, prec_score, rec_score)

# %%
def train(model, device, train_loader, optimizer, epoch):

    model.train()
    correct = 0
    tot_loss = 0
    for batch, (data, labels) in enumerate(train_loader):
        data, labels = data.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        classification = model(data.float())
        loss = loss_function(classification, labels)

        loss.backward()
        optimizer.step()

        pred = torch.round(classification)
        correct += pred.eq(labels.view_as(pred)).sum().item()
        tot_loss += loss.item()
    print("Epoch: {}".format(epoch))
    print("\tAverage loss: {:.6f}".format(tot_loss / (batch + 1)))
    print("\tAccuracy: {:.6f}".format(correct / len(train_loader.dataset)))

    labels_detached = labels.detach()
    preds_detached = pred.detach()
    print(classification_report(labels_detached, preds_detached))
    return (tot_loss / (batch + 1), correct / len(train_loader.dataset))

# %%
plots = {"train loss": [],
         "train acc": [],
         "test loss": [],
         "test acc": [],
         "test prec": [],
         "test rec": []}

for epoch in range(120):
    trl, tra = train(CNNPoor, device, train_loader, optimizer, epoch)
    plots["train loss"].append(trl)
    plots["train acc"].append(tra)
    tl, ta, tp, tr = test(CNNPoor, device, test_loader)
    plots["test loss"].append(tl)
    plots["test acc"].append(ta)
    plots["test prec"].append(tp)
    plots["test rec"].append(tr)
# Out:
# Epoch: 0
# 	Average loss: 0.667418
# 	Accuracy: 0.545455
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.71      0.65        14
#          1.0       0.73      0.61      0.67        18
#
#     accuracy                           0.66        32
#    macro avg       0.66      0.66      0.66        32
# weighted avg       0.67      0.66      0.66        32
#
#
# Test set: Total loss: 0.692485, Accuracy: 0.520000
# Epoch: 1
# 	Average loss: 0.752104
# 	Accuracy: 0.484848
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.47      0.50        15
#          1.0       0.58      0.65      0.61        17
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.56      0.56      0.56        32
#
#
# Test set: Total loss: 0.692628, Accuracy: 0.520000
# Epoch: 2
# 	Average loss: 0.721884
# 	Accuracy: 0.545455
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.47      0.52        15
#          1.0       0.60      0.71      0.65        17
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.58        32
# weighted avg       0.59      0.59      0.59        32
#
#
# Test set: Total loss: 0.692187, Accuracy: 0.520000
# Epoch: 3
# 	Average loss: 0.740263
# 	Accuracy: 0.474747
#               precision    recall  f1-score   support
#
#          0.0       0.30      0.19      0.23        16
#          1.0       0.41      0.56      0.47        16
#
#     accuracy                           0.38        32
#    macro avg       0.35      0.38      0.35        32
# weighted avg       0.35      0.38      0.35        32
#
#
# Test set: Total loss: 0.692020, Accuracy: 0.520000
# Epoch: 4
# 	Average loss: 0.731823
# 	Accuracy: 0.484848
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.50      0.47        16
#          1.0       0.43      0.38      0.40        16
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.692582, Accuracy: 0.480000
# Epoch: 5
# 	Average loss: 0.708475
# 	Accuracy: 0.545455
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.38      0.39        16
#          1.0       0.41      0.44      0.42        16
#
#     accuracy                           0.41        32
#    macro avg       0.41      0.41      0.41        32
# weighted avg       0.41      0.41      0.41        32
#
#
# Test set: Total loss: 0.692344, Accuracy: 0.520000
# Epoch: 6
# 	Average loss: 0.706270
# 	Accuracy: 0.505051
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.40      0.39        15
#          1.0       0.44      0.41      0.42        17
#
#     accuracy                           0.41        32
#    macro avg       0.41      0.41      0.41        32
# weighted avg       0.41      0.41      0.41        32
#
#
# Test set: Total loss: 0.692132, Accuracy: 0.520000
# Epoch: 7
# 	Average loss: 0.711853
# 	Accuracy: 0.525253
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.59      0.56        17
#          1.0       0.46      0.40      0.43        15
#
#     accuracy                           0.50        32
#    macro avg       0.49      0.49      0.49        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Test set: Total loss: 0.691935, Accuracy: 0.520000
# Epoch: 8
# 	Average loss: 0.742109
# 	Accuracy: 0.494949
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.44      0.53        18
#          1.0       0.50      0.71      0.59        14
#
#     accuracy                           0.56        32
#    macro avg       0.58      0.58      0.56        32
# weighted avg       0.59      0.56      0.56        32
#
#
# Test set: Total loss: 0.691926, Accuracy: 0.520000
# Epoch: 9
# 	Average loss: 0.749433
# 	Accuracy: 0.505051
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.44      0.48        16
#          1.0       0.53      0.62      0.57        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Test set: Total loss: 0.691946, Accuracy: 0.520000
# Epoch: 10
# 	Average loss: 0.683783
# 	Accuracy: 0.555556
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.43      0.44        14
#          1.0       0.58      0.61      0.59        18
#
#     accuracy                           0.53        32
#    macro avg       0.52      0.52      0.52        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Test set: Total loss: 0.691917, Accuracy: 0.520000
# Epoch: 11
# 	Average loss: 0.809628
# 	Accuracy: 0.383838
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.35      0.35        17
#          1.0       0.27      0.27      0.27        15
#
#     accuracy                           0.31        32
#    macro avg       0.31      0.31      0.31        32
# weighted avg       0.31      0.31      0.31        32
#
#
# Test set: Total loss: 0.691831, Accuracy: 0.520000
# Epoch: 12
# 	Average loss: 0.720832
# 	Accuracy: 0.444444
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.50      0.53        16
#          1.0       0.56      0.62      0.59        16
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.56      0.56      0.56        32
#
#
# Test set: Total loss: 0.692019, Accuracy: 0.520000
# Epoch: 13
# 	Average loss: 0.760885
# 	Accuracy: 0.474747
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.58      0.59        19
#          1.0       0.43      0.46      0.44        13
#
#     accuracy                           0.53        32
#    macro avg       0.52      0.52      0.52        32
# weighted avg       0.54      0.53      0.53        32
#
#
# Test set: Total loss: 0.692045, Accuracy: 0.520000
# Epoch: 14
# 	Average loss: 0.641576
# 	Accuracy: 0.565657
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.79      0.67        14
#          1.0       0.77      0.56      0.65        18
#
#     accuracy                           0.66        32
#    macro avg       0.67      0.67      0.66        32
# weighted avg       0.69      0.66      0.65        32
#
#
# Test set: Total loss: 0.692513, Accuracy: 0.560000
# Epoch: 15
# 	Average loss: 0.810227
# 	Accuracy: 0.414141
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.65      0.59        17
#          1.0       0.50      0.40      0.44        15
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.52      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Test set: Total loss: 0.693344, Accuracy: 0.520000
# Epoch: 16
# 	Average loss: 0.728789
# 	Accuracy: 0.444444
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50        16
#          1.0       0.50      0.50      0.50        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Test set: Total loss: 0.693766, Accuracy: 0.480000
# Epoch: 17
# 	Average loss: 0.714532
# 	Accuracy: 0.545455
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.60      0.60        15
#          1.0       0.65      0.65      0.65        17
#
#     accuracy                           0.62        32
#    macro avg       0.62      0.62      0.62        32
# weighted avg       0.62      0.62      0.62        32
#
#
# Test set: Total loss: 0.694007, Accuracy: 0.480000
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 18
# 	Average loss: 0.749950
# 	Accuracy: 0.464646
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.40      0.40        15
#          1.0       0.47      0.47      0.47        17
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.693757, Accuracy: 0.520000
# Epoch: 19
# 	Average loss: 0.761954
# 	Accuracy: 0.434343
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.47      0.46        17
#          1.0       0.36      0.33      0.34        15
#
#     accuracy                           0.41        32
#    macro avg       0.40      0.40      0.40        32
# weighted avg       0.40      0.41      0.40        32
#
#
# Test set: Total loss: 0.693760, Accuracy: 0.480000
# Epoch: 20
# 	Average loss: 0.717991
# 	Accuracy: 0.484848
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.57      0.48        14
#          1.0       0.54      0.39      0.45        18
#
#     accuracy                           0.47        32
#    macro avg       0.48      0.48      0.47        32
# weighted avg       0.49      0.47      0.47        32
#
#
# Test set: Total loss: 0.693942, Accuracy: 0.440000
# Epoch: 21
# 	Average loss: 0.758641
# 	Accuracy: 0.414141
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.29      0.33        17
#          1.0       0.37      0.47      0.41        15
#
#     accuracy                           0.38        32
#    macro avg       0.38      0.38      0.37        32
# weighted avg       0.38      0.38      0.37        32
#
#
# Test set: Total loss: 0.693156, Accuracy: 0.520000
# Epoch: 22
# 	Average loss: 0.749615
# 	Accuracy: 0.454545
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.35      0.39        17
#          1.0       0.39      0.47      0.42        15
#
#     accuracy                           0.41        32
#    macro avg       0.41      0.41      0.41        32
# weighted avg       0.41      0.41      0.40        32
#
#
# Test set: Total loss: 0.693494, Accuracy: 0.520000
# Epoch: 23
# 	Average loss: 0.724523
# 	Accuracy: 0.464646
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.57      0.55        14
#          1.0       0.65      0.61      0.63        18
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Test set: Total loss: 0.693789, Accuracy: 0.480000
# Epoch: 24
# 	Average loss: 0.721967
# 	Accuracy: 0.474747
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.53      0.57        19
#          1.0       0.44      0.54      0.48        13
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.55      0.53      0.54        32
#
#
# Test set: Total loss: 0.693036, Accuracy: 0.480000
# Epoch: 25
# 	Average loss: 0.696568
# 	Accuracy: 0.545455
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.53      0.46        15
#          1.0       0.42      0.29      0.34        17
#
#     accuracy                           0.41        32
#    macro avg       0.41      0.41      0.40        32
# weighted avg       0.41      0.41      0.40        32
#
#
# Test set: Total loss: 0.693758, Accuracy: 0.400000
# Epoch: 26
# 	Average loss: 0.705040
# 	Accuracy: 0.505051
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.67      0.57        15
#          1.0       0.58      0.41      0.48        17
#
#     accuracy                           0.53        32
#    macro avg       0.54      0.54      0.53        32
# weighted avg       0.54      0.53      0.52        32
#
#
# Test set: Total loss: 0.693890, Accuracy: 0.480000
# Epoch: 27
# 	Average loss: 0.722231
# 	Accuracy: 0.474747
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.67      0.54        15
#          1.0       0.50      0.29      0.37        17
#
#     accuracy                           0.47        32
#    macro avg       0.48      0.48      0.46        32
# weighted avg       0.48      0.47      0.45        32
#
#
# Test set: Total loss: 0.693505, Accuracy: 0.480000
# Epoch: 28
# 	Average loss: 0.688205
# 	Accuracy: 0.555556
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.50      0.57        16
#          1.0       0.60      0.75      0.67        16
#
#     accuracy                           0.62        32
#    macro avg       0.63      0.62      0.62        32
# weighted avg       0.63      0.62      0.62        32
#
#
# Test set: Total loss: 0.693106, Accuracy: 0.520000
# Epoch: 29
# 	Average loss: 0.780973
# 	Accuracy: 0.414141
#               precision    recall  f1-score   support
#
#          0.0       0.37      0.44      0.40        16
#          1.0       0.31      0.25      0.28        16
#
#     accuracy                           0.34        32
#    macro avg       0.34      0.34      0.34        32
# weighted avg       0.34      0.34      0.34        32
#
#
# Test set: Total loss: 0.692445, Accuracy: 0.560000
# Epoch: 30
# 	Average loss: 0.717795
# 	Accuracy: 0.505051
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.71      0.62        17
#          1.0       0.50      0.33      0.40        15
#
#     accuracy                           0.53        32
#    macro avg       0.52      0.52      0.51        32
# weighted avg       0.52      0.53      0.51        32
#
#
# Test set: Total loss: 0.692165, Accuracy: 0.520000
# Epoch: 31
# 	Average loss: 0.769735
# 	Accuracy: 0.494949
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.36      0.40        14
#          1.0       0.57      0.67      0.62        18
#
#     accuracy                           0.53        32
#    macro avg       0.51      0.51      0.51        32
# weighted avg       0.52      0.53      0.52        32
#
#
# Test set: Total loss: 0.691895, Accuracy: 0.520000
# Epoch: 32
# 	Average loss: 0.690362
# 	Accuracy: 0.505051
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.69      0.67        16
#          1.0       0.67      0.62      0.65        16
#
#     accuracy                           0.66        32
#    macro avg       0.66      0.66      0.66        32
# weighted avg       0.66      0.66      0.66        32
#
#
# Test set: Total loss: 0.691871, Accuracy: 0.520000
# Epoch: 33
# 	Average loss: 0.739012
# 	Accuracy: 0.464646
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.53      0.55        15
#          1.0       0.61      0.65      0.63        17
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.59      0.59      0.59        32
#
#
# Test set: Total loss: 0.692154, Accuracy: 0.520000
# Epoch: 34
# 	Average loss: 0.724279
# 	Accuracy: 0.525253
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.60      0.55        15
#          1.0       0.57      0.47      0.52        17
#
#     accuracy                           0.53        32
#    macro avg       0.54      0.54      0.53        32
# weighted avg       0.54      0.53      0.53        32
#
#
# Test set: Total loss: 0.692120, Accuracy: 0.520000
# Epoch: 35
# 	Average loss: 0.707004
# 	Accuracy: 0.525253
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.55      0.41        11
#          1.0       0.64      0.43      0.51        21
#
#     accuracy                           0.47        32
#    macro avg       0.49      0.49      0.46        32
# weighted avg       0.54      0.47      0.48        32
#
#
# Test set: Total loss: 0.692212, Accuracy: 0.600000
# Epoch: 36
# 	Average loss: 0.794309
# 	Accuracy: 0.424242
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.47      0.47        17
#          1.0       0.40      0.40      0.40        15
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.691991, Accuracy: 0.480000
# Epoch: 37
# 	Average loss: 0.753797
# 	Accuracy: 0.444444
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.38      0.40        16
#          1.0       0.44      0.50      0.47        16
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.691858, Accuracy: 0.520000
# Epoch: 38
# 	Average loss: 0.703496
# 	Accuracy: 0.515152
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.47      0.45        15
#          1.0       0.50      0.47      0.48        17
#
#     accuracy                           0.47        32
#    macro avg       0.47      0.47      0.47        32
# weighted avg       0.47      0.47      0.47        32
#
#
# Test set: Total loss: 0.692467, Accuracy: 0.560000
# Epoch: 39
# 	Average loss: 0.732655
# 	Accuracy: 0.505051
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.45      0.51        20
#          1.0       0.35      0.50      0.41        12
#
#     accuracy                           0.47        32
#    macro avg       0.48      0.47      0.46        32
# weighted avg       0.51      0.47      0.48        32
#
#
# Test set: Total loss: 0.692255, Accuracy: 0.600000
# Epoch: 40
# 	Average loss: 0.769932
# 	Accuracy: 0.414141
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.29      0.31        17
#          1.0       0.29      0.33      0.31        15
#
#     accuracy                           0.31        32
#    macro avg       0.31      0.31      0.31        32
# weighted avg       0.31      0.31      0.31        32
#
#
# Test set: Total loss: 0.692699, Accuracy: 0.560000
# Epoch: 41
# 	Average loss: 0.726590
# 	Accuracy: 0.434343
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.35      0.39        17
#          1.0       0.39      0.47      0.42        15
#
#     accuracy                           0.41        32
#    macro avg       0.41      0.41      0.41        32
# weighted avg       0.41      0.41      0.40        32
#
#
# Test set: Total loss: 0.693798, Accuracy: 0.480000
# Epoch: 42
# 	Average loss: 0.721233
# 	Accuracy: 0.505051
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.33      0.41        18
#          1.0       0.43      0.64      0.51        14
#
#     accuracy                           0.47        32
#    macro avg       0.49      0.49      0.46        32
# weighted avg       0.49      0.47      0.46        32
#
#
# Test set: Total loss: 0.695893, Accuracy: 0.480000
# Epoch: 43
# 	Average loss: 0.720593
# 	Accuracy: 0.484848
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.61      0.56        18
#          1.0       0.36      0.29      0.32        14
#
#     accuracy                           0.47        32
#    macro avg       0.44      0.45      0.44        32
# weighted avg       0.45      0.47      0.46        32
#
#
# Test set: Total loss: 0.697360, Accuracy: 0.480000
# Epoch: 44
# 	Average loss: 0.701207
# 	Accuracy: 0.515152
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.73      0.46        11
#          1.0       0.62      0.24      0.34        21
#
#     accuracy                           0.41        32
#    macro avg       0.48      0.48      0.40        32
# weighted avg       0.52      0.41      0.38        32
#
#
# Test set: Total loss: 0.700048, Accuracy: 0.480000
# Epoch: 45
# 	Average loss: 0.717480
# 	Accuracy: 0.494949
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50        14
#          1.0       0.61      0.61      0.61        18
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.56      0.56      0.56        32
#
#
# Test set: Total loss: 0.699596, Accuracy: 0.480000
# Epoch: 46
# 	Average loss: 0.676089
# 	Accuracy: 0.555556
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.65      0.58        17
#          1.0       0.45      0.33      0.38        15
#
#     accuracy                           0.50        32
#    macro avg       0.49      0.49      0.48        32
# weighted avg       0.49      0.50      0.49        32
#
#
# Test set: Total loss: 0.697478, Accuracy: 0.480000
# Epoch: 47
# 	Average loss: 0.771187
# 	Accuracy: 0.414141
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.67      0.59        18
#          1.0       0.33      0.21      0.26        14
#
#     accuracy                           0.47        32
#    macro avg       0.43      0.44      0.42        32
# weighted avg       0.44      0.47      0.44        32
#
#
# Test set: Total loss: 0.694617, Accuracy: 0.480000
# Epoch: 48
# 	Average loss: 0.690830
# 	Accuracy: 0.525253
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.50      0.41        12
#          1.0       0.60      0.45      0.51        20
#
#     accuracy                           0.47        32
#    macro avg       0.48      0.47      0.46        32
# weighted avg       0.51      0.47      0.48        32
#
#
# Test set: Total loss: 0.693479, Accuracy: 0.520000
# Epoch: 49
# 	Average loss: 0.738506
# 	Accuracy: 0.464646
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.41      0.45        17
#          1.0       0.44      0.53      0.48        15
#
#     accuracy                           0.47        32
#    macro avg       0.47      0.47      0.47        32
# weighted avg       0.47      0.47      0.47        32
#
#
# Test set: Total loss: 0.692549, Accuracy: 0.560000
# Epoch: 50
# 	Average loss: 0.742036
# 	Accuracy: 0.454545
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.60      0.53        15
#          1.0       0.54      0.41      0.47        17
#
#     accuracy                           0.50        32
#    macro avg       0.51      0.51      0.50        32
# weighted avg       0.51      0.50      0.50        32
#
#
# Test set: Total loss: 0.692385, Accuracy: 0.520000
# Epoch: 51
# 	Average loss: 0.697400
# 	Accuracy: 0.545455
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.67      0.65        15
#          1.0       0.69      0.65      0.67        17
#
#     accuracy                           0.66        32
#    macro avg       0.66      0.66      0.66        32
# weighted avg       0.66      0.66      0.66        32
#
#
# Test set: Total loss: 0.692359, Accuracy: 0.520000
# Epoch: 52
# 	Average loss: 0.696931
# 	Accuracy: 0.484848
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.30      0.41        20
#          1.0       0.39      0.75      0.51        12
#
#     accuracy                           0.47        32
#    macro avg       0.53      0.53      0.46        32
# weighted avg       0.56      0.47      0.45        32
#
#
# Test set: Total loss: 0.692159, Accuracy: 0.520000
# Epoch: 53
# 	Average loss: 0.730419
# 	Accuracy: 0.505051
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.40      0.50        20
#          1.0       0.40      0.67      0.50        12
#
#     accuracy                           0.50        32
#    macro avg       0.53      0.53      0.50        32
# weighted avg       0.57      0.50      0.50        32
#
#
# Test set: Total loss: 0.692399, Accuracy: 0.520000
# Epoch: 54
# 	Average loss: 0.688933
# 	Accuracy: 0.575758
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.67      0.65        18
#          1.0       0.54      0.50      0.52        14
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.58      0.58        32
# weighted avg       0.59      0.59      0.59        32
#
#
# Test set: Total loss: 0.693143, Accuracy: 0.520000
# Epoch: 55
# 	Average loss: 0.727734
# 	Accuracy: 0.515152
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.69      0.58        16
#          1.0       0.50      0.31      0.38        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.48        32
# weighted avg       0.50      0.50      0.48        32
#
#
# Test set: Total loss: 0.694353, Accuracy: 0.480000
# Epoch: 56
# 	Average loss: 0.747633
# 	Accuracy: 0.474747
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.54      0.45        13
#          1.0       0.57      0.42      0.48        19
#
#     accuracy                           0.47        32
#    macro avg       0.48      0.48      0.47        32
# weighted avg       0.50      0.47      0.47        32
#
#
# Test set: Total loss: 0.695733, Accuracy: 0.480000
# Epoch: 57
# 	Average loss: 0.693209
# 	Accuracy: 0.545455
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.72      0.67        18
#          1.0       0.55      0.43      0.48        14
#
#     accuracy                           0.59        32
#    macro avg       0.58      0.58      0.57        32
# weighted avg       0.59      0.59      0.58        32
#
#
# Test set: Total loss: 0.694881, Accuracy: 0.480000
# Epoch: 58
# 	Average loss: 0.684172
# 	Accuracy: 0.535354
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.79      0.58        14
#          1.0       0.62      0.28      0.38        18
#
#     accuracy                           0.50        32
#    macro avg       0.54      0.53      0.48        32
# weighted avg       0.55      0.50      0.47        32
#
#
# Test set: Total loss: 0.693850, Accuracy: 0.480000
# Epoch: 59
# 	Average loss: 0.758805
# 	Accuracy: 0.434343
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.53      0.50        17
#          1.0       0.38      0.33      0.36        15
#
#     accuracy                           0.44        32
#    macro avg       0.43      0.43      0.43        32
# weighted avg       0.43      0.44      0.43        32
#
#
# Test set: Total loss: 0.693025, Accuracy: 0.600000
# Epoch: 60
# 	Average loss: 0.708026
# 	Accuracy: 0.515152
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.33      0.37        15
#          1.0       0.50      0.59      0.54        17
#
#     accuracy                           0.47        32
#    macro avg       0.46      0.46      0.46        32
# weighted avg       0.46      0.47      0.46        32
#
#
# Test set: Total loss: 0.692789, Accuracy: 0.560000
# Epoch: 61
# 	Average loss: 0.693560
# 	Accuracy: 0.484848
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.53      0.46        15
#          1.0       0.42      0.29      0.34        17
#
#     accuracy                           0.41        32
#    macro avg       0.41      0.41      0.40        32
# weighted avg       0.41      0.41      0.40        32
#
#
# Test set: Total loss: 0.692864, Accuracy: 0.520000
# Epoch: 62
# 	Average loss: 0.710160
# 	Accuracy: 0.525253
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.41      0.42        17
#          1.0       0.38      0.40      0.39        15
#
#     accuracy                           0.41        32
#    macro avg       0.41      0.41      0.41        32
# weighted avg       0.41      0.41      0.41        32
#
#
# Test set: Total loss: 0.692687, Accuracy: 0.520000
# Epoch: 63
# 	Average loss: 0.769451
# 	Accuracy: 0.424242
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.59      0.56        17
#          1.0       0.46      0.40      0.43        15
#
#     accuracy                           0.50        32
#    macro avg       0.49      0.49      0.49        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Test set: Total loss: 0.692660, Accuracy: 0.600000
# Epoch: 64
# 	Average loss: 0.696891
# 	Accuracy: 0.484848
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.57      0.53        14
#          1.0       0.62      0.56      0.59        18
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.57      0.56      0.56        32
#
#
# Test set: Total loss: 0.692561, Accuracy: 0.560000
# Epoch: 65
# 	Average loss: 0.712298
# 	Accuracy: 0.525253
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.59      0.56        17
#          1.0       0.46      0.40      0.43        15
#
#     accuracy                           0.50        32
#    macro avg       0.49      0.49      0.49        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Test set: Total loss: 0.693086, Accuracy: 0.480000
# Epoch: 66
# 	Average loss: 0.718147
# 	Accuracy: 0.454545
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.43      0.40        14
#          1.0       0.50      0.44      0.47        18
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.45      0.44      0.44        32
#
#
# Test set: Total loss: 0.694649, Accuracy: 0.480000
# Epoch: 67
# 	Average loss: 0.694351
# 	Accuracy: 0.545455
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.59      0.57        17
#          1.0       0.50      0.47      0.48        15
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Test set: Total loss: 0.693608, Accuracy: 0.480000
# Epoch: 68
# 	Average loss: 0.731110
# 	Accuracy: 0.505051
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.73      0.61        15
#          1.0       0.64      0.41      0.50        17
#
#     accuracy                           0.56        32
#    macro avg       0.58      0.57      0.56        32
# weighted avg       0.58      0.56      0.55        32
#
#
# Test set: Total loss: 0.695253, Accuracy: 0.480000
# Epoch: 69
# 	Average loss: 0.737269
# 	Accuracy: 0.434343
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.50      0.47        14
#          1.0       0.56      0.50      0.53        18
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.51      0.50      0.50        32
#
#
# Test set: Total loss: 0.695861, Accuracy: 0.480000
# Epoch: 70
# 	Average loss: 0.683197
# 	Accuracy: 0.575758
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.82      0.70        17
#          1.0       0.67      0.40      0.50        15
#
#     accuracy                           0.62        32
#    macro avg       0.64      0.61      0.60        32
# weighted avg       0.64      0.62      0.61        32
#
#
# Test set: Total loss: 0.693930, Accuracy: 0.480000
# Epoch: 71
# 	Average loss: 0.712045
# 	Accuracy: 0.505051
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.50      0.47        14
#          1.0       0.56      0.50      0.53        18
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.51      0.50      0.50        32
#
#
# Test set: Total loss: 0.692688, Accuracy: 0.560000
# Epoch: 72
# 	Average loss: 0.737711
# 	Accuracy: 0.474747
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.50      0.43        12
#          1.0       0.62      0.50      0.56        20
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.49        32
# weighted avg       0.53      0.50      0.51        32
#
#
# Test set: Total loss: 0.693626, Accuracy: 0.440000
# Epoch: 73
# 	Average loss: 0.725869
# 	Accuracy: 0.464646
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.56      0.49        16
#          1.0       0.36      0.25      0.30        16
#
#     accuracy                           0.41        32
#    macro avg       0.40      0.41      0.39        32
# weighted avg       0.40      0.41      0.39        32
#
#
# Test set: Total loss: 0.693655, Accuracy: 0.520000
# Epoch: 74
# 	Average loss: 0.702881
# 	Accuracy: 0.585859
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.50      0.62        18
#          1.0       0.57      0.86      0.69        14
#
#     accuracy                           0.66        32
#    macro avg       0.69      0.68      0.65        32
# weighted avg       0.71      0.66      0.65        32
#
#
# Test set: Total loss: 0.693286, Accuracy: 0.480000
# Epoch: 75
# 	Average loss: 0.671976
# 	Accuracy: 0.565657
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.56      0.59        18
#          1.0       0.50      0.57      0.53        14
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.57      0.56      0.56        32
#
#
# Test set: Total loss: 0.695379, Accuracy: 0.480000
# Epoch: 76
# 	Average loss: 0.717557
# 	Accuracy: 0.494949
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.47      0.50        19
#          1.0       0.33      0.38      0.36        13
#
#     accuracy                           0.44        32
#    macro avg       0.43      0.43      0.43        32
# weighted avg       0.45      0.44      0.44        32
#
#
# Test set: Total loss: 0.698439, Accuracy: 0.480000
# Epoch: 77
# 	Average loss: 0.720428
# 	Accuracy: 0.515152
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.50      0.45        14
#          1.0       0.53      0.44      0.48        18
#
#     accuracy                           0.47        32
#    macro avg       0.47      0.47      0.47        32
# weighted avg       0.48      0.47      0.47        32
#
#
# Test set: Total loss: 0.700767, Accuracy: 0.480000
# Epoch: 78
# 	Average loss: 0.723471
# 	Accuracy: 0.505051
#               precision    recall  f1-score   support
#
#          0.0       0.37      0.58      0.45        12
#          1.0       0.62      0.40      0.48        20
#
#     accuracy                           0.47        32
#    macro avg       0.49      0.49      0.47        32
# weighted avg       0.52      0.47      0.47        32
#
#
# Test set: Total loss: 0.699630, Accuracy: 0.480000
# Epoch: 79
# 	Average loss: 0.724000
# 	Accuracy: 0.545455
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.58      0.50        12
#          1.0       0.69      0.55      0.61        20
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.57      0.56        32
# weighted avg       0.59      0.56      0.57        32
#
#
# Test set: Total loss: 0.700702, Accuracy: 0.480000
# Epoch: 80
# 	Average loss: 0.698045
# 	Accuracy: 0.535354
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.59      0.61        17
#          1.0       0.56      0.60      0.58        15
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Test set: Total loss: 0.703059, Accuracy: 0.480000
# Epoch: 81
# 	Average loss: 0.659163
# 	Accuracy: 0.545455
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.64      0.60        14
#          1.0       0.69      0.61      0.65        18
#
#     accuracy                           0.62        32
#    macro avg       0.62      0.63      0.62        32
# weighted avg       0.63      0.62      0.63        32
#
#
# Test set: Total loss: 0.705350, Accuracy: 0.480000
# Epoch: 82
# 	Average loss: 0.764664
# 	Accuracy: 0.424242
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.63      0.59        19
#          1.0       0.30      0.23      0.26        13
#
#     accuracy                           0.47        32
#    macro avg       0.42      0.43      0.42        32
# weighted avg       0.45      0.47      0.45        32
#
#
# Test set: Total loss: 0.699678, Accuracy: 0.480000
# Epoch: 83
# 	Average loss: 0.743457
# 	Accuracy: 0.494949
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.27      0.32        15
#          1.0       0.50      0.65      0.56        17
#
#     accuracy                           0.47        32
#    macro avg       0.45      0.46      0.44        32
# weighted avg       0.45      0.47      0.45        32
#
#
# Test set: Total loss: 0.695181, Accuracy: 0.480000
# Epoch: 84
# 	Average loss: 0.750496
# 	Accuracy: 0.434343
#               precision    recall  f1-score   support
#
#          0.0       0.31      0.31      0.31        13
#          1.0       0.53      0.53      0.53        19
#
#     accuracy                           0.44        32
#    macro avg       0.42      0.42      0.42        32
# weighted avg       0.44      0.44      0.44        32
#
#
# Test set: Total loss: 0.694473, Accuracy: 0.440000
# Epoch: 85
# 	Average loss: 0.720381
# 	Accuracy: 0.505051
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.60      0.60        15
#          1.0       0.65      0.65      0.65        17
#
#     accuracy                           0.62        32
#    macro avg       0.62      0.62      0.62        32
# weighted avg       0.62      0.62      0.62        32
#
#
# Test set: Total loss: 0.695975, Accuracy: 0.480000
# Epoch: 86
# 	Average loss: 0.745735
# 	Accuracy: 0.474747
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.53      0.58        17
#          1.0       0.56      0.67      0.61        15
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.60      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Test set: Total loss: 0.697994, Accuracy: 0.480000
# Epoch: 87
# 	Average loss: 0.691178
# 	Accuracy: 0.535354
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.68      0.68        19
#          1.0       0.54      0.54      0.54        13
#
#     accuracy                           0.62        32
#    macro avg       0.61      0.61      0.61        32
# weighted avg       0.62      0.62      0.62        32
#
#
# Test set: Total loss: 0.700253, Accuracy: 0.480000
# Epoch: 88
# 	Average loss: 0.704717
# 	Accuracy: 0.484848
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.47      0.45        15
#          1.0       0.50      0.47      0.48        17
#
#     accuracy                           0.47        32
#    macro avg       0.47      0.47      0.47        32
# weighted avg       0.47      0.47      0.47        32
#
#
# Test set: Total loss: 0.704140, Accuracy: 0.480000
# Epoch: 89
# 	Average loss: 0.723580
# 	Accuracy: 0.515152
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.76      0.72        17
#          1.0       0.69      0.60      0.64        15
#
#     accuracy                           0.69        32
#    macro avg       0.69      0.68      0.68        32
# weighted avg       0.69      0.69      0.69        32
#
#
# Test set: Total loss: 0.700675, Accuracy: 0.480000
# Epoch: 90
# 	Average loss: 0.728200
# 	Accuracy: 0.494949
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.65      0.65        17
#          1.0       0.60      0.60      0.60        15
#
#     accuracy                           0.62        32
#    macro avg       0.62      0.62      0.62        32
# weighted avg       0.62      0.62      0.62        32
#
#
# Test set: Total loss: 0.696718, Accuracy: 0.480000
# Epoch: 91
# 	Average loss: 0.733441
# 	Accuracy: 0.434343
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.37      0.45        19
#          1.0       0.40      0.62      0.48        13
#
#     accuracy                           0.47        32
#    macro avg       0.49      0.49      0.47        32
# weighted avg       0.51      0.47      0.47        32
#
#
# Test set: Total loss: 0.694208, Accuracy: 0.480000
# Epoch: 92
# 	Average loss: 0.666577
# 	Accuracy: 0.585859
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.71      0.67        14
#          1.0       0.75      0.67      0.71        18
#
#     accuracy                           0.69        32
#    macro avg       0.69      0.69      0.69        32
# weighted avg       0.70      0.69      0.69        32
#
#
# Test set: Total loss: 0.694358, Accuracy: 0.480000
# Epoch: 93
# 	Average loss: 0.720020
# 	Accuracy: 0.474747
#               precision    recall  f1-score   support
#
#          0.0       0.37      0.50      0.42        14
#          1.0       0.46      0.33      0.39        18
#
#     accuracy                           0.41        32
#    macro avg       0.41      0.42      0.41        32
# weighted avg       0.42      0.41      0.40        32
#
#
# Test set: Total loss: 0.695335, Accuracy: 0.480000
# Epoch: 94
# 	Average loss: 0.719156
# 	Accuracy: 0.454545
#               precision    recall  f1-score   support
#
#          0.0       0.32      0.46      0.37        13
#          1.0       0.46      0.32      0.37        19
#
#     accuracy                           0.38        32
#    macro avg       0.39      0.39      0.37        32
# weighted avg       0.40      0.38      0.37        32
#
#
# Test set: Total loss: 0.695578, Accuracy: 0.480000
# Epoch: 95
# 	Average loss: 0.770075
# 	Accuracy: 0.444444
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50        16
#          1.0       0.50      0.50      0.50        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Test set: Total loss: 0.695019, Accuracy: 0.480000
# Epoch: 96
# 	Average loss: 0.715934
# 	Accuracy: 0.525253
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.65      0.65        17
#          1.0       0.60      0.60      0.60        15
#
#     accuracy                           0.62        32
#    macro avg       0.62      0.62      0.62        32
# weighted avg       0.62      0.62      0.62        32
#
#
# Test set: Total loss: 0.693253, Accuracy: 0.480000
# Epoch: 97
# 	Average loss: 0.693096
# 	Accuracy: 0.555556
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.50      0.55        16
#          1.0       0.58      0.69      0.63        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Test set: Total loss: 0.692596, Accuracy: 0.520000
# Epoch: 98
# 	Average loss: 0.777942
# 	Accuracy: 0.404040
#               precision    recall  f1-score   support
#
#          0.0       0.20      0.25      0.22        12
#          1.0       0.47      0.40      0.43        20
#
#     accuracy                           0.34        32
#    macro avg       0.34      0.33      0.33        32
# weighted avg       0.37      0.34      0.35        32
#
#
# Test set: Total loss: 0.692590, Accuracy: 0.520000
# Epoch: 99
# 	Average loss: 0.717760
# 	Accuracy: 0.474747
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.69      0.59        16
#          1.0       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Test set: Total loss: 0.692535, Accuracy: 0.520000
# Epoch: 100
# 	Average loss: 0.744109
# 	Accuracy: 0.484848
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.60      0.53        15
#          1.0       0.54      0.41      0.47        17
#
#     accuracy                           0.50        32
#    macro avg       0.51      0.51      0.50        32
# weighted avg       0.51      0.50      0.50        32
#
#
# Test set: Total loss: 0.692699, Accuracy: 0.440000
# Epoch: 101
# 	Average loss: 0.726956
# 	Accuracy: 0.444444
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.62      0.56        16
#          1.0       0.50      0.38      0.43        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.49        32
# weighted avg       0.50      0.50      0.49        32
#
#
# Test set: Total loss: 0.692787, Accuracy: 0.480000
# Epoch: 102
# 	Average loss: 0.722558
# 	Accuracy: 0.474747
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.47      0.50        17
#          1.0       0.47      0.53      0.50        15
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Test set: Total loss: 0.693453, Accuracy: 0.520000
# Epoch: 103
# 	Average loss: 0.747863
# 	Accuracy: 0.434343
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.58      0.59        19
#          1.0       0.43      0.46      0.44        13
#
#     accuracy                           0.53        32
#    macro avg       0.52      0.52      0.52        32
# weighted avg       0.54      0.53      0.53        32
#
#
# Test set: Total loss: 0.694118, Accuracy: 0.480000
# Epoch: 104
# 	Average loss: 0.716860
# 	Accuracy: 0.505051
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.53      0.52        15
#          1.0       0.56      0.53      0.55        17
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Test set: Total loss: 0.694882, Accuracy: 0.480000
# Epoch: 105
# 	Average loss: 0.727148
# 	Accuracy: 0.464646
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.62      0.54        16
#          1.0       0.45      0.31      0.37        16
#
#     accuracy                           0.47        32
#    macro avg       0.47      0.47      0.46        32
# weighted avg       0.47      0.47      0.46        32
#
#
# Test set: Total loss: 0.694956, Accuracy: 0.480000
# Epoch: 106
# 	Average loss: 0.721748
# 	Accuracy: 0.484848
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.69      0.59        16
#          1.0       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Test set: Total loss: 0.694532, Accuracy: 0.480000
# Epoch: 107
# 	Average loss: 0.732158
# 	Accuracy: 0.494949
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.44      0.47        18
#          1.0       0.38      0.43      0.40        14
#
#     accuracy                           0.44        32
#    macro avg       0.44      0.44      0.44        32
# weighted avg       0.45      0.44      0.44        32
#
#
# Test set: Total loss: 0.693484, Accuracy: 0.560000
# Epoch: 108
# 	Average loss: 0.724297
# 	Accuracy: 0.464646
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.62      0.53        13
#          1.0       0.67      0.53      0.59        19
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.57      0.56        32
# weighted avg       0.59      0.56      0.57        32
#
#
# Test set: Total loss: 0.693292, Accuracy: 0.520000
# Epoch: 109
# 	Average loss: 0.696579
# 	Accuracy: 0.565657
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.47      0.53        17
#          1.0       0.53      0.67      0.59        15
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.57      0.56        32
# weighted avg       0.57      0.56      0.56        32
#
#
# Test set: Total loss: 0.693166, Accuracy: 0.560000
# Epoch: 110
# 	Average loss: 0.712182
# 	Accuracy: 0.484848
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.31      0.37        16
#          1.0       0.48      0.62      0.54        16
#
#     accuracy                           0.47        32
#    macro avg       0.47      0.47      0.46        32
# weighted avg       0.47      0.47      0.46        32
#
#
# Test set: Total loss: 0.694217, Accuracy: 0.480000
# Epoch: 111
# 	Average loss: 0.703464
# 	Accuracy: 0.515152
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.57      0.53        14
#          1.0       0.62      0.56      0.59        18
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.57      0.56      0.56        32
#
#
# Test set: Total loss: 0.695683, Accuracy: 0.480000
# Epoch: 112
# 	Average loss: 0.677370
# 	Accuracy: 0.545455
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.50      0.59        20
#          1.0       0.44      0.67      0.53        12
#
#     accuracy                           0.56        32
#    macro avg       0.58      0.58      0.56        32
# weighted avg       0.61      0.56      0.57        32
#
#
# Test set: Total loss: 0.694848, Accuracy: 0.480000
# Epoch: 113
# 	Average loss: 0.729310
# 	Accuracy: 0.424242
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.42      0.43        19
#          1.0       0.21      0.23      0.22        13
#
#     accuracy                           0.34        32
#    macro avg       0.33      0.33      0.33        32
# weighted avg       0.35      0.34      0.35        32
#
#
# Test set: Total loss: 0.694419, Accuracy: 0.480000
# Epoch: 114
# 	Average loss: 0.698394
# 	Accuracy: 0.515152
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.45      0.38        11
#          1.0       0.65      0.52      0.58        21
#
#     accuracy                           0.50        32
#    macro avg       0.49      0.49      0.48        32
# weighted avg       0.54      0.50      0.51        32
#
#
# Test set: Total loss: 0.696039, Accuracy: 0.480000
# Epoch: 115
# 	Average loss: 0.734651
# 	Accuracy: 0.444444
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.62      0.57        16
#          1.0       0.54      0.44      0.48        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Test set: Total loss: 0.695340, Accuracy: 0.480000
# Epoch: 116
# 	Average loss: 0.702889
# 	Accuracy: 0.525253
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.47      0.52        17
#          1.0       0.50      0.60      0.55        15
#
#     accuracy                           0.53        32
#    macro avg       0.54      0.54      0.53        32
# weighted avg       0.54      0.53      0.53        32
#
#
# Test set: Total loss: 0.694148, Accuracy: 0.480000
# Epoch: 117
# 	Average loss: 0.745471
# 	Accuracy: 0.353535
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.47      0.43        17
#          1.0       0.25      0.20      0.22        15
#
#     accuracy                           0.34        32
#    macro avg       0.33      0.34      0.33        32
# weighted avg       0.33      0.34      0.33        32
#
#
# Test set: Total loss: 0.693545, Accuracy: 0.520000
# Epoch: 118
# 	Average loss: 0.733525
# 	Accuracy: 0.454545
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.52      0.61        21
#          1.0       0.41      0.64      0.50        11
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.58      0.56        32
# weighted avg       0.62      0.56      0.57        32
#
#
# Test set: Total loss: 0.692288, Accuracy: 0.480000
# Epoch: 119
# 	Average loss: 0.734962
# 	Accuracy: 0.404040
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.60      0.58        15
#          1.0       0.62      0.59      0.61        17
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Test set: Total loss: 0.692295, Accuracy: 0.520000

# %%
conv1 = list(CNNPoor.children())
print(conv1[1].weight.shape)
weight1 = conv1[1].weight.reshape((8,125)).data.numpy()
#weight2 = conv1[4].weight.reshape((16,7)).data.numpy()
# weight3 = conv1[9].weight.reshape((32,32)).data.numpy()
#weight4 = conv1[10].weight.reshape((16,32)).data.numpy()
# weight5 = conv1[16].weight.reshape((1,176)).data.numpy()
pyplot.figure(figsize=(20,10))
pyplot.imshow(weight1)

#pyplot.imshow(weight2)
#pyplot.imshow(weight3)
#pyplot.imshow(weight4)
# pyplot.imshow(weight5)
# Out:
# torch.Size([8, 1, 1, 125])

# %%
pyplot.plot(plots["train acc"], "royalblue", label = "train")
pyplot.plot(plots["test acc"], "darkorange", label = "test")
pyplot.title("accuracy over training")
pyplot.legend()
pyplot.show()

# %%
# tload = torch.utils.data.TensorDataset(X_train, X_actual)
# tloader = torch.utils.data.DataLoader(tload, batch_size = X_train.shape[0], shuffle = True)
# _, _, _, _ = test(CNNPoor, device, tloader)
_, _, _, _ = test(CNNPoor, device, test_loader)
# Out:
# Test set: Total loss: 0.692295, Accuracy: 0.520000

# %%
# torch.save(CNNPoor.state_dict(), '/content/drive/Shared drives/NeuroTech ML/my_model.pt')

# %%
# import pickle

# pickle.dump(CNNPoor, open('model.pkl', 'wb'))
# # model = pickle.load(open('model.pkl', 'rb'))
